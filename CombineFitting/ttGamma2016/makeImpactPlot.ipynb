# %%
# %%capture 
#toy ele
# !text2workspace.py  datacard_M3ChIso_ele_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125 -t -1 --expectSignal 0.85 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125 -t -1 --expectSignal 0.85 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125 -t -1 --expectSignal 0.85 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_ele_2016
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data ele
# !text2workspace.py  datacard_M3ChIso_ele_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2016.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_ele_2016
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

#toy mu
# !text2workspace.py  datacard_M3ChIso_mu_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125 -t -1 --expectSignal 0.92 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125 -t -1 --expectSignal 0.92 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125 -t -1 --expectSignal 0.92 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_mu_2016
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data mu
# !text2workspace.py  datacard_M3ChIso_mu_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2016.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_mu_2016
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)

# %%
# !plotImpacts.py --help
# Out:
# usage: plotImpacts.py [-h] [--input INPUT] [--output OUTPUT]
#                       [--translate TRANSLATE] [--units UNITS]
#                       [--per-page PER_PAGE] [--max-pages MAX_PAGES]
#                       [--height HEIGHT] [--left-margin LEFT_MARGIN]
#                       [--label-size LABEL_SIZE] [--cms-label CMS_LABEL]
#                       [--transparent] [--checkboxes] [--blind]
#                       [--color-groups COLOR_GROUPS] [--pullDef PULLDEF]
#                       [--POI POI]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --input INPUT, -i INPUT
#                         input json file
#   --output OUTPUT, -o OUTPUT
#                         name of the output file to create
#   --translate TRANSLATE, -t TRANSLATE
#                         JSON file for remapping of parameter names
#   --units UNITS         Add units to the best-fit parameter value
#   --per-page PER_PAGE   Number of parameters to show per page
# ...

# %%
# !combineTool.py -M Impacts --help
# Out:
# usage: combineTool.py [-M METHOD]
#                       [--job-mode {interactive,script,lxbatch,SGE,condor,crab3}]
#                       [--prefix-file PREFIX_FILE] [--task-name TASK_NAME]
#                       [--parallel PARALLEL] [--merge MERGE] [--dry-run]
#                       [--sub-opts SUB_OPTS] [--memory MEMORY]
#                       [--crab-area CRAB_AREA] [--custom-crab CUSTOM_CRAB]
#                       [--crab-extra-files CRAB_EXTRA_FILES [CRAB_EXTRA_FILES ...]]
#                       [--pre-cmd PRE_CMD]
#                       [--custom-crab-post CUSTOM_CRAB_POST] -m MASS -d
#                       DATACARD [--redefineSignalPOIs REDEFINESIGNALPOIS]
#                       [--setPhysicsModelParameters SETPHYSICSMODELPARAMETERS]
#                       [--setParameters SETPARAMETERS] [--name NAME]
#                       [--named PARAM1,PARAM2,...]
#                       [--exclude PARAM1,PARAM2,...] [--doInitialFit]
# ...

# %%
# %%capture 

#toy ele
# !text2workspace.py  datacard_M3ChIso_ele_2017.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125 -t -1 --expectSignal 0.85 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125 -t -1 --expectSignal 0.85 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125 -t -1 --expectSignal 0.85 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_ele_2017
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data ele
# !text2workspace.py  datacard_M3ChIso_ele_2017.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2017.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_ele_2017
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

#toy mu
# !text2workspace.py  datacard_M3ChIso_mu_2017.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125 -t -1 --expectSignal 0.92 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125 -t -1 --expectSignal 0.92 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125 -t -1 --expectSignal 0.92 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_mu_2017
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data mu
# !text2workspace.py  datacard_M3ChIso_mu_2017.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2017.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_mu_2017
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)

# %%
# %%capture 

#toy ele
# !text2workspace.py  datacard_M3ChIso_ele_2018.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125 -t -1 --expectSignal 0.85 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125 -t -1 --expectSignal 0.85 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125 -t -1 --expectSignal 0.85 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_ele_2018
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data ele
# !text2workspace.py  datacard_M3ChIso_ele_2018.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_ele_2018.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_ele_2018
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

#toy mu
# !text2workspace.py  datacard_M3ChIso_mu_2018.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125 -t -1 --expectSignal 0.92 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125 -t -1 --expectSignal 0.92 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125 -t -1 --expectSignal 0.92 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_toy_mu_2018
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	

# data mu
# !text2workspace.py  datacard_M3ChIso_mu_2018.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_M3ChIso_mu_2018.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts_data_mu_2018
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
