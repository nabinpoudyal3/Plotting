# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/Datacard_ZJets_2017

# %% [markdown]
# ## Both Channel

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1089.394783     51.911202       total sum
# 0          440.000000      20.976177       Unweighted events, alpha=2.475897
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1396.231483     59.746049       total sum
# 1          546.000000      23.366643       Unweighted events, alpha=2.557201
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1799.753586     68.481707       total sum
# 2          691.000000      26.286879       Unweighted events, alpha=2.604564
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2385.469902     78.974894       total sum
# 3          912.000000      30.199338       Unweighted events, alpha=2.615647
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3527.342728     96.031274       total sum
# 4          1349.000000     36.728735       Unweighted events, alpha=2.614783
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          5373.541916     119.455352      total sum
# 5          2024.000000     44.988888       Unweighted events, alpha=2.654912
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          8110.026825     147.369187      total sum
# 6          3029.000000     55.036352       Unweighted events, alpha=2.677460
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          12034.488373    178.793482      total sum
# 7          4531.000000     67.312703       Unweighted events, alpha=2.656034
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          18371.245605    221.251577      total sum
# 8          6895.000000     83.036137       Unweighted events, alpha=2.664430
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          26130.062958    264.280915      total sum
# 9          9776.000000     98.873657       Unweighted events, alpha=2.672879
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         31843.270386    291.630124      total sum
# 10         11923.000000    109.192491      Unweighted events, alpha=2.670743
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         30553.504761    285.890136      total sum
# 11         11422.000000    106.873757      Unweighted events, alpha=2.674970
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         24278.935364    254.699100      total sum
# 12         9087.000000     95.325757       Unweighted events, alpha=2.671832
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         16885.044128    211.570209      total sum
# 13         6369.000000     79.806015       Unweighted events, alpha=2.651130
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         11197.617798    172.481510      total sum
# 14         4215.000000     64.923031       Unweighted events, alpha=2.656612
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         7226.222061     138.700196      total sum
# 15         2714.000000     52.096065       Unweighted events, alpha=2.662573
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         4684.926819     111.399867      total sum
# 16         1769.000000     42.059482       Unweighted events, alpha=2.648348
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         3349.193207     93.338698       total sum
# 17         1288.000000     35.888717       Unweighted events, alpha=2.600305
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         2567.838272     82.432208       total sum
# 18         970.000000      31.144823       Unweighted events, alpha=2.647256
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1953.639961     71.543461       total sum
# 19         746.000000      27.313001       Unweighted events, alpha=2.618820
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3673.303497     97.476615       total sum
# 0          1420.000000     37.682887       Unweighted events, alpha=2.586833
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4245.857544     105.161289      total sum
# 1          1630.000000     40.373258       Unweighted events, alpha=2.604821
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          5439.422211     120.128669      total sum
# 2          2050.000000     45.276926       Unweighted events, alpha=2.653377
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          6759.349396     133.567131      total sum
# 3          2561.000000     50.606324       Unweighted events, alpha=2.639340
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          9295.873199     157.742264      total sum
# 4          3473.000000     58.932164       Unweighted events, alpha=2.676612
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          12283.883057    181.495475      total sum
# 5          4581.000000     67.683085       Unweighted events, alpha=2.681485
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          17917.672577    219.544875      total sum
# 6          6661.000000     81.614950       Unweighted events, alpha=2.689937
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          26944.937500    269.536649      total sum
# 7          9994.000000     99.969995       Unweighted events, alpha=2.696111
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          44041.234497    345.276283      total sum
# 8          16270.000000    127.553910      Unweighted events, alpha=2.706898
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          69014.981567    432.735950      total sum
# 9          25436.000000    159.486677      Unweighted events, alpha=2.713280
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         93579.416870    504.014574      total sum
# 10         34473.000000    185.669060      Unweighted events, alpha=2.714571
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         97208.815552    513.498929      total sum
# 11         35837.000000    189.306630      Unweighted events, alpha=2.712527
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         72702.574707    443.643194      total sum
# 12         26855.000000    163.874952      Unweighted events, alpha=2.707227
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         45664.938171    351.770843      total sum
# 13         16852.000000    129.815253      Unweighted events, alpha=2.709764
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         27494.209198    272.759614      total sum
# 14         10161.000000    100.801786      Unweighted events, alpha=2.705857
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         16660.026062    211.340495      total sum
# 15         6214.000000     78.828929       Unweighted events, alpha=2.681047
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         10874.200562    170.631196      total sum
# 16         4061.000000     63.725976       Unweighted events, alpha=2.677715
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         7843.819168     145.013365      total sum
# 17         2926.000000     54.092513       Unweighted events, alpha=2.680731
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         5975.522842     125.878605      total sum
# 18         2253.000000     47.465777       Unweighted events, alpha=2.652252
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         4659.751068     111.169958      total sum
# 19         1757.000000     41.916584       Unweighted events, alpha=2.652106
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-AtHexN.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8647a90
#   Clients:
#     (0x87904e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8648fb0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8574ac0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 214758
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8656e20
#   Clients:
#     (0x87904e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86560e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8657e10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 582280
# Error in <TList::Clear>: A list is accessing an object (0x87c11b4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87c145c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a0ba40
#   Clients:
#     (0x8a0a420,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8a33650,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8574ac0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 25303.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a3e2e0
#   Clients:
#     (0x8a0a420,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8a6ab70,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8657e10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 71012
# Error in <TList::Clear>: A list is accessing an object (0x87c1c54) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87c1efc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8647a90
#   Clients:
#     (0x87904e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8648fb0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8574ac0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 256592
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8656e20
#   Clients:
#     (0x87904e0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86560e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8657e10,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 770504
# Error in <TList::Clear>: A list is accessing an object (0x87c21a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87c244c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.29881  -0.00274443/+0.00275844  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1089.394783     51.911202       total sum
# 0          440.000000      20.976177       Unweighted events, alpha=2.475897
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1396.231483     59.746049       total sum
# 1          546.000000      23.366643       Unweighted events, alpha=2.557201
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1799.753586     68.481707       total sum
# 2          691.000000      26.286879       Unweighted events, alpha=2.604564
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2385.469902     78.974894       total sum
# 3          912.000000      30.199338       Unweighted events, alpha=2.615647
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3527.342728     96.031274       total sum
# 4          1349.000000     36.728735       Unweighted events, alpha=2.614783
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          5373.541916     119.455352      total sum
# 5          2024.000000     44.988888       Unweighted events, alpha=2.654912
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          8110.026825     147.369187      total sum
# 6          3029.000000     55.036352       Unweighted events, alpha=2.677460
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          12034.488373    178.793482      total sum
# 7          4531.000000     67.312703       Unweighted events, alpha=2.656034
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          18371.245605    221.251577      total sum
# 8          6895.000000     83.036137       Unweighted events, alpha=2.664430
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          26130.062958    264.280915      total sum
# 9          9776.000000     98.873657       Unweighted events, alpha=2.672879
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         31843.270386    291.630124      total sum
# 10         11923.000000    109.192491      Unweighted events, alpha=2.670743
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         30553.504761    285.890136      total sum
# 11         11422.000000    106.873757      Unweighted events, alpha=2.674970
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         24278.935364    254.699100      total sum
# 12         9087.000000     95.325757       Unweighted events, alpha=2.671832
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         16885.044128    211.570209      total sum
# 13         6369.000000     79.806015       Unweighted events, alpha=2.651130
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         11197.617798    172.481510      total sum
# 14         4215.000000     64.923031       Unweighted events, alpha=2.656612
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         7226.222061     138.700196      total sum
# 15         2714.000000     52.096065       Unweighted events, alpha=2.662573
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         4684.926819     111.399867      total sum
# 16         1769.000000     42.059482       Unweighted events, alpha=2.648348
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         3349.193207     93.338698       total sum
# 17         1288.000000     35.888717       Unweighted events, alpha=2.600305
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         2567.838272     82.432208       total sum
# 18         970.000000      31.144823       Unweighted events, alpha=2.647256
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1953.639961     71.543461       total sum
# 19         746.000000      27.313001       Unweighted events, alpha=2.618820
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3673.303497     97.476615       total sum
# 0          1420.000000     37.682887       Unweighted events, alpha=2.586833
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4245.857544     105.161289      total sum
# 1          1630.000000     40.373258       Unweighted events, alpha=2.604821
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          5439.422211     120.128669      total sum
# 2          2050.000000     45.276926       Unweighted events, alpha=2.653377
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          6759.349396     133.567131      total sum
# 3          2561.000000     50.606324       Unweighted events, alpha=2.639340
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          9295.873199     157.742264      total sum
# 4          3473.000000     58.932164       Unweighted events, alpha=2.676612
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          12283.883057    181.495475      total sum
# 5          4581.000000     67.683085       Unweighted events, alpha=2.681485
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          17917.672577    219.544875      total sum
# 6          6661.000000     81.614950       Unweighted events, alpha=2.689937
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          26944.937500    269.536649      total sum
# 7          9994.000000     99.969995       Unweighted events, alpha=2.696111
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          44041.234497    345.276283      total sum
# 8          16270.000000    127.553910      Unweighted events, alpha=2.706898
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          69014.981567    432.735950      total sum
# 9          25436.000000    159.486677      Unweighted events, alpha=2.713280
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         93579.416870    504.014574      total sum
# 10         34473.000000    185.669060      Unweighted events, alpha=2.714571
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         97208.815552    513.498929      total sum
# 11         35837.000000    189.306630      Unweighted events, alpha=2.712527
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         72702.574707    443.643194      total sum
# 12         26855.000000    163.874952      Unweighted events, alpha=2.707227
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         45664.938171    351.770843      total sum
# 13         16852.000000    129.815253      Unweighted events, alpha=2.709764
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         27494.209198    272.759614      total sum
# 14         10161.000000    100.801786      Unweighted events, alpha=2.705857
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         16660.026062    211.340495      total sum
# 15         6214.000000     78.828929       Unweighted events, alpha=2.681047
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         10874.200562    170.631196      total sum
# 16         4061.000000     63.725976       Unweighted events, alpha=2.677715
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         7843.819168     145.013365      total sum
# 17         2926.000000     54.092513       Unweighted events, alpha=2.680731
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         5975.522842     125.878605      total sum
# 18         2253.000000     47.465777       Unweighted events, alpha=2.652252
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         4659.751068     111.169958      total sum
# 19         1757.000000     41.916584       Unweighted events, alpha=2.652106
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-b3yRz3.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a750e0
#   Clients:
#     (0x8bbdb10,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a76600,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x89a2110,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 214758
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a84460
#   Clients:
#     (0x8bbdb10,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a83720,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8a85450,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 582280
# Error in <TList::Clear>: A list is accessing an object (0x8bee764) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8beea0c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e38d80
#   Clients:
#     (0x8e37760,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8e609e0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x89a2110,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 25303.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e6b670
#   Clients:
#     (0x8e37760,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8e97f00,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8a85450,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 71012
# Error in <TList::Clear>: A list is accessing an object (0x8bef204) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8bef4ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a750e0
#   Clients:
#     (0x8bbdb10,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a76600,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x89a2110,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 256592
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a84460
#   Clients:
#     (0x8bbdb10,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a83720,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8a85450,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 770504
# Error in <TList::Clear>: A list is accessing an object (0x8bef754) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8bef9fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.29881  -0.00274443/+0.00275844  (68% CL)
# Done in 0.05 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          818.205261      44.832957       total sum
# 0          333.000000      18.248288       Unweighted events, alpha=2.457073
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1076.803230     52.588300       total sum
# 1          419.000000      20.469489       Unweighted events, alpha=2.569936
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1381.715118     59.960375       total sum
# 2          531.000000      23.043437       Unweighted events, alpha=2.602100
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1847.889084     69.682591       total sum
# 3          703.000000      26.514147       Unweighted events, alpha=2.628576
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2767.870079     85.228622       total sum
# 4          1055.000000     32.480764       Unweighted events, alpha=2.623574
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4143.889313     105.131632      total sum
# 5          1554.000000     39.420807       Unweighted events, alpha=2.666595
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          6275.489113     129.684462      total sum
# 6          2342.000000     48.394215       Unweighted events, alpha=2.679543
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          9223.644730     156.470793      total sum
# 7          3475.000000     58.949131       Unweighted events, alpha=2.654286
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          14072.220932    193.654582      total sum
# 8          5280.000000     72.663608       Unweighted events, alpha=2.665193
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          20093.284943    231.842444      total sum
# 9          7511.000000     86.666026       Unweighted events, alpha=2.675181
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         24445.883270    255.607280      total sum
# 10         9147.000000     95.639950       Unweighted events, alpha=2.672557
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         23381.440826    250.233743      total sum
# 11         8731.000000     93.439820       Unweighted events, alpha=2.677980
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         18486.722321    222.321531      total sum
# 12         6914.000000     83.150466       Unweighted events, alpha=2.673810
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         12982.219925    185.584015      total sum
# 13         4893.000000     69.949982       Unweighted events, alpha=2.653223
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         8518.242081     150.607920      total sum
# 14         3199.000000     56.559703       Unweighted events, alpha=2.662783
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         5580.365921     121.923599      total sum
# 15         2095.000000     45.771170       Unweighted events, alpha=2.663659
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         3532.712791     96.659309       total sum
# 16         1336.000000     36.551334       Unweighted events, alpha=2.644246
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         2619.885834     82.426633       total sum
# 17         1010.000000     31.780497       Unweighted events, alpha=2.593946
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1945.533989     71.680528       total sum
# 18         737.000000      27.147744       Unweighted events, alpha=2.639802
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1573.081150     64.402743       total sum
# 19         597.000000      24.433583       Unweighted events, alpha=2.634977
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2804.725006     85.478506       total sum
# 0          1077.000000     32.817678       Unweighted events, alpha=2.604201
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3337.598160     93.437820       total sum
# 1          1276.000000     35.721142       Unweighted events, alpha=2.615673
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4204.587753     105.841538      total sum
# 2          1578.000000     39.724048       Unweighted events, alpha=2.664504
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5183.126831     117.219098      total sum
# 3          1955.000000     44.215382       Unweighted events, alpha=2.651216
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7195.574356     138.967781      total sum
# 4          2681.000000     51.778374       Unweighted events, alpha=2.683914
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          9635.868317     160.910145      total sum
# 5          3586.000000     59.883220       Unweighted events, alpha=2.687080
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          13854.423706    193.499148      total sum
# 6          5126.000000     71.596089       Unweighted events, alpha=2.702775
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          20853.464203    237.407976      total sum
# 7          7716.000000     87.840765       Unweighted events, alpha=2.702626
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          34591.872437    306.308945      total sum
# 8          12753.000000    112.929181      Unweighted events, alpha=2.712450
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          53909.831421    382.826887      total sum
# 9          19830.000000    140.819033      Unweighted events, alpha=2.718600
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         73796.761841    447.941904      total sum
# 10         27141.000000    164.745258      Unweighted events, alpha=2.719014
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         76316.879761    455.087922      total sum
# 11         28122.000000    167.696154      Unweighted events, alpha=2.713779
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         57217.354431    393.726307      total sum
# 12         21119.000000    145.323776      Unweighted events, alpha=2.709283
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         35477.760681    310.231963      total sum
# 13         13078.000000    114.359084      Unweighted events, alpha=2.712782
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         21418.891449    241.126062      total sum
# 14         7891.000000     88.831301       Unweighted events, alpha=2.714344
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         12876.164093    186.038211      total sum
# 15         4790.000000     69.209826       Unweighted events, alpha=2.688134
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         8393.279007     150.346606      total sum
# 16         3117.000000     55.830099       Unweighted events, alpha=2.692743
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         6113.461090     128.237453      total sum
# 17         2273.000000     47.675990       Unweighted events, alpha=2.689600
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         4666.668137     111.678008      total sum
# 18         1746.000000     41.785165       Unweighted events, alpha=2.672777
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         3589.801437     98.083544       total sum
# 19         1340.000000     36.606010       Unweighted events, alpha=2.678956
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-HXJIcz.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8ae2dd0
#   Clients:
#     (0x8c2b7f0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8ae42f0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8a0fe30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 164767
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8af2130
#   Clients:
#     (0x8c2b7f0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8af13f0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8af3120,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 455438
# Error in <TList::Clear>: A list is accessing an object (0x8c5c4c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c5c76c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8ea6a50
#   Clients:
#     (0x8ea5430,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ece9b0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8a0fe30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 19047.1
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8ed9640
#   Clients:
#     (0x8ea5430,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8f05f30,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8af3120,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 54265.6
# Error in <TList::Clear>: A list is accessing an object (0x8c5cf64) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c5d20c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8ae2dd0
#   Clients:
#     (0x8c2b7f0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8ae42f0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8a0fe30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 196963
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8af2130
#   Clients:
#     (0x8c2b7f0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8af13f0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8af3120,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 602078
# Error in <TList::Clear>: A list is accessing an object (0x8c5d4b4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c5d75c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.29792  -0.00310656/+0.00312245  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          214.937501      23.517528       total sum
# 0          84.000000       9.165151        Unweighted events, alpha=2.558780
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          255.062519      25.724164       total sum
# 1          98.000000       9.899495        Unweighted events, alpha=2.602679
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          336.570189      29.857255       total sum
# 2          127.000000      11.269428       Unweighted events, alpha=2.650159
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          414.935076      32.667320       total sum
# 3          161.000000      12.688578       Unweighted events, alpha=2.577236
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          570.546144      38.047241       total sum
# 4          225.000000      15.000000       Unweighted events, alpha=2.535761
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          977.557255      50.689653       total sum
# 5          372.000000      19.287302       Unweighted events, alpha=2.627842
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1432.539623     61.775341       total sum
# 6          538.000000      23.194827       Unweighted events, alpha=2.662713
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2187.875000     76.455104       total sum
# 7          819.000000      28.618176       Unweighted events, alpha=2.671398
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3272.825264     93.288114       total sum
# 8          1231.000000     35.085610       Unweighted events, alpha=2.658672
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4639.440590     111.325629      total sum
# 9          1737.000000     41.677332       Unweighted events, alpha=2.670950
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         5678.715881     123.132440      total sum
# 10         2127.000000     46.119410       Unweighted events, alpha=2.669824
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         5546.203247     121.571390      total sum
# 11         2081.000000     45.617979       Unweighted events, alpha=2.665163
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         4491.980362     109.569512      total sum
# 12         1681.000000     41.000000       Unweighted events, alpha=2.672207
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         2984.629242     88.803424       total sum
# 13         1130.000000     33.615473       Unweighted events, alpha=2.641265
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2014.676105     73.011729       total sum
# 14         761.000000      27.586228       Unweighted events, alpha=2.647406
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1308.494331     58.977485       total sum
# 15         492.000000      22.181073       Unweighted events, alpha=2.659541
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         890.125233      48.819090       total sum
# 16         332.000000      18.220867       Unweighted events, alpha=2.681100
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         557.955671      38.402696       total sum
# 17         211.000000      14.525839       Unweighted events, alpha=2.644340
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         487.859089      35.967687       total sum
# 18         184.000000      13.564660       Unweighted events, alpha=2.651408
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         299.279444      27.602352       total sum
# 19         118.000000      10.862780       Unweighted events, alpha=2.536266
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          655.055859      40.864885       total sum
# 0          257.000000      16.031220       Unweighted events, alpha=2.548855
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          724.779472      43.024398       total sum
# 1          284.000000      16.852300       Unweighted events, alpha=2.552040
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          975.426533      50.635498       total sum
# 2          371.000000      19.261360       Unweighted events, alpha=2.629182
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1203.338966     56.241038       total sum
# 3          458.000000      21.400935       Unweighted events, alpha=2.627378
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1594.505630     65.103236       total sum
# 4          600.000000      24.494897       Unweighted events, alpha=2.657509
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2067.704437     74.443902       total sum
# 5          771.000000      27.766887       Unweighted events, alpha=2.681848
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          3082.729179     90.209708       total sum
# 6          1168.000000     34.176015       Unweighted events, alpha=2.639323
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          4659.759636     111.552221      total sum
# 7          1745.000000     41.773197       Unweighted events, alpha=2.670349
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          7285.846359     139.938192      total sum
# 8          2711.000000     52.067264       Unweighted events, alpha=2.687512
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          11960.113724    179.544924      total sum
# 9          4437.000000     66.610810       Unweighted events, alpha=2.695541
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         15468.825134    204.277441      total sum
# 10         5734.000000     75.723180       Unweighted events, alpha=2.697737
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         16119.982697    208.849865      total sum
# 11         5957.000000     77.181604       Unweighted events, alpha=2.706057
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         12044.612915    180.343674      total sum
# 12         4461.000000     66.790718       Unweighted events, alpha=2.699980
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         7768.905334     144.259231      total sum
# 13         2900.000000     53.851648       Unweighted events, alpha=2.678933
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         4677.571159     111.872956      total sum
# 14         1748.000000     41.809090       Unweighted events, alpha=2.675956
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2928.392410     88.065979       total sum
# 15         1106.000000     33.256578       Unweighted events, alpha=2.647733
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1866.716988     69.980180       total sum
# 16         712.000000      26.683328       Unweighted events, alpha=2.621794
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1351.437145     59.978686       total sum
# 17         508.000000      22.538855       Unweighted events, alpha=2.660309
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         977.239815      50.285517       total sum
# 18         378.000000      19.442222       Unweighted events, alpha=2.585291
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         791.153057      44.883160       total sum
# 19         311.000000      17.635192       Unweighted events, alpha=2.543901
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-F8bknV.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90feb10
#   Clients:
#     (0x9247560,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9100030,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x902bb30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 38562.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x910dea0
#   Clients:
#     (0x9247560,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x910d160,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x910ee90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 98204.1
# Error in <TList::Clear>: A list is accessing an object (0x9278234) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x92784dc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94c2920
#   Clients:
#     (0x94c1300,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x94ea620,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x902bb30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 4747.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94f51f0
#   Clients:
#     (0x94c1300,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x95219c0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x910ee90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 12885.7
# Error in <TList::Clear>: A list is accessing an object (0x9278cd4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9278f7c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x90feb10
#   Clients:
#     (0x9247560,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9100030,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x902bb30,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 45897.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x910dea0
#   Clients:
#     (0x9247560,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x910d160,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x910ee90,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 131252
# Error in <TList::Clear>: A list is accessing an object (0x9279224) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x92794cc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.30806  -0.00666702/+0.00673455  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          56.251825       11.476267       total sum
# 0          24.000000       4.898979        Unweighted events, alpha=2.343826
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          64.365822       11.930150       total sum
# 1          29.000000       5.385165        Unweighted events, alpha=2.219511
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          81.469096       14.249280       total sum
# 2          33.000000       5.744563        Unweighted events, alpha=2.468760
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          122.645966      17.726154       total sum
# 3          48.000000       6.928203        Unweighted events, alpha=2.555124
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          188.927183      22.594139       total sum
# 4          70.000000       8.366600        Unweighted events, alpha=2.698960
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          252.095472      25.445633       total sum
# 5          98.000000       9.899495        Unweighted events, alpha=2.572403
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          401.999853      32.915418       total sum
# 6          149.000000      12.206556       Unweighted events, alpha=2.697986
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          622.965475      40.479836       total sum
# 7          237.000000      15.394804       Unweighted events, alpha=2.628546
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1026.188820     52.416512       total sum
# 8          383.000000      19.570386       Unweighted events, alpha=2.679344
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1397.380424     60.828347       total sum
# 9          528.000000      22.978251       Unweighted events, alpha=2.646554
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1718.772465     67.464433       total sum
# 10         649.000000      25.475478       Unweighted events, alpha=2.648340
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1625.930107     65.853176       total sum
# 11         610.000000      24.698178       Unweighted events, alpha=2.665459
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1300.234821     58.645461       total sum
# 12         492.000000      22.181073       Unweighted events, alpha=2.642754
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         918.179848      49.340435       total sum
# 13         346.000000      18.601075       Unweighted events, alpha=2.653699
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         664.662493      41.670289       total sum
# 14         254.000000      15.937377       Unweighted events, alpha=2.616781
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         337.368649      29.900444       total sum
# 15         127.000000      11.269428       Unweighted events, alpha=2.656446
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         262.084138      26.145838       total sum
# 16         100.000000      10.000000       Unweighted events, alpha=2.620841
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         171.350008      21.052213       total sum
# 17         66.000000       8.124038        Unweighted events, alpha=2.596212
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         134.444669      19.060331       total sum
# 18         50.000000       7.071068        Unweighted events, alpha=2.688893
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         81.279766       14.452115       total sum
# 19         32.000000       5.656854        Unweighted events, alpha=2.539993
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          213.525156      22.916732       total sum
# 0          87.000000       9.327379        Unweighted events, alpha=2.454312
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          183.478521      21.844259       total sum
# 1          71.000000       8.426150        Unweighted events, alpha=2.584205
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          259.404112      25.778135       total sum
# 2          101.000000      10.049876       Unweighted events, alpha=2.568358
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          372.880711      30.607307       total sum
# 3          148.000000      12.165525       Unweighted events, alpha=2.519464
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          505.805023      36.498579       total sum
# 4          192.000000      13.856406       Unweighted events, alpha=2.634401
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          580.313234      38.815441       total sum
# 5          224.000000      14.966630       Unweighted events, alpha=2.590684
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          980.507992      51.188282       total sum
# 6          367.000000      19.157244       Unweighted events, alpha=2.671684
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1431.776218     61.996450       total sum
# 7          533.000000      23.086793       Unweighted events, alpha=2.686259
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2163.294300     76.209212       total sum
# 8          806.000000      28.390139       Unweighted events, alpha=2.683988
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          3145.345535     92.019549       total sum
# 9          1168.000000     34.176015       Unweighted events, alpha=2.692933
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         4314.329506     107.932702      total sum
# 10         1598.000000     39.974992       Unweighted events, alpha=2.699831
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         4773.465279     113.832629      total sum
# 11         1758.000000     41.928511       Unweighted events, alpha=2.715282
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         3440.807991     96.307001       total sum
# 12         1276.000000     35.721142       Unweighted events, alpha=2.696558
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         2418.251255     81.780983       total sum
# 13         874.000000      29.563491       Unweighted events, alpha=2.766878
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1397.827427     61.159391       total sum
# 14         522.000000      22.847319       Unweighted events, alpha=2.677830
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         855.473600      47.947598       total sum
# 15         318.000000      17.832555       Unweighted events, alpha=2.690169
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         614.193254      40.170607       total sum
# 16         234.000000      15.297059       Unweighted events, alpha=2.624757
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         378.916590      31.410010       total sum
# 17         146.000000      12.083046       Unweighted events, alpha=2.595319
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         331.614664      29.065660       total sum
# 18         130.000000      11.401754       Unweighted events, alpha=2.550882
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         278.793278      26.905013       total sum
# 19         107.000000      10.344080       Unweighted events, alpha=2.605545
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-YorKY9.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9530020
#   Clients:
#     (0x9678a60,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9531540,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x945d050,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 11428.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x953f3a0
#   Clients:
#     (0x9678a60,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x953e660,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9540390,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 28640
# Error in <TList::Clear>: A list is accessing an object (0x96a96e4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x96a998c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x98f3b40
#   Clients:
#     (0x98f2520,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x991b750,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x945d050,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1486.49
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9926380
#   Clients:
#     (0x98f2520,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9952c20,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x9540390,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3800.11
# Error in <TList::Clear>: A list is accessing an object (0x96aa184) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x96aa42c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9530020
#   Clients:
#     (0x9678a60,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9531540,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x945d050,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 13719.1
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x953f3a0
#   Clients:
#     (0x9678a60,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x953e660,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9540390,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 37182.4
# Error in <TList::Clear>: A list is accessing an object (0x96aa6d4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x96aa97c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.28738  -0.0122278/+0.0123531  (68% CL)
# Done in 0.05 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          128.742912      13.769684       total sum
# 0          87.000000       9.327379        Unweighted events, alpha=1.479804
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          157.507339      15.889969       total sum
# 1          98.000000       9.899495        Unweighted events, alpha=1.607218
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          183.353600      17.832288       total sum
# 2          106.000000      10.295630       Unweighted events, alpha=1.729751
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          209.276482      19.424797       total sum
# 3          116.000000      10.770330       Unweighted events, alpha=1.804108
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          315.469284      25.277944       total sum
# 4          156.000000      12.489996       Unweighted events, alpha=2.022239
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          408.877724      29.717627       total sum
# 5          189.000000      13.747727       Unweighted events, alpha=2.163374
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          607.857162      37.325580       total sum
# 6          265.000000      16.278821       Unweighted events, alpha=2.293801
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          894.380287      45.258018       total sum
# 7          391.000000      19.773720       Unweighted events, alpha=2.287418
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1273.778770     54.669472       total sum
# 8          543.000000      23.302360       Unweighted events, alpha=2.345817
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1839.077446     66.521527       total sum
# 9          764.000000      27.640550       Unweighted events, alpha=2.407169
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         2225.810226     73.161795       total sum
# 10         926.000000      30.430248       Unweighted events, alpha=2.403683
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         2237.088127     74.046254       total sum
# 11         913.000000      30.215890       Unweighted events, alpha=2.450261
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1690.368233     63.743346       total sum
# 12         703.000000      26.514147       Unweighted events, alpha=2.404507
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         1073.994858     49.896950       total sum
# 13         463.000000      21.517435       Unweighted events, alpha=2.319643
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         822.818703      43.336573       total sum
# 14         360.000000      18.973666       Unweighted events, alpha=2.285608
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         542.207237      33.864456       total sum
# 15         256.000000      16.000000       Unweighted events, alpha=2.117997
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         353.942444      26.585714       total sum
# 16         177.000000      13.304135       Unweighted events, alpha=1.999675
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         278.474709      23.160350       total sum
# 17         145.000000      12.041595       Unweighted events, alpha=1.920515
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         231.787331      20.167976       total sum
# 18         132.000000      11.489125       Unweighted events, alpha=1.755965
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         204.903175      18.463637       total sum
# 19         123.000000      11.090537       Unweighted events, alpha=1.665879
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          436.045609      25.786607       total sum
# 0          286.000000      16.911535       Unweighted events, alpha=1.524635
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          431.835220      25.659432       total sum
# 1          283.000000      16.822604       Unweighted events, alpha=1.525920
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          533.085678      30.504748       total sum
# 2          305.000000      17.464249       Unweighted events, alpha=1.747822
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          604.611450      33.303990       total sum
# 3          330.000000      18.165902       Unweighted events, alpha=1.832156
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          784.855453      39.439752       total sum
# 4          396.000000      19.899749       Unweighted events, alpha=1.981958
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1096.738419     48.609817       total sum
# 5          509.000000      22.561028       Unweighted events, alpha=2.154692
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1348.453049     54.935083       total sum
# 6          603.000000      24.556058       Unweighted events, alpha=2.236241
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1974.633224     67.603644       total sum
# 7          853.000000      29.206164       Unweighted events, alpha=2.314928
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3156.569336     86.819127       total sum
# 8          1322.000000     36.359318       Unweighted events, alpha=2.387723
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4851.044403     108.883717      total sum
# 9          1985.000000     44.553339       Unweighted events, alpha=2.443851
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         6779.839752     129.594422      total sum
# 10         2737.000000     52.316345       Unweighted events, alpha=2.477106
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         6654.665985     128.336986      total sum
# 11         2689.000000     51.855569       Unweighted events, alpha=2.474774
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         5211.518585     114.036937      total sum
# 12         2089.000000     45.705580       Unweighted events, alpha=2.494743
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         3168.096008     87.125779       total sum
# 13         1322.000000     36.359318       Unweighted events, alpha=2.396442
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         2075.900162     69.670766       total sum
# 14         888.000000      29.799329       Unweighted events, alpha=2.337725
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1299.750885     53.168960       total sum
# 15         598.000000      24.454039       Unweighted events, alpha=2.173496
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         986.556915      45.185694       total sum
# 16         477.000000      21.840330       Unweighted events, alpha=2.068253
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         686.617447      36.391034       total sum
# 17         356.000000      18.867962       Unweighted events, alpha=1.928701
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         581.905029      32.485794       total sum
# 18         321.000000      17.916473       Unweighted events, alpha=1.812788
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         520.891006      30.152383       total sum
# 19         298.000000      17.262677       Unweighted events, alpha=1.747956
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-ifEm8c.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95b5e10
#   Clients:
#     (0x96fe830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x95b7330,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x94e2e50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 15679.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95c5170
#   Clients:
#     (0x96fe830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x95c4430,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x95c6160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 43183.6
# Error in <TList::Clear>: A list is accessing an object (0x972f4b4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x972f75c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x997a0e0
#   Clients:
#     (0x9978ac0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x99a1e00,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x94e2e50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 4013.66
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x99ac9d0
#   Clients:
#     (0x9978ac0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x99d9260,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x95c6160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 11240.1
# Error in <TList::Clear>: A list is accessing an object (0x972ff54) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x97301fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95b5e10
#   Clients:
#     (0x96fe830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x95b7330,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x94e2e50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 18864.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95c5170
#   Clients:
#     (0x96fe830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x95c4430,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x95c6160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 56600
# Error in <TList::Clear>: A list is accessing an object (0x97304a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x973074c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.3209  -0.0105195/+0.0107617  (68% CL)
# Done in 0.05 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          56.115410       8.003769        total sum
# 0          49.000000       7.000000        Unweighted events, alpha=1.145212
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          81.055767       10.567332       total sum
# 1          59.000000       7.681146        Unweighted events, alpha=1.373827
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          84.521446       11.919759       total sum
# 2          50.000000       7.071068        Unweighted events, alpha=1.690429
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          92.753075       12.649743       total sum
# 3          54.000000       7.348469        Unweighted events, alpha=1.717650
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          109.473961      14.231417       total sum
# 4          59.000000       7.681146        Unweighted events, alpha=1.855491
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          152.379353      17.758458       total sum
# 5          74.000000       8.602325        Unweighted events, alpha=2.059180
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          190.631767      19.505591       total sum
# 6          96.000000       9.797959        Unweighted events, alpha=1.985748
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          301.564213      25.679616       total sum
# 7          138.000000      11.747340       Unweighted events, alpha=2.185248
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          440.094650      31.747560       total sum
# 8          192.000000      13.856406       Unweighted events, alpha=2.292160
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          658.064632      39.318367       total sum
# 9          280.000000      16.733201       Unweighted events, alpha=2.350231
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         734.624664      41.546586       total sum
# 10         313.000000      17.691806       Unweighted events, alpha=2.347044
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         733.096806      41.677503       total sum
# 11         309.000000      17.578396       Unweighted events, alpha=2.372482
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         608.529354      37.526985       total sum
# 12         263.000000      16.217275       Unweighted events, alpha=2.313800
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         442.269115      31.516035       total sum
# 13         197.000000      14.035669       Unweighted events, alpha=2.245021
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         262.407433      23.582738       total sum
# 14         124.000000      11.135529       Unweighted events, alpha=2.116189
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         222.725075      21.679222       total sum
# 15         106.000000      10.295630       Unweighted events, alpha=2.101180
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         141.960720      16.593810       total sum
# 16         73.000000       8.544004        Unweighted events, alpha=1.944667
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         111.690407      14.051361       total sum
# 17         63.000000       7.937254        Unweighted events, alpha=1.772864
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         82.019951       10.572675       total sum
# 18         60.000000       7.745967        Unweighted events, alpha=1.366999
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         69.715443       8.732041        total sum
# 19         64.000000       8.000000        Unweighted events, alpha=1.089304
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          154.558861      12.709529       total sum
# 0          148.000000      12.165525       Unweighted events, alpha=1.044317
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          200.322609      17.189804       total sum
# 1          136.000000      11.661904       Unweighted events, alpha=1.472960
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          192.280983      16.468413       total sum
# 2          136.000000      11.661904       Unweighted events, alpha=1.413831
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          245.757317      19.952293       total sum
# 3          152.000000      12.328828       Unweighted events, alpha=1.616824
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          268.404503      22.326283       total sum
# 4          145.000000      12.041595       Unweighted events, alpha=1.851066
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          347.677948      25.251843       total sum
# 5          190.000000      13.784049       Unweighted events, alpha=1.829884
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          541.363190      34.120532       total sum
# 6          252.000000      15.874508       Unweighted events, alpha=2.148267
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          677.583954      39.011726       total sum
# 7          302.000000      17.378147       Unweighted events, alpha=2.243655
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          957.695801      47.331796       total sum
# 8          409.000000      20.223748       Unweighted events, alpha=2.341555
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1480.657074     59.247130       total sum
# 9          625.000000      25.000000       Unweighted events, alpha=2.369051
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1931.040573     68.306484       total sum
# 10         799.000000      28.266588       Unweighted events, alpha=2.416822
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         2033.738281     69.968692       total sum
# 11         845.000000      29.068884       Unweighted events, alpha=2.406791
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1558.827194     61.443234       total sum
# 12         644.000000      25.377155       Unweighted events, alpha=2.420539
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         895.831688      45.070128       total sum
# 13         395.000000      19.874607       Unweighted events, alpha=2.267928
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         652.818779      38.057602       total sum
# 14         294.000000      17.146428       Unweighted events, alpha=2.220472
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         378.899475      27.162841       total sum
# 15         195.000000      13.964240       Unweighted events, alpha=1.943074
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         322.985909      24.526608       total sum
# 16         173.000000      13.152946       Unweighted events, alpha=1.866971
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         254.573128      20.744742       total sum
# 17         151.000000      12.288206       Unweighted events, alpha=1.685915
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         244.681137      19.804894       total sum
# 18         153.000000      12.369317       Unweighted events, alpha=1.599223
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         203.666435      17.656616       total sum
# 19         133.000000      11.532563       Unweighted events, alpha=1.531327
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-PCBKFi.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f49e90
#   Clients:
#     (0x80928b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f4b3b0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7e76ed0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 5575.69
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f591f0
#   Clients:
#     (0x80928b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f584b0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7f5a1e0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 13543.4
# Error in <TList::Clear>: A list is accessing an object (0x80c3504) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80c37ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x830d9f0
#   Clients:
#     (0x830c3d0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8335940,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7e76ed0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1720.25
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8340510
#   Clients:
#     (0x830c3d0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x836ccf0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7f5a1e0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 4636.24
# Error in <TList::Clear>: A list is accessing an object (0x80c3fa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80c424c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f49e90
#   Clients:
#     (0x80928b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f4b3b0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7e76ed0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 6962.24
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f591f0
#   Clients:
#     (0x80928b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f584b0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7f5a1e0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 19049.2
# Error in <TList::Clear>: A list is accessing an object (0x80c44f4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80c479c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.44126  -0.0206732/+0.021251  (68% CL)
# Done in 0.05 min (cpu), 0.06 min (real)

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          54.132786       5.748455        total sum
# 0          89.000000       9.433981        Unweighted events, alpha=0.608234
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          44.443147       4.736319        total sum
# 1          88.000000       9.380832        Unweighted events, alpha=0.505036
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          62.083944       8.266924        total sum
# 2          56.000000       7.483315        Unweighted events, alpha=1.108642
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          67.761625       8.597401        total sum
# 3          62.000000       7.874008        Unweighted events, alpha=1.092929
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          63.818014       9.368248        total sum
# 4          46.000000       6.782330        Unweighted events, alpha=1.387348
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          90.284843       11.236707       total sum
# 5          65.000000       8.062258        Unweighted events, alpha=1.388998
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          92.519222       11.197906       total sum
# 6          68.000000       8.246211        Unweighted events, alpha=1.360577
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          162.575085      17.126308       total sum
# 7          90.000000       9.486833        Unweighted events, alpha=1.806390
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          195.139259      19.019923       total sum
# 8          105.000000      10.246951       Unweighted events, alpha=1.858469
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          245.139141      22.138965       total sum
# 9          123.000000      11.090537       Unweighted events, alpha=1.993001
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         327.360287      26.413634       total sum
# 10         154.000000      12.409674       Unweighted events, alpha=2.125716
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         264.014214      22.828408       total sum
# 11         134.000000      11.575837       Unweighted events, alpha=1.970255
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         256.573494      22.160361       total sum
# 12         134.000000      11.575837       Unweighted events, alpha=1.914728
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         205.903114      19.094332       total sum
# 13         116.000000      10.770330       Unweighted events, alpha=1.775027
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         146.972935      16.210658       total sum
# 14         82.000000       9.055385        Unweighted events, alpha=1.792353
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         96.533371       11.023613       total sum
# 15         77.000000       8.774964        Unweighted events, alpha=1.253680
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         98.356926       11.575112       total sum
# 16         72.000000       8.485281        Unweighted events, alpha=1.366068
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         67.032864       7.672149        total sum
# 17         76.000000       8.717798        Unweighted events, alpha=0.882011
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         75.420509       8.185521        total sum
# 18         85.000000       9.219544        Unweighted events, alpha=0.887300
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         56.467355       4.997255        total sum
# 19         128.000000      11.313708       Unweighted events, alpha=0.441151
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          162.680140      11.201934       total sum
# 0          211.000000      14.525839       Unweighted events, alpha=0.770996
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          161.185711      11.946309       total sum
# 1          182.000000      13.490738       Unweighted events, alpha=0.885636
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          169.623814      12.752813       total sum
# 2          177.000000      13.304135       Unweighted events, alpha=0.958327
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          177.966507      13.361052       total sum
# 3          177.000000      13.304135       Unweighted events, alpha=1.005460
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          196.135765      15.033393       total sum
# 4          170.000000      13.038405       Unweighted events, alpha=1.153740
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          242.446686      18.451614       total sum
# 5          173.000000      13.152946       Unweighted events, alpha=1.401426
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          264.558624      19.254483       total sum
# 6          189.000000      13.747727       Unweighted events, alpha=1.399781
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          345.850098      23.743539       total sum
# 7          212.000000      14.560220       Unweighted events, alpha=1.631368
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          478.000366      29.428858       total sum
# 8          264.000000      16.248077       Unweighted events, alpha=1.810607
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          699.099182      37.568949       total sum
# 9          346.000000      18.601075       Unweighted events, alpha=2.020518
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         818.294662      41.527966       total sum
# 10         388.000000      19.697716       Unweighted events, alpha=2.109007
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         851.945755      42.163082       total sum
# 11         408.000000      20.199010       Unweighted events, alpha=2.088102
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         645.674484      36.041454       total sum
# 12         321.000000      17.916473       Unweighted events, alpha=2.011447
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         447.868164      28.247432       total sum
# 13         251.000000      15.842980       Unweighted events, alpha=1.784335
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         344.029953      23.834274       total sum
# 14         208.000000      14.422205       Unweighted events, alpha=1.653990
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         241.542191      17.966385       total sum
# 15         181.000000      13.453624       Unweighted events, alpha=1.334487
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         208.926964      15.324881       total sum
# 16         186.000000      13.638182       Unweighted events, alpha=1.123263
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         203.647396      14.120672       total sum
# 17         208.000000      14.422205       Unweighted events, alpha=0.979074
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         183.298714      13.171088       total sum
# 18         194.000000      13.928388       Unweighted events, alpha=0.944839
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         165.451220      10.985103       total sum
# 19         227.000000      15.066519       Unweighted events, alpha=0.728860
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-MdMcI7.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x84199b0
#   Clients:
#     (0x8562400,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x841aed0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x83469e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2672.53
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8428d40
#   Clients:
#     (0x8562400,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8428000,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8429d30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7008.23
# Error in <TList::Clear>: A list is accessing an object (0x8593064) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x859330c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87ddb70
#   Clients:
#     (0x87dc550,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8805810,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x83469e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1399.83
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x88104a0
#   Clients:
#     (0x87dc550,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x883cd90,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8429d30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3840.23
# Error in <TList::Clear>: A list is accessing an object (0x8593b04) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8593dac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x84199b0
#   Clients:
#     (0x8562400,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x841aed0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x83469e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2876.57
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8428d40
#   Clients:
#     (0x8562400,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8428000,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8429d30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7953.01
# Error in <TList::Clear>: A list is accessing an object (0x8594054) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x85942fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.1994  -0.0297269/+0.0310799  (68% CL)
# Done in 0.05 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          29.984650       4.257276        total sum
# 0          50.000000       7.071068        Unweighted events, alpha=0.599693
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          24.225063       3.380251        total sum
# 1          51.000000       7.141428        Unweighted events, alpha=0.475001
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          30.242105       5.910938        total sum
# 2          26.000000       5.099020        Unweighted events, alpha=1.163158
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          37.464424       5.300766        total sum
# 3          50.000000       7.071068        Unweighted events, alpha=0.749288
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          44.710834       6.187293        total sum
# 4          52.000000       7.211103        Unweighted events, alpha=0.859824
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          44.271801       7.881424        total sum
# 5          32.000000       5.656854        Unweighted events, alpha=1.383494
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          70.843830       10.010293       total sum
# 6          50.000000       7.071068        Unweighted events, alpha=1.416877
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          81.464506       11.562087       total sum
# 7          50.000000       7.071068        Unweighted events, alpha=1.629290
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          116.336147      14.107452       total sum
# 8          68.000000       8.246211        Unweighted events, alpha=1.710826
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          147.806057      16.637716       total sum
# 9          79.000000       8.888194        Unweighted events, alpha=1.870963
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         168.376591      18.253022       total sum
# 10         85.000000       9.219544        Unweighted events, alpha=1.980901
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         225.045208      22.342541       total sum
# 11         101.000000      10.049876       Unweighted events, alpha=2.228170
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         132.720678      15.996645       total sum
# 12         69.000000       8.306624        Unweighted events, alpha=1.923488
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         130.445904      15.915147       total sum
# 13         67.000000       8.185353        Unweighted events, alpha=1.946954
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         73.314613       10.604685       total sum
# 14         48.000000       6.928203        Unweighted events, alpha=1.527388
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         54.726809       9.413054        total sum
# 15         34.000000       5.830952        Unweighted events, alpha=1.609612
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         53.109362       7.337345        total sum
# 16         52.000000       7.211103        Unweighted events, alpha=1.021334
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         52.997849       8.659577        total sum
# 17         37.000000       6.082763        Unweighted events, alpha=1.432374
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         33.918344       5.433386        total sum
# 18         39.000000       6.244998        Unweighted events, alpha=0.869701
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         58.872547       8.766010        total sum
# 19         45.000000       6.708204        Unweighted events, alpha=1.308279
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          87.673912       8.598436        total sum
# 0          104.000000      10.198039       Unweighted events, alpha=0.843018
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          97.665878       9.323301        total sum
# 1          110.000000      10.488088       Unweighted events, alpha=0.887872
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          104.384033      9.201305        total sum
# 2          129.000000      11.357817       Unweighted events, alpha=0.809179
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          110.536694      10.386278       total sum
# 3          113.000000      10.630146       Unweighted events, alpha=0.978201
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          103.419916      9.191121        total sum
# 4          127.000000      11.269428       Unweighted events, alpha=0.814330
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          120.341793      11.590751       total sum
# 5          108.000000      10.392305       Unweighted events, alpha=1.114276
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          161.668571      15.286892       total sum
# 6          112.000000      10.583005       Unweighted events, alpha=1.443469
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          209.176216      18.032028       total sum
# 7          135.000000      11.618950       Unweighted events, alpha=1.549453
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          237.508698      20.377461       total sum
# 8          136.000000      11.661904       Unweighted events, alpha=1.746387
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          299.325005      24.047368       total sum
# 9          155.000000      12.449900       Unweighted events, alpha=1.931129
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         415.154991      29.209519       total sum
# 10         202.000000      14.212670       Unweighted events, alpha=2.055223
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         420.352692      29.219704       total sum
# 11         207.000000      14.387495       Unweighted events, alpha=2.030689
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         338.250404      26.034845       total sum
# 12         169.000000      13.000000       Unweighted events, alpha=2.001482
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         229.791313      19.754136       total sum
# 13         135.000000      11.618950       Unweighted events, alpha=1.702158
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         161.449844      15.707026       total sum
# 14         106.000000      10.295630       Unweighted events, alpha=1.523112
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         114.729904      10.750415       total sum
# 15         114.000000      10.677078       Unweighted events, alpha=1.006403
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         101.499035      8.401251        total sum
# 16         146.000000      12.083046       Unweighted events, alpha=0.695199
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         104.036505      9.877978        total sum
# 17         111.000000      10.535654       Unweighted events, alpha=0.937266
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         82.820661       6.714899        total sum
# 18         152.000000      12.328828       Unweighted events, alpha=0.544873
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         93.315368       8.665121        total sum
# 19         116.000000      10.770330       Unweighted events, alpha=0.804443
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-kifQuj.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86d9ab0
#   Clients:
#     (0x8822500,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86dafd0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8606ae0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1610.88
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86e8e40
#   Clients:
#     (0x8822500,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86e8100,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x86e9e30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 3593.1
# Error in <TList::Clear>: A list is accessing an object (0x8853184) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x885342c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a9d410
#   Clients:
#     (0x8a9bdf0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ac50b0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8606ae0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 831.067
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8acfce0
#   Clients:
#     (0x8a9bdf0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8afc5d0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x86e9e30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2222.89
# Error in <TList::Clear>: A list is accessing an object (0x8853c24) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8853ecc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86d9ab0
#   Clients:
#     (0x8822500,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86dafd0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8606ae0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1657.81
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86e8e40
#   Clients:
#     (0x8822500,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86e8100,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x86e9e30,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 4321.27
# Error in <TList::Clear>: A list is accessing an object (0x8854174) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x885441c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.29211  -0.0464946/+0.0490554  (68% CL)
# Done in 0.04 min (cpu), 0.09 min (real)

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          45.919125       7.146164        total sum
# 0          41.000000       6.403124        Unweighted events, alpha=1.119979
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          42.818094       7.464688        total sum
# 1          33.000000       5.744563        Unweighted events, alpha=1.297518
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          54.179243       8.921220        total sum
# 2          37.000000       6.082763        Unweighted events, alpha=1.464304
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          68.052944       10.224849       total sum
# 3          44.000000       6.633250        Unweighted events, alpha=1.546658
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          66.021460       9.191188        total sum
# 4          52.000000       7.211103        Unweighted events, alpha=1.269643
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          86.300266       11.857626       total sum
# 5          53.000000       7.280110        Unweighted events, alpha=1.628307
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          122.101669      14.853867       total sum
# 6          68.000000       8.246211        Unweighted events, alpha=1.795613
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          186.912624      20.065972       total sum
# 7          87.000000       9.327379        Unweighted events, alpha=2.148421
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          263.170391      24.160269       total sum
# 8          119.000000      10.908712       Unweighted events, alpha=2.211516
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          309.301598      25.450087       total sum
# 9          148.000000      12.165525       Unweighted events, alpha=2.089876
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         458.003704      33.008066       total sum
# 10         193.000000      13.892444       Unweighted events, alpha=2.373076
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         388.833611      30.080561       total sum
# 11         167.000000      12.922848       Unweighted events, alpha=2.328345
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         326.563679      27.164667       total sum
# 12         145.000000      12.041595       Unweighted events, alpha=2.252163
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         218.580524      21.738164       total sum
# 13         101.000000      10.049876       Unweighted events, alpha=2.164164
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         142.872841      16.450541       total sum
# 14         75.000000       8.660254        Unweighted events, alpha=1.904971
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         102.153709      13.298632       total sum
# 15         59.000000       7.681146        Unweighted events, alpha=1.731419
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         73.264317       9.547237        total sum
# 16         59.000000       7.681146        Unweighted events, alpha=1.241768
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         79.497894       10.868335       total sum
# 17         54.000000       7.348469        Unweighted events, alpha=1.472183
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         46.514523       6.164355        total sum
# 18         57.000000       7.549834        Unweighted events, alpha=0.816044
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         65.351568       9.201059        total sum
# 19         50.000000       7.071068        Unweighted events, alpha=1.307031
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          110.757763      10.141801       total sum
# 0          119.000000      10.908712       Unweighted events, alpha=0.930738
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          146.970779      12.891253       total sum
# 1          130.000000      11.401754       Unweighted events, alpha=1.130544
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          159.176170      14.247158       total sum
# 2          125.000000      11.180340       Unweighted events, alpha=1.273409
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          170.421776      15.398882       total sum
# 3          122.000000      11.045361       Unweighted events, alpha=1.396900
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          215.850212      18.701918       total sum
# 4          133.000000      11.532563       Unweighted events, alpha=1.622934
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          218.663788      18.432714       total sum
# 5          141.000000      11.874342       Unweighted events, alpha=1.550807
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          268.017555      22.232425       total sum
# 6          145.000000      12.041595       Unweighted events, alpha=1.848397
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          409.153709      28.625957       total sum
# 7          204.000000      14.282857       Unweighted events, alpha=2.005655
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          533.561615      33.149211       total sum
# 8          259.000000      16.093477       Unweighted events, alpha=2.060083
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          795.325600      42.678116       total sum
# 9          347.000000      18.627936       Unweighted events, alpha=2.292005
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1004.638565     48.406735       total sum
# 10         431.000000      20.760539       Unweighted events, alpha=2.330948
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1049.189697     49.773998       total sum
# 11         444.000000      21.071308       Unweighted events, alpha=2.363040
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         805.900085      42.097910       total sum
# 12         366.000000      19.131126       Unweighted events, alpha=2.201913
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         508.030327      32.358712       total sum
# 13         246.000000      15.684387       Unweighted events, alpha=2.065164
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         361.248955      26.307634       total sum
# 14         189.000000      13.747727       Unweighted events, alpha=1.911370
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         275.912369      22.471414       total sum
# 15         151.000000      12.288206       Unweighted events, alpha=1.827234
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         254.565643      21.117256       total sum
# 16         145.000000      12.041595       Unweighted events, alpha=1.755625
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         188.262321      16.227098       total sum
# 17         135.000000      11.618950       Unweighted events, alpha=1.394536
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         148.805481      14.602543       total sum
# 18         104.000000      10.198039       Unweighted events, alpha=1.430822
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         157.394768      13.422727       total sum
# 19         137.000000      11.704700       Unweighted events, alpha=1.148867
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-XAKlAe.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x942ede0
#   Clients:
#     (0x9577800,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9430300,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x935be10,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 3146.41
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x943e140
#   Clients:
#     (0x9577800,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x943d400,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x943f130,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7781.85
# Error in <TList::Clear>: A list is accessing an object (0x95a84d4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95a877c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x97f2a80
#   Clients:
#     (0x97f1460,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x981a9e0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x935be10,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1391.62
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9825670
#   Clients:
#     (0x97f1460,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9851ea0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x943f130,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3707.56
# Error in <TList::Clear>: A list is accessing an object (0x95a8f74) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95a921c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x942ede0
#   Clients:
#     (0x9577800,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9430300,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x935be10,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 3942.13
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x943e140
#   Clients:
#     (0x9577800,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x943d400,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x943f130,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 10518
# Error in <TList::Clear>: A list is accessing an object (0x95a94c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95a976c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.46559  -0.0308025/+0.0318748  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)
