# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/Plotting/CombineFitting/Datacard_ZJets_2017

# %% [markdown]
# ## Both Channel

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2722.711868     82.695027       total sum
# 0          1084.000000     32.924155       Unweighted events, alpha=2.511727
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4676.323380     110.020567      total sum
# 1          1807.000000     42.508823       Unweighted events, alpha=2.587893
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          10013.694336    161.890519      total sum
# 2          3826.000000     61.854668       Unweighted events, alpha=2.617275
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          22523.177429    244.512624      total sum
# 3          8485.000000     92.114060       Unweighted events, alpha=2.654470
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          48564.120972    360.260433      total sum
# 4          18172.000000    134.803561      Unweighted events, alpha=2.672470
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          67347.504150    424.996315      total sum
# 5          25112.000000    158.467662      Unweighted events, alpha=2.681885
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          45603.151794    348.952222      total sum
# 6          17079.000000    130.686648      Unweighted events, alpha=2.670130
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          21196.614502    237.479633      total sum
# 7          7967.000000     89.258053       Unweighted events, alpha=2.660552
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          9449.020966     157.820951      total sum
# 8          3585.000000     59.874870       Unweighted events, alpha=2.635710
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          5113.506989     116.065754      total sum
# 9          1941.000000     44.056782       Unweighted events, alpha=2.634470
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          8293.353394     151.279958      total sum
# 0          3005.000000     54.817880       Unweighted events, alpha=2.759851
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          12779.233154    189.472446      total sum
# 1          4549.000000     67.446275       Unweighted events, alpha=2.809240
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          22633.707764    253.827969      total sum
# 2          7951.000000     89.168380       Unweighted events, alpha=2.846649
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          47060.603638    367.018403      total sum
# 3          16441.000000    128.222463      Unweighted events, alpha=2.862393
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          118728.833252   584.808558      total sum
# 4          41218.000000    203.022166      Unweighted events, alpha=2.880509
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          200423.267578   760.228641      total sum
# 5          69504.000000    263.636113      Unweighted events, alpha=2.883622
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          124299.561279   598.031836      total sum
# 6          43201.000000    207.848503      Unweighted events, alpha=2.877238
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          46387.544312    364.454446      total sum
# 7          16200.000000    127.279221      Unweighted events, alpha=2.863429
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          19623.034546    236.346876      total sum
# 8          6893.000000     83.024093       Unweighted events, alpha=2.846806
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          11118.721008    177.171838      total sum
# 9          3938.000000     62.753486       Unweighted events, alpha=2.823444
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-3BT3l8.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9221fa0
#   Clients:
#     (0x934dc40,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x92234c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x916ba70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 237210
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9231320
#   Clients:
#     (0x934dc40,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x92305e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9232310,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 611348
# Error in <TList::Clear>: A list is accessing an object (0x937ea74) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x937ed1c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9591220
#   Clients:
#     (0x958fc00,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x95a6090,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x916ba70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 25591.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x95b07d0
#   Clients:
#     (0x958fc00,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x95c7c80,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x9232310,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 67665.1
# Error in <TList::Clear>: A list is accessing an object (0x937f514) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x937f7bc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9221fa0
#   Clients:
#     (0x934dc40,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x92234c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x916ba70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 281009
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9231320
#   Clients:
#     (0x934dc40,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x92305e0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9232310,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 772128
# Error in <TList::Clear>: A list is accessing an object (0x937fa64) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x937fd0c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.24719  -0.00259778/+0.00262118  (68% CL)
# Done in 0.02 min (cpu), 0.07 min (real)

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2722.711868     82.695027       total sum
# 0          1084.000000     32.924155       Unweighted events, alpha=2.511727
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          4676.323380     110.020567      total sum
# 1          1807.000000     42.508823       Unweighted events, alpha=2.587893
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          10013.694336    161.890519      total sum
# 2          3826.000000     61.854668       Unweighted events, alpha=2.617275
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          22523.177429    244.512624      total sum
# 3          8485.000000     92.114060       Unweighted events, alpha=2.654470
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          48564.120972    360.260433      total sum
# 4          18172.000000    134.803561      Unweighted events, alpha=2.672470
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          67347.504150    424.996315      total sum
# 5          25112.000000    158.467662      Unweighted events, alpha=2.681885
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          45603.151794    348.952222      total sum
# 6          17079.000000    130.686648      Unweighted events, alpha=2.670130
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          21196.614502    237.479633      total sum
# 7          7967.000000     89.258053       Unweighted events, alpha=2.660552
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          9449.020966     157.820951      total sum
# 8          3585.000000     59.874870       Unweighted events, alpha=2.635710
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          5113.506989     116.065754      total sum
# 9          1941.000000     44.056782       Unweighted events, alpha=2.634470
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          8293.353394     151.279958      total sum
# 0          3005.000000     54.817880       Unweighted events, alpha=2.759851
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          12779.233154    189.472446      total sum
# 1          4549.000000     67.446275       Unweighted events, alpha=2.809240
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          22633.707764    253.827969      total sum
# 2          7951.000000     89.168380       Unweighted events, alpha=2.846649
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          47060.603638    367.018403      total sum
# 3          16441.000000    128.222463      Unweighted events, alpha=2.862393
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          118728.833252   584.808558      total sum
# 4          41218.000000    203.022166      Unweighted events, alpha=2.880509
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          200423.267578   760.228641      total sum
# 5          69504.000000    263.636113      Unweighted events, alpha=2.883622
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          124299.561279   598.031836      total sum
# 6          43201.000000    207.848503      Unweighted events, alpha=2.877238
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          46387.544312    364.454446      total sum
# 7          16200.000000    127.279221      Unweighted events, alpha=2.863429
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          19623.034546    236.346876      total sum
# 8          6893.000000     83.024093       Unweighted events, alpha=2.846806
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          11118.721008    177.171838      total sum
# 9          3938.000000     62.753486       Unweighted events, alpha=2.823444
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-9xevsA.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x843f240
#   Clients:
#     (0x856aee0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8440760,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8388d20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 237210
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x844e5c0
#   Clients:
#     (0x856aee0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x844d880,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x844f5b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 611348
# Error in <TList::Clear>: A list is accessing an object (0x859bd24) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x859bfcc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87addf0
#   Clients:
#     (0x87ac7d0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x87c2cc0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8388d20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 25591.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x87cd400
#   Clients:
#     (0x87ac7d0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x87e48b0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x844f5b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 67665.1
# Error in <TList::Clear>: A list is accessing an object (0x859c7c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x859ca6c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x843f240
#   Clients:
#     (0x856aee0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8440760,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8388d20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 281009
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x844e5c0
#   Clients:
#     (0x856aee0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x844d880,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x844f5b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 772128
# Error in <TList::Clear>: A list is accessing an object (0x859cd14) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x859cfbc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.24719  -0.00259778/+0.00262118  (68% CL)
# Done in 0.03 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2067.859375     71.975757       total sum
# 0          825.000000      28.722813       Unweighted events, alpha=2.506496
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3582.252045     96.126335       total sum
# 1          1389.000000     37.269290       Unweighted events, alpha=2.579015
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          7754.765747     142.574131      total sum
# 2          2958.000000     54.387499       Unweighted events, alpha=2.621625
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          17205.640350    213.393137      total sum
# 3          6501.000000     80.628779       Unweighted events, alpha=2.646614
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          37128.606323    314.705425      total sum
# 4          13919.000000    117.978812      Unweighted events, alpha=2.667477
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          51543.359741    371.427843      total sum
# 5          19257.000000    138.769593      Unweighted events, alpha=2.676604
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          34828.209534    304.675625      total sum
# 6          13067.000000    114.310979      Unweighted events, alpha=2.665356
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          16124.416687    207.126695      total sum
# 7          6060.000000     77.846002       Unweighted events, alpha=2.660795
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          7207.546875     137.603083      total sum
# 8          2744.000000     52.383203       Unweighted events, alpha=2.626657
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          3983.618690     102.425955      total sum
# 9          1513.000000     38.897301       Unweighted events, alpha=2.632927
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          6446.759674     133.666178      total sum
# 0          2326.000000     48.228622       Unweighted events, alpha=2.771608
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          9845.029785     166.563470      total sum
# 1          3494.000000     59.110067       Unweighted events, alpha=2.817696
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          17658.045898    224.409938      total sum
# 2          6192.000000     78.689262       Unweighted events, alpha=2.851752
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          36432.482422    323.304291      total sum
# 3          12699.000000    112.689840      Unweighted events, alpha=2.868925
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          92968.824219    517.787674      total sum
# 4          32238.000000    179.549436      Unweighted events, alpha=2.883827
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          157741.713867   674.557032      total sum
# 5          54683.000000    233.843965      Unweighted events, alpha=2.884657
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          97371.489868    529.377710      total sum
# 6          33832.000000    183.934771      Unweighted events, alpha=2.878088
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          36031.183838    321.587518      total sum
# 7          12553.000000    112.040171      Unweighted events, alpha=2.870325
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          15212.257965    208.542493      total sum
# 8          5321.000000     72.945185       Unweighted events, alpha=2.858910
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          8644.511108     156.839532      total sum
# 9          3038.000000     55.118055       Unweighted events, alpha=2.845461
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-AbWaBe.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ed0fe0
#   Clients:
#     (0x7ffcc80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7ed2500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7e1aab0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 181426
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ee0360
#   Clients:
#     (0x7ffcc80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7edf620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7ee1350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 478352
# Error in <TList::Clear>: A list is accessing an object (0x802dab4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x802dd5c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8240130
#   Clients:
#     (0x823eb10,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8255070,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7e1aab0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 19485.3
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x825f7b0
#   Clients:
#     (0x823eb10,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8276d20,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7ee1350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 52145.9
# Error in <TList::Clear>: A list is accessing an object (0x802e554) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x802e7fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ed0fe0
#   Clients:
#     (0x7ffcc80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7ed2500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7e1aab0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 215438
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ee0360
#   Clients:
#     (0x7ffcc80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7edf620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7ee1350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 603429
# Error in <TList::Clear>: A list is accessing an object (0x802eaa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x802ed4c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.24681  -0.0029433/+0.00296745  (68% CL)
# Done in 0.02 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          512.715973      36.382505       total sum
# 0          199.000000      14.106736       Unweighted events, alpha=2.576462
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          852.731472      47.282815       total sum
# 1          325.000000      18.027756       Unweighted events, alpha=2.623789
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1734.658150     67.083214       total sum
# 2          669.000000      25.865034       Unweighted events, alpha=2.592912
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4121.163582     105.019120      total sum
# 3          1540.000000     39.242834       Unweighted events, alpha=2.676080
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          8726.705154     153.047402      total sum
# 4          3251.000000     57.017541       Unweighted events, alpha=2.684314
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          12136.803314    180.749042      total sum
# 5          4509.000000     67.149088       Unweighted events, alpha=2.691684
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          8286.961868     149.141581      total sum
# 6          3087.000000     55.560778       Unweighted events, alpha=2.684471
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          3899.031158     101.931198      total sum
# 7          1463.000000     38.249183       Unweighted events, alpha=2.665093
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1705.823586     67.474738       total sum
# 8          639.000000      25.278449       Unweighted events, alpha=2.669520
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          874.582794      47.799316       total sum
# 9          335.000000      18.303005       Unweighted events, alpha=2.610695
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1436.439758     62.510681       total sum
# 0          528.000000      22.978251       Unweighted events, alpha=2.720530
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2273.946838     79.820893       total sum
# 1          812.000000      28.495614       Unweighted events, alpha=2.800427
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3840.590210     104.399269      total sum
# 2          1353.000000     36.783148       Unweighted events, alpha=2.838574
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          8105.126984     151.525517      total sum
# 3          2861.000000     53.488316       Unweighted events, alpha=2.832970
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          20191.579529    240.566392      total sum
# 4          7045.000000     83.934498       Unweighted events, alpha=2.866087
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          33158.580994    308.845257      total sum
# 5          11527.000000    107.363867      Unweighted events, alpha=2.876601
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          20781.759613    244.027308      total sum
# 6          7253.000000     85.164547       Unweighted events, alpha=2.865264
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          7989.324692     150.480864      total sum
# 7          2819.000000     53.094256       Unweighted events, alpha=2.834099
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          3377.704987     97.346961       total sum
# 8          1204.000000     34.698703       Unweighted events, alpha=2.805403
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1839.850708     71.005996       total sum
# 9          671.000000      25.903668       Unweighted events, alpha=2.741953
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-5TU5sm.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85adb00
#   Clients:
#     (0x86d97a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85af020,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x84f75e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 42851.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85bce80
#   Clients:
#     (0x86d97a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85bc140,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x85bde70,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 102995
# Error in <TList::Clear>: A list is accessing an object (0x870a5d4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x870a87c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x891d160
#   Clients:
#     (0x891bb40,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8931fa0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x84f75e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 4704.78
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x893c6e0
#   Clients:
#     (0x891bb40,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8953c50,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x85bde70,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 12040.1
# Error in <TList::Clear>: A list is accessing an object (0x870b074) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x870b31c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85adb00
#   Clients:
#     (0x86d97a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85af020,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x84f75e0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 50418.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x85bce80
#   Clients:
#     (0x86d97a0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x85bc140,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x85bde70,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 131483
# Error in <TList::Clear>: A list is accessing an object (0x870b5c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x870b86c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.25472  -0.00630243/+0.00638654  (68% CL)
# Done in 0.03 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          142.136807      18.283085       total sum
# 0          60.000000       7.745967        Unweighted events, alpha=2.368947
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          241.341055      25.071662       total sum
# 1          93.000000       9.643651        Unweighted events, alpha=2.595065
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          524.271881      37.161806       total sum
# 2          199.000000      14.106736       Unweighted events, alpha=2.634532
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1196.362473     56.751889       total sum
# 3          444.000000      21.071308       Unweighted events, alpha=2.694510
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2708.939903     85.583687       total sum
# 4          1002.000000     31.654384       Unweighted events, alpha=2.703533
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3667.494034     99.965037       total sum
# 5          1346.000000     36.687873       Unweighted events, alpha=2.724736
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2488.102055     81.836456       total sum
# 6          924.000000      30.397368       Unweighted events, alpha=2.692751
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1173.201405     55.723775       total sum
# 7          443.000000      21.047565       Unweighted events, alpha=2.648310
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          535.655027      37.682937       total sum
# 8          202.000000      14.212670       Unweighted events, alpha=2.651758
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          255.306246      26.370597       total sum
# 9          94.000000       9.695360        Unweighted events, alpha=2.716024
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          410.157856      33.337564       total sum
# 0          151.000000      12.288206       Unweighted events, alpha=2.716277
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          660.250843      42.249773       total sum
# 1          244.000000      15.620499       Unweighted events, alpha=2.705946
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1135.019157     56.299290       total sum
# 2          406.000000      20.149442       Unweighted events, alpha=2.795614
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2523.072372     84.952109       total sum
# 3          882.000000      29.698485       Unweighted events, alpha=2.860626
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          5568.532684     126.589041      total sum
# 4          1935.000000     43.988635       Unweighted events, alpha=2.877795
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          9523.134247     165.936751      total sum
# 5          3294.000000     57.393379       Unweighted events, alpha=2.891055
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          6146.539551     133.611341      total sum
# 6          2116.000000     46.000000       Unweighted events, alpha=2.904792
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2367.142479     82.243671       total sum
# 7          828.000000      28.774989       Unweighted events, alpha=2.858868
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1033.080498     53.790738       total sum
# 8          369.000000      19.209373       Unweighted events, alpha=2.799676
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          634.366516      41.825471       total sum
# 9          230.000000      15.165751       Unweighted events, alpha=2.758115
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-GMXbs8.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x991ee00
#   Clients:
#     (0x9a4aaa0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9920320,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x98688c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 12932.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x992e180
#   Clients:
#     (0x9a4aaa0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x992d440,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x992f170,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 30001.3
# Error in <TList::Clear>: A list is accessing an object (0x9a7b884) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a7bb2c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9c8deb0
#   Clients:
#     (0x9c8c890,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9ca2de0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x98688c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1394.09
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9cad520
#   Clients:
#     (0x9c8c890,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9cc4a30,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x992f170,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3464.07
# Error in <TList::Clear>: A list is accessing an object (0x9a7c324) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a7c5cc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x991ee00
#   Clients:
#     (0x9a4aaa0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9920320,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x98688c0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 15147.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x992e180
#   Clients:
#     (0x9a4aaa0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x992d440,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x992f170,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 37219.9
# Error in <TList::Clear>: A list is accessing an object (0x9a7c874) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a7cb1c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.22952  -0.0114741/+0.0116531  (68% CL)
# Done in 0.02 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          283.424637      20.546933       total sum
# 0          190.000000      13.784049       Unweighted events, alpha=1.491709
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          410.692322      26.718374       total sum
# 1          236.000000      15.362291       Unweighted events, alpha=1.740222
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          778.058899      40.275294       total sum
# 2          373.000000      19.313208       Unweighted events, alpha=2.085949
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1610.071747     60.628318       total sum
# 3          705.000000      26.551836       Unweighted events, alpha=2.283790
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3335.165070     89.744852       total sum
# 4          1381.000000     37.161808       Unweighted events, alpha=2.415036
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4758.475830     108.342581      total sum
# 5          1929.000000     43.920383       Unweighted events, alpha=2.466810
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2999.110794     85.025987       total sum
# 6          1244.000000     35.270384       Unweighted events, alpha=2.410861
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1479.761108     57.512985       total sum
# 7          662.000000      25.729361       Unweighted events, alpha=2.235289
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          702.305969      37.184271       total sum
# 8          357.000000      18.894444       Unweighted events, alpha=1.967244
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          466.861145      27.947616       total sum
# 9          279.000000      16.703293       Unweighted events, alpha=1.673337
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          869.052399      36.437310       total sum
# 0          569.000000      23.853721       Unweighted events, alpha=1.527333
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1163.263153     46.152414       total sum
# 1          635.000000      25.199206       Unweighted events, alpha=1.831910
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1926.477356     64.987695       total sum
# 2          879.000000      29.647934       Unweighted events, alpha=2.191669
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3451.097717     91.483732       total sum
# 3          1423.000000     37.722672       Unweighted events, alpha=2.425227
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          8318.015259     147.075583      total sum
# 4          3199.000000     56.559703       Unweighted events, alpha=2.600192
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          14047.761353    193.000135      total sum
# 5          5298.000000     72.787362       Unweighted events, alpha=2.651522
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          8731.917969     151.641138      total sum
# 6          3316.000000     57.584720       Unweighted events, alpha=2.633268
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          3495.517029     92.016957       total sum
# 7          1443.000000     37.986840       Unweighted events, alpha=2.422396
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1724.699860     60.099235       total sum
# 8          824.000000      28.705400       Unweighted events, alpha=2.093082
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1150.050659     45.288924       total sum
# 9          645.000000      25.396850       Unweighted events, alpha=1.783024
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-DCvIjW.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f9ded0
#   Clients:
#     (0x80c9b70,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f9f3f0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7ee7980,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 16823.9
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7fad250
#   Clients:
#     (0x80c9b70,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7fac510,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7fae240,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 44877.9
# Error in <TList::Clear>: A list is accessing an object (0x80fa924) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80fabcc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x830ce70
#   Clients:
#     (0x830b850,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8321d60,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7ee7980,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 2958.08
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x832c440
#   Clients:
#     (0x830b850,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8343a10,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7fae240,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 7960.63
# Error in <TList::Clear>: A list is accessing an object (0x80fb3c4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80fb66c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f9ded0
#   Clients:
#     (0x80c9b70,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7f9f3f0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7ee7980,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 20291.1
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7fad250
#   Clients:
#     (0x80c9b70,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7fac510,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7fae240,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 56739.7
# Error in <TList::Clear>: A list is accessing an object (0x80fb914) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x80fbbbc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.27858  -0.0101522/+0.0103005  (68% CL)
# Done in 0.02 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          124.456707      12.436398       total sum
# 0          100.000000      10.000000       Unweighted events, alpha=1.244567
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          178.007080      17.452161       total sum
# 1          104.000000      10.198039       Unweighted events, alpha=1.711607
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          285.942642      23.742565       total sum
# 2          145.000000      12.041595       Unweighted events, alpha=1.972018
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          525.405594      33.360036       total sum
# 3          248.000000      15.748016       Unweighted events, alpha=2.118571
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1192.201096     53.644002       total sum
# 4          494.000000      22.226111       Unweighted events, alpha=2.413363
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1566.053986     62.223273       total sum
# 5          633.000000      25.159491       Unweighted events, alpha=2.474019
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1106.548271     51.028838       total sum
# 6          470.000000      21.679483       Unweighted events, alpha=2.354358
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          532.866852      34.286892       total sum
# 7          242.000000      15.556349       Unweighted events, alpha=2.201929
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          284.438805      23.098510       total sum
# 8          152.000000      12.328828       Unweighted events, alpha=1.871308
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          156.128830      13.996775       total sum
# 9          124.000000      11.135529       Unweighted events, alpha=1.259103
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          346.172409      20.977867       total sum
# 0          272.000000      16.492423       Unweighted events, alpha=1.272693
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          433.221802      25.836405       total sum
# 1          281.000000      16.763055       Unweighted events, alpha=1.541715
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          627.435791      34.466583       total sum
# 2          331.000000      18.193405       Unweighted events, alpha=1.895576
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1252.337250     54.363558       total sum
# 3          531.000000      23.043437       Unweighted events, alpha=2.358451
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2545.908569     80.341080       total sum
# 4          1004.000000     31.685959       Unweighted events, alpha=2.535766
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4104.896423     103.670906      total sum
# 5          1568.000000     39.597980       Unweighted events, alpha=2.617919
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2542.518097     80.830444       total sum
# 6          989.000000      31.448370       Unweighted events, alpha=2.570797
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1062.008163     48.764229       total sum
# 7          474.000000      21.771541       Unweighted events, alpha=2.240524
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          587.168625      32.923520       total sum
# 8          318.000000      17.832555       Unweighted events, alpha=1.846442
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          451.641602      26.652113       total sum
# 9          287.000000      16.941074       Unweighted events, alpha=1.573664
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-zi53EN.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a831e0
#   Clients:
#     (0x8baee80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a84700,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x89cccb0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 5952.05
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a92560
#   Clients:
#     (0x8baee80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a91820,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8a93550,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 13953.3
# Error in <TList::Clear>: A list is accessing an object (0x8bdfcc4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8bdff6c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8df20f0
#   Clients:
#     (0x8df0ad0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8e06f00,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x89cccb0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1224
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8e11640
#   Clients:
#     (0x8df0ad0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8e28b50,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8a93550,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3315.75
# Error in <TList::Clear>: A list is accessing an object (0x8be0764) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8be0a0c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a831e0
#   Clients:
#     (0x8baee80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a84700,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x89cccb0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 7495.23
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a92560
#   Clients:
#     (0x8baee80,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8a91820,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8a93550,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 19092.6
# Error in <TList::Clear>: A list is accessing an object (0x8be0cb4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8be0f5c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.39884  -0.0199895/+0.0204434  (68% CL)
# Done in 0.02 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          92.247054       4.496084        total sum
# 0          421.000000      20.518285       Unweighted events, alpha=0.219114
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          130.138531      10.368890       total sum
# 1          158.000000      12.569805       Unweighted events, alpha=0.823662
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          165.300819      13.679410       total sum
# 2          146.000000      12.083046       Unweighted events, alpha=1.132197
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          262.482788      20.152192       total sum
# 3          170.000000      13.038405       Unweighted events, alpha=1.544016
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          476.929802      29.787055       total sum
# 4          256.000000      16.000000       Unweighted events, alpha=1.863007
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          614.575745      34.975063       total sum
# 5          309.000000      17.578396       Unweighted events, alpha=1.988918
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          465.499916      29.157900       total sum
# 6          255.000000      15.968719       Unweighted events, alpha=1.825490
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          261.894714      19.583236       total sum
# 7          179.000000      13.379088       Unweighted events, alpha=1.463099
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          174.306442      13.154356       total sum
# 8          176.000000      13.266499       Unweighted events, alpha=0.990378
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          128.729364      6.982935        total sum
# 9          340.000000      18.439089       Unweighted events, alpha=0.378616
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          318.009071      13.565313       total sum
# 0          550.000000      23.452079       Unweighted events, alpha=0.578198
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          355.197067      16.435401       total sum
# 1          467.000000      21.610183       Unweighted events, alpha=0.760593
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          456.022141      22.816325       total sum
# 2          399.000000      19.974984       Unweighted events, alpha=1.142913
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          629.192566      30.395383       total sum
# 3          429.000000      20.712315       Unweighted events, alpha=1.466649
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1215.497681     49.108177       total sum
# 4          613.000000      24.758837       Unweighted events, alpha=1.982867
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1740.929504     61.418653       total sum
# 5          803.000000      28.337255       Unweighted events, alpha=2.168032
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1137.436584     46.964480       total sum
# 6          587.000000      24.228083       Unweighted events, alpha=1.937711
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          622.272644      29.686563       total sum
# 7          439.000000      20.952327       Unweighted events, alpha=1.417478
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          414.576035      18.996897       total sum
# 8          476.000000      21.817424       Unweighted events, alpha=0.870958
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          347.299767      14.282988       total sum
# 9          591.000000      24.310492       Unweighted events, alpha=0.587648
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-bjVxHo.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94a75b0
#   Clients:
#     (0x95d3250,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x94a8ad0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x93f1080,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2772.11
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94b6930
#   Clients:
#     (0x95d3250,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x94b5bf0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x94b7920,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7236.43
# Error in <TList::Clear>: A list is accessing an object (0x9604014) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x96042bc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9816080
#   Clients:
#     (0x9814a60,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x982af30,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x93f1080,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1127.89
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9835670
#   Clients:
#     (0x9814a60,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x984cc40,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x94b7920,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 3061.41
# Error in <TList::Clear>: A list is accessing an object (0x9604ab4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9604d5c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94a75b0
#   Clients:
#     (0x95d3250,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x94a8ad0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x93f1080,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2997.23
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x94b6930
#   Clients:
#     (0x95d3250,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x94b5bf0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x94b7920,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7983.67
# Error in <TList::Clear>: A list is accessing an object (0x9605004) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x96052ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.15824  -0.028072/+0.0290945  (68% CL)
# Done in 0.02 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          56.006095       3.574139        total sum
# 0          246.000000      15.684387       Unweighted events, alpha=0.227667
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          74.244944       7.095590        total sum
# 1          109.000000      10.440307       Unweighted events, alpha=0.681146
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          91.521290       8.896879        total sum
# 2          106.000000      10.295630       Unweighted events, alpha=0.863408
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          152.045471      14.822673       total sum
# 3          105.000000      10.246951       Unweighted events, alpha=1.448052
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          264.344357      22.105384       total sum
# 4          143.000000      11.958261       Unweighted events, alpha=1.848562
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          402.218300      29.007364       total sum
# 5          192.000000      13.856406       Unweighted events, alpha=2.094887
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          272.591202      22.737830       total sum
# 6          144.000000      12.000000       Unweighted events, alpha=1.892994
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          139.743752      14.052580       total sum
# 7          99.000000       9.949874        Unweighted events, alpha=1.411553
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          105.876625      10.364993       total sum
# 8          104.000000      10.198039       Unweighted events, alpha=1.018044
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          99.158386       9.540128        total sum
# 9          108.000000      10.392305       Unweighted events, alpha=0.918133
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          188.629181      10.646609       total sum
# 0          314.000000      17.720045       Unweighted events, alpha=0.600730
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          197.011917      11.782577       total sum
# 1          280.000000      16.733201       Unweighted events, alpha=0.703614
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          221.232330      13.234849       total sum
# 2          279.000000      16.703293       Unweighted events, alpha=0.792947
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          376.864075      23.333126       total sum
# 3          261.000000      16.155494       Unweighted events, alpha=1.443924
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          561.416901      31.931961       total sum
# 4          309.000000      17.578396       Unweighted events, alpha=1.816883
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          873.907928      42.461934       total sum
# 5          424.000000      20.591260       Unweighted events, alpha=2.061104
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          585.077118      33.249390       total sum
# 6          310.000000      17.606817       Unweighted events, alpha=1.887346
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          293.986504      18.394295       total sum
# 7          255.000000      15.968719       Unweighted events, alpha=1.152888
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          202.125095      10.747542       total sum
# 8          354.000000      18.814888       Unweighted events, alpha=0.570975
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          177.152931      8.126268        total sum
# 9          475.000000      21.794495       Unweighted events, alpha=0.372954
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-0rabL0.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ba2320
#   Clients:
#     (0x7ccdfc0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7ba3840,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7aebdf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1657.75
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7bb16a0
#   Clients:
#     (0x7ccdfc0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7bb0960,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7bb2690,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 3677.4
# Error in <TList::Clear>: A list is accessing an object (0x7cfed54) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7cfeffc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f10ec0
#   Clients:
#     (0x7f0f8a0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x7f25db0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7aebdf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 661.545
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7f304f0
#   Clients:
#     (0x7f0f8a0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x7f479a0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7bb2690,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 1773.71
# Error in <TList::Clear>: A list is accessing an object (0x7cff7f4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7cffa9c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7ba2320
#   Clients:
#     (0x7ccdfc0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7ba3840,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7aebdf0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1730.56
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7bb16a0
#   Clients:
#     (0x7ccdfc0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7bb0960,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7bb2690,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 4320.77
# Error in <TList::Clear>: A list is accessing an object (0x7cffd44) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7cfffec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.2515  -0.0434771/+0.0458754  (68% CL)
# Done in 0.03 min (cpu), 0.03 min (real)

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          99.506672       9.908426        total sum
# 0          101.000000      10.049876       Unweighted events, alpha=0.985215
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          135.606415      13.249682       total sum
# 1          105.000000      10.246951       Unweighted events, alpha=1.291490
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          158.923111      14.916413       total sum
# 2          114.000000      10.677078       Unweighted events, alpha=1.394062
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          346.145020      26.686518       total sum
# 3          168.000000      12.961481       Unweighted events, alpha=2.060387
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          602.493393      35.818752       total sum
# 4          283.000000      16.822604       Unweighted events, alpha=2.128952
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          891.125610      45.620769       total sum
# 5          382.000000      19.544820       Unweighted events, alpha=2.332790
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          585.419182      35.483648       total sum
# 6          272.000000      16.492423       Unweighted events, alpha=2.152276
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          259.354126      21.106273       total sum
# 7          151.000000      12.288206       Unweighted events, alpha=1.717577
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          163.898178      14.690266       total sum
# 8          124.000000      11.135529       Unweighted events, alpha=1.321760
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          113.120598      9.639890        total sum
# 9          138.000000      11.747340       Unweighted events, alpha=0.819714
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          248.681068      14.597350       total sum
# 0          290.000000      17.029386       Unweighted events, alpha=0.857521
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          324.683441      19.653922       total sum
# 1          273.000000      16.522712       Unweighted events, alpha=1.189317
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          428.206879      25.884298       total sum
# 2          274.000000      16.552945       Unweighted events, alpha=1.562799
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          676.718903      36.453484       total sum
# 3          345.000000      18.574176       Unweighted events, alpha=1.961504
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1368.637024     55.539484       total sum
# 4          607.000000      24.637370       Unweighted events, alpha=2.254756
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2134.478149     72.032464       total sum
# 5          878.000000      29.631065       Unweighted events, alpha=2.431069
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1325.576462     54.422338       total sum
# 6          593.000000      24.351591       Unweighted events, alpha=2.235373
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          640.589722      34.722826       total sum
# 7          340.000000      18.439089       Unweighted events, alpha=1.884087
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          432.726059      25.942804       total sum
# 8          278.000000      16.673332       Unweighted events, alpha=1.556569
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          309.470535      18.788188       total sum
# 9          271.000000      16.462078       Unweighted events, alpha=1.141958
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-duXmrq.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x98e73a0
#   Clients:
#     (0x9a13060,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x98e88c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x9830e70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 3355.59
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x98f6740
#   Clients:
#     (0x9a13060,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x98f5a00,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x98f7730,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7889.77
# Error in <TList::Clear>: A list is accessing an object (0x9a43df4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a4409c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9c56140
#   Clients:
#     (0x9c54b20,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9c6af20,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x9830e70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1031.08
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9c755a0
#   Clients:
#     (0x9c54b20,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9c8cb10,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x98f7730,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2597.32
# Error in <TList::Clear>: A list is accessing an object (0x9a44894) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a44b3c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x98e73a0
#   Clients:
#     (0x9a13060,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x98e88c0,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x9830e70,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 4241.26
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x98f6740
#   Clients:
#     (0x9a13060,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x98f5a00,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x98f7730,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 10527.2
# Error in <TList::Clear>: A list is accessing an object (0x9a44de4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9a4508c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.43331  -0.0293156/+0.0303045  (68% CL)
# Done in 0.02 min (cpu), 0.02 min (real)
