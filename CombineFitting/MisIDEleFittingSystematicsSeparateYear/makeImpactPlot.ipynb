# %%
# %%capture 
# # mu toy
# !text2workspace.py  datacard_CR123_mu_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125 -t -1 --expectSignal 0.1 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125 -t -1 --expectSignal 0.1 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125 -t -1 --expectSignal 0.1 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)	
# !combine -M FitDiagnostics -n MYmuTEST -d datacard_CR123_mu_2016.root  -t -1 --expectSignal 2 --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYmuTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_mu_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_mu_2016.txt

# %%
# %%capture 
# # mu data
# !text2workspace.py  datacard_CR123_mu_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_mu_2016.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)	
# !combine -M FitDiagnostics -n MYmuTEST -d datacard_CR123_mu_2016.root  -t -1 --expectSignal 2 --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYmuTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_mu_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_mu_2016.txt

# %%
###### ele only channel

# %%
# %%capture 
# # toy ele
# !text2workspace.py  datacard_CR123_ele_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125 -t -1 --expectSignal 2 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125 -t -1 --expectSignal 2 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125 -t -1 --expectSignal 2 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)	
# !combine -M FitDiagnostics -n MYeleTEST -d datacard_CR123_ele_2016.root  -t -1 --expectSignal 2 --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYeleTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_ele_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_ele_2016.txt

# %%
# %%capture 
# # data, ele
# !text2workspace.py  datacard_CR123_ele_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_ele_2016.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)	 
# !combine -M FitDiagnostics -n MYeleTEST -d datacard_CR123_ele_2016.root --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYeleTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_ele_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_ele_2016.txt

# %%
############## old both channel
# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --expectSignal 2 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --expectSignal 2 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --expectSignal 2 -o impacts_toy_2016.json
# !plotImpacts.py -t rename.json -i impacts_toy_2016.json -o impacts_toy_2016

# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125  -o impacts_data_2016.json
# !plotImpacts.py -t rename.json -i impacts_data_2016.json -o impacts_data_2016

# !text2workspace.py  datacard_CR123_2017.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125 -t -1 --expectSignal 2 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125 -t -1 --expectSignal 2 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125 -t -1 --expectSignal 2 -o impacts_toy_2017.json
# !plotImpacts.py -t rename.json -i impacts_toy_2017.json -o impacts_toy_2017

# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2017.root -m 125  -o impacts_data_2017.json
# !plotImpacts.py -t rename.json -i impacts_data_2017.json -o impacts_data_2017

# !text2workspace.py  datacard_CR123_2018.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125 -t -1 --expectSignal 2 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125 -t -1 --expectSignal 2 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125 -t -1 --expectSignal 2 -o impacts_toy_2018.json
# !plotImpacts.py -t rename.json -i impacts_toy_2018.json -o impacts_toy_2018

# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2018.root -m 125  -o impacts_data_2018.json
# !plotImpacts.py -t rename.json -i impacts_data_2018.json -o impacts_data_2018
# Out:
# Channel ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binele
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          14421.373962    190.786856      total sum
# 0          5714.000000     75.591005       Unweighted events, alpha=2.523867
#   => Total parameter prop_binele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1319.635574     57.518234       total sum
# 1          526.000000      22.934690       Unweighted events, alpha=2.508813
#   => Total parameter prop_binele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1825.533157     81.522746       total sum
# 2          501.000000      22.383029       Unweighted events, alpha=3.643779
#   => Total parameter prop_binele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ...

# %%
# %%capture 
# toy both channel, see updated code in "makeImpactPlot.sh"
# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --redefineSignalPOIs WGammaBkgPhotonSF --setParameters WGammaBkgPhotonSF=1 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --redefineSignalPOIs WGammaBkgPhotonSF --setParameters WGammaBkgPhotonSF=1 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 -t -1 --redefineSignalPOIs WGammaBkgPhotonSF --setParameters WGammaBkgPhotonSF=1 -o impacts_toy_2016_wg.json
# !plotImpacts.py -t rename.json -i impacts_toy_2016_wg.json -o impacts_toy_2016_wg
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	
# !combine -M FitDiagnostics -n MYTEST -d datacard_CR123_2016.root  -t -1 --expectSignal 2 --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_2016.txt
# Out:
# Channel ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binele
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          14421.373962    190.786856      total sum
# 0          5714.000000     75.591005       Unweighted events, alpha=2.523867
#   => Total parameter prop_binele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1319.635574     57.518234       total sum
# 1          526.000000      22.934690       Unweighted events, alpha=2.508813
#   => Total parameter prop_binele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1825.533157     81.522746       total sum
# 2          501.000000      22.383029       Unweighted events, alpha=3.643779
#   => Total parameter prop_binele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ...

# %%
# %%capture 
# data, both channel
# !text2workspace.py  datacard_CR123_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 --redefineSignalPOIs WGammaBkgPhotonSF --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 --redefineSignalPOIs WGammaBkgPhotonSF --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_2016.root -m 125 --redefineSignalPOIs WGammaBkgPhotonSF -o impacts_data_2016_wg.json
# !plotImpacts.py -t rename.json -i impacts_data_2016_wg.json -o impacts_data_2016_wg
from datetime import datetime
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	 
# !combine -M FitDiagnostics -n MYTEST -d datacard_CR123_2016.root --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_2016.txt
# Out:
# Channel ele will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binele
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          14421.373962    190.786856      total sum
# 0          5714.000000     75.591005       Unweighted events, alpha=2.523867
#   => Total parameter prop_binele_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1319.635574     57.518234       total sum
# 1          526.000000      22.934690       Unweighted events, alpha=2.508813
#   => Total parameter prop_binele_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1825.533157     81.522746       total sum
# 2          501.000000      22.383029       Unweighted events, alpha=3.643779
#   => Total parameter prop_binele_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ...

# %%
# !plotImpacts.py --help
########### new one, both channel
# Out:
# usage: plotImpacts.py [-h] [--input INPUT] [--output OUTPUT]
#                       [--translate TRANSLATE] [--units UNITS]
#                       [--per-page PER_PAGE] [--max-pages MAX_PAGES]
#                       [--height HEIGHT] [--left-margin LEFT_MARGIN]
#                       [--label-size LABEL_SIZE] [--cms-label CMS_LABEL]
#                       [--transparent] [--checkboxes] [--blind]
#                       [--color-groups COLOR_GROUPS] [--pullDef PULLDEF]
#                       [--POI POI]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --input INPUT, -i INPUT
#                         input json file
#   --output OUTPUT, -o OUTPUT
#                         name of the output file to create
#   --translate TRANSLATE, -t TRANSLATE
#                         JSON file for remapping of parameter names
#   --units UNITS         Add units to the best-fit parameter value
#   --per-page PER_PAGE   Number of parameters to show per page
# ...

# %%
# %%capture
# # toy new 
# !text2workspace.py  datacard_CR123_new_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125 -t -1 --expectSignal 2 --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125 -t -1 --expectSignal 2 --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125 -t -1 --expectSignal 2 -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)
# !combine -M FitDiagnostics -n MYnewTEST -d datacard_CR123_new_2016.root  -t -1 --expectSignal 2 --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYnewTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_new_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_new_2016.txt

# %%
# %%capture 
# # data, new
# !text2workspace.py  datacard_CR123_new_2016.txt # saveworkspace while doing fitting and use the rootfile here to make impact plot --redefineSignalPOIs r,ZGammaBkgPhotonSF,WGammaBkgPhotonSF
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125  --doInitialFit --robustFit 1 
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125  --robustFit 1 --doFits 
# !combineTool.py -M Impacts -d datacard_CR123_new_2016.root -m 125  -o impacts.json
# !plotImpacts.py -i impacts.json -o impacts
# from datetime import datetime
# now = datetime.now() 
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)	 
# !combine -M FitDiagnostics -n MYnewTEST -d datacard_CR123_new_2016.root --saveNormalizations --saveWithUncertainties --plots 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsMYnewTEST.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/diffNuisances.py -a -A fitDiagnosticsCR123_new_2016.root -g plots.root 
# !python /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/HiggsAnalysis/CombinedLimit/test/systematicsAnalyzer.py -a datacard_CR123_new_2016.txt

# %%
# !combine --help
