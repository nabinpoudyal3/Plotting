# %%
import ROOT
import os

# %%
# !combine -M FitDiagnostics -n 1_100 datacard_all.txt --expectSignal=1 -t 1000 -s -1 --redefineSignalPOIs r,nonPromptSF
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> Used OpenSSL to get a really random seed 1070069162
# Channel ch1_M3 will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binch1_M3
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          21.764353       4.288543        total sum
# 0          26.000000       5.099020        Unweighted events, alpha=0.837091
#   => Total parameter prop_binch1_M3_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          85.048232       7.213462        total sum
# 1          139.000000      11.789826       Unweighted events, alpha=0.611858
#   => Total parameter prop_binch1_M3_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          73.489372       7.391661        total sum
# ...

# %%
# !ls
# Out:
# ChIso_CMS_th1x_fit_b.png
# ChIso_CMS_th1x_fit_s.png
# ChIso_CMS_th1x_prefit.png
# M3_CMS_th1x_fit_b.png
# M3_CMS_th1x_fit_s.png
# M3_CMS_th1x_prefit.png
# ch1_ChIso_CMS_th1x_fit_b.png
# ch1_ChIso_CMS_th1x_fit_s.png
# ch1_ChIso_CMS_th1x_prefit.png
# ch1_M3_CMS_th1x_fit_b.png
# ch1_M3_CMS_th1x_fit_s.png
# ch1_M3_CMS_th1x_prefit.png
# ch2_ChIso_CMS_th1x_fit_b.png
# ch2_ChIso_CMS_th1x_fit_s.png
# ch2_ChIso_CMS_th1x_prefit.png
# ch2_M3_CMS_th1x_fit_b.png
# ch2_M3_CMS_th1x_fit_s.png
# ch2_M3_CMS_th1x_prefit.png
# combine_logger.out
# covariance_fit_b.png
# covariance_fit_s.png
# datacard_CR123_wildcard.txt
# datacard_M3.txt
# datacard_SR.txt
# datacard_SR_ele.txt
# datacard_all.txt
# datacard_both.txt
# elJets_CMS_th1x_fit_s.png
# elJets_CMS_th1x_prefit.png
# fitDiagnosticsSR.root
# fitDiagnosticsSR_ele.root
# fitDiagnosticsboth.root
# higgsCombineSR.FitDiagnostics.mH120.root
# higgsCombineSR_ele.FitDiagnostics.mH120.root
# higgsCombineboth.FitDiagnostics.mH120.123456.root
# ...
