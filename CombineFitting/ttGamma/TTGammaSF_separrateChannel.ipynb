# %%
import ROOT
# !pwd
# Out:
# Welcome to JupyROOT 6.12/07
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/Plotting/CombineFitting/ttGamma

# %%
# !ls -lrt higgsCombineel_2016.MultiDimFit.mH120.314159.root
print "--------------------------------------------------------------------------------------------"
ROOT.gStyle.SetOptFit(1111)
canvas = ROOT.TCanvas()
myfile = ROOT.TFile("higgsCombineel_2016.MultiDimFit.mH120.314159.root","read")
mytree=myfile.limit
mytree.Draw("r>>hist2")
# mytree.Draw("nonPromptSF>>hist2")
hist2 = ROOT.gDirectory.Get('hist2')
hist2.Fit("gaus")
canvas.Draw("colz")
# Out:
# -rw-r--r-- 1 npoudyal us_cms 21453 Apr 29 21:26 higgsCombineel_2016.MultiDimFit.mH120.314159.root
# --------------------------------------------------------------------------------------------
#  FCN=59.0254 FROM MIGRAD    STATUS=CONVERGED      61 CALLS          62 TOTAL
#                      EDM=1.48846e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.87631e+01   1.18637e+00   3.54766e-03   7.51165e-05
#    2  Mean         9.94932e-01   2.26474e-03   8.55999e-06   7.56690e-01
#    3  Sigma        6.71555e-02   1.81220e-03   2.66609e-05  -2.40310e-02

# %%
ROOT.gStyle.SetOptFit(1111)
canvas = ROOT.TCanvas()
myfile = ROOT.TFile("higgsCombineel_2016.MultiDimFit.mH120.314159.root","read")
mytree=myfile.limit
# mytree.Draw("r>>hist2")
mytree.Draw("nonPromptSF>>hist2")
hist2 = ROOT.gDirectory.Get('hist2')
hist2.Fit("gaus")
canvas.Draw("colz")
# Out:
#  FCN=77.478 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=8.97755e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.16010e+01   1.31599e+00   4.50014e-03  -1.07048e-05
#    2  Mean         9.99819e-01   5.33678e-04   2.30062e-06  -1.43437e-01
#    3  Sigma        1.58978e-02   4.18656e-04   2.86515e-05  -1.48046e-02

# %%
# canvas = ROOT.TCanvas()
# myfile = ROOT.TFile("higgsCombineel_M3_2016_test.MultiDimFit.mH120.1.root","read")
# mytree=myfile.limit
# mytree.Draw("nonPromptSF>>hist2")
# hist2 = ROOT.gDirectory.Get('hist2')
# print hist2.GetMean()
# canvas.Draw()

# %%
# canvas = ROOT.TCanvas()
# myfile = ROOT.TFile("higgsCombineel_2016.MultiDimFit.mH120.1.root","read")
# mytree=myfile.limit
# mytree.Draw("r>>hist1")
# hist1 = ROOT.gDirectory.Get('hist1')
# print hist1.GetMean()
# canvas.Draw()

# %%
# canvas = ROOT.TCanvas()
# myfile = ROOT.TFile("higgsCombineel_2016.MultiDimFit.mH120.1.root","read")
# mytree=myfile.limit
# mytree.Draw("nonPromptSF>>hist2")
# hist2 = ROOT.gDirectory.Get('hist2')
# print hist2.GetMean()
# canvas.Draw()

# %%
# canvas = ROOT.TCanvas()
# myfile = ROOT.TFile("higgsCombinemu_2016.MultiDimFit.mH120.1.root","read")
# mytree=myfile.limit
# mytree.Draw("r>>hist1")
# hist1 = ROOT.gDirectory.Get('hist1')
# print hist1.GetMean()
# canvas.Draw()

# %%
# canvas = ROOT.TCanvas()
# myfile = ROOT.TFile("higgsCombinemu_2016.MultiDimFit.mH120.1.root","read")
# mytree=myfile.limit
# mytree.Draw("nonPromptSF>>hist2")
# hist2 = ROOT.gDirectory.Get('hist2')
# print hist2.GetMean()
# canvas.Draw()

# %%
#########################################
#########################################
#########################################

# %%
# #########################
# import numpy
# import array

# ListOfFiles = [
#                "higgsCombineel_M3_2016_0.4.MultiDimFit.mH120.40.root",
#                "higgsCombineel_M3_2016_0.6.MultiDimFit.mH120.60.root",
#                "higgsCombineel_M3_2016_0.8.MultiDimFit.mH120.80.root",
#                "higgsCombineel_M3_2016_1.0.MultiDimFit.mH120.100.root",
#                "higgsCombineel_M3_2016_1.2.MultiDimFit.mH120.120.root",
#                "higgsCombineel_M3_2016_1.4.MultiDimFit.mH120.140.root",
#                "higgsCombineel_M3_2016_1.6.MultiDimFit.mH120.160.root",
#                "higgsCombineel_M3_2016_1.8.MultiDimFit.mH120.180.root",
#                "higgsCombineel_M3_2016_2.0.MultiDimFit.mH120.200.root",                                                                                          
#                "higgsCombineel_M3_2016_2.2.MultiDimFit.mH120.220.root",
#                "higgsCombineel_M3_2016_2.4.MultiDimFit.mH120.240.root",
#                "higgsCombineel_M3_2016_2.6.MultiDimFit.mH120.260.root",                                            
#               ]
              

# c1 = ROOT.TCanvas( 'c1', 'Toy Data vs expected signal strength', 800,800 )
# c1.SetGrid()

# xData = list(numpy.arange(0.4,2.8,0.2))
# yData = []
# n = len(xData)
# errMinusData = []
# errPlusData = []
# zerosData = []
# for ifile in ListOfFiles:
# 	zerosData.append(0)
# 	myfile = ROOT.TFile(ifile,"read")
# 	mytree=myfile.limit
# 	mytree.Draw("r>>hist1")
# 	hist1 = ROOT.gDirectory.Get('hist1')
# 	yData.append(hist1.GetMean())
# 	errMinusData.append(hist1.GetRMS())
# 	errPlusData.append(hist1.GetRMS())

# x = array.array( 'f', xData )
# y = array.array( 'f', yData )
# errMinus = array.array( 'f', errMinusData )
# errPlus  = array.array( 'f', errPlusData )
# zeros = array.array('f',zerosData)
# oneLine = ROOT.TF1("oneline","x",0,3)

# gr = ROOT.TGraphAsymmErrors( n, x, y, zeros,zeros,errMinus, errPlus)
# gr.SetTitle('Toy fitting for ttgamma SF ')
# gr.GetXaxis().SetTitle("Expected ttgamma SF");
# gr.GetYaxis().SetTitle("Toy Data ttgamma SF");
# gr.SetMarkerColor(2)
# gr.SetMarkerStyle(7)
# gr.GetXaxis().SetRangeUser(0,3)
# gr.GetYaxis().SetRangeUser(0,3)
# # gr.SetMarkerSize(3)
# gr.Draw('AP')
# oneLine.Draw('same')

# c1.Draw()

# %%
# #########################
# import numpy
# import array

# ListOfFiles = [
#                "higgsCombineel_Ch_2016_0.4.MultiDimFit.mH120.40.root",
#                "higgsCombineel_Ch_2016_0.6.MultiDimFit.mH120.60.root",
#                "higgsCombineel_Ch_2016_0.8.MultiDimFit.mH120.80.root",
#                "higgsCombineel_Ch_2016_1.0.MultiDimFit.mH120.100.root",
#                "higgsCombineel_Ch_2016_1.2.MultiDimFit.mH120.120.root",
#                "higgsCombineel_Ch_2016_1.4.MultiDimFit.mH120.140.root",
#                "higgsCombineel_Ch_2016_1.6.MultiDimFit.mH120.160.root",
#                "higgsCombineel_Ch_2016_1.8.MultiDimFit.mH120.180.root",
#                "higgsCombineel_Ch_2016_2.0.MultiDimFit.mH120.200.root",                                                                                          
#                "higgsCombineel_Ch_2016_2.2.MultiDimFit.mH120.220.root",
#                "higgsCombineel_Ch_2016_2.4.MultiDimFit.mH120.240.root",
#                "higgsCombineel_Ch_2016_2.6.MultiDimFit.mH120.260.root",                                            
#               ]
              

# c1 = ROOT.TCanvas( 'c1', 'Toy Data vs expected signal strength', 800,800 )
# c1.SetGrid()

# xData = list(numpy.arange(0.4,2.8,0.2))
# yData = []
# n = len(xData)
# errMinusData = []
# errPlusData = []
# zerosData = []
# for ifile in ListOfFiles:
# 	zerosData.append(0)
# 	myfile = ROOT.TFile(ifile,"read")
# 	mytree=myfile.limit
# 	mytree.Draw("r>>hist1")
# 	hist1 = ROOT.gDirectory.Get('hist1')
# 	yData.append(hist1.GetMean())
# 	errMinusData.append(hist1.GetRMS())
# 	errPlusData.append(hist1.GetRMS())

# x = array.array( 'f', xData )
# y = array.array( 'f', yData )
# errMinus = array.array( 'f', errMinusData )
# errPlus  = array.array( 'f', errPlusData )
# zeros = array.array('f',zerosData)
# oneLine = ROOT.TF1("oneline","x",0,3)

# gr = ROOT.TGraphAsymmErrors( n, x, y, zeros,zeros,errMinus, errPlus)
# gr.SetTitle('Toy fitting for ttgamma SF ')
# gr.GetXaxis().SetTitle("Expected ttgamma SF");
# gr.GetYaxis().SetTitle("Toy Data ttgamma SF");
# gr.SetMarkerColor(2)
# gr.SetMarkerStyle(7)
# gr.GetXaxis().SetRangeUser(0,3)
# gr.GetYaxis().SetRangeUser(0,3)
# # gr.SetMarkerSize(3)
# gr.Draw('AP')
# oneLine.Draw('same')

# c1.Draw()

# %%
#########################

# %%
# #########################
# import numpy
# import array

# ListOfFiles = [
#                "higgsCombineel_M3_2016_NP_0.4.MultiDimFit.mH120.40.root",
#                "higgsCombineel_M3_2016_NP_0.6.MultiDimFit.mH120.60.root",
#                "higgsCombineel_M3_2016_NP_0.8.MultiDimFit.mH120.80.root",
#                "higgsCombineel_M3_2016_NP_1.0.MultiDimFit.mH120.100.root",
#                "higgsCombineel_M3_2016_NP_1.2.MultiDimFit.mH120.120.root",
#                "higgsCombineel_M3_2016_NP_1.4.MultiDimFit.mH120.140.root",
#                "higgsCombineel_M3_2016_NP_1.6.MultiDimFit.mH120.160.root",
#                "higgsCombineel_M3_2016_NP_1.8.MultiDimFit.mH120.180.root",
#                "higgsCombineel_M3_2016_NP_2.0.MultiDimFit.mH120.200.root",                                                                                          
#                "higgsCombineel_M3_2016_NP_2.2.MultiDimFit.mH120.220.root",
#                "higgsCombineel_M3_2016_NP_2.4.MultiDimFit.mH120.240.root",
#                "higgsCombineel_M3_2016_NP_2.6.MultiDimFit.mH120.260.root",                                            
#               ]
              

# c1 = ROOT.TCanvas( 'c1', 'Toy Data vs expected signal strength', 800,800 )
# c1.SetGrid()

# xData = list(numpy.arange(0.4,2.8,0.2))
# yData = []
# n = len(xData)
# errMinusData = []
# errPlusData = []
# zerosData = []
# for ifile in ListOfFiles:
# 	zerosData.append(0)
# 	myfile = ROOT.TFile(ifile,"read")
# 	mytree=myfile.limit
# 	mytree.Draw("nonPromptSF>>hist1")
# 	hist1 = ROOT.gDirectory.Get('hist1')
# 	yData.append(hist1.GetMean())
# 	errMinusData.append(hist1.GetRMS())
# 	errPlusData.append(hist1.GetRMS())

# x = array.array( 'f', xData )
# y = array.array( 'f', yData )
# errMinus = array.array( 'f', errMinusData )
# errPlus  = array.array( 'f', errPlusData )
# zeros = array.array('f',zerosData)
# oneLine = ROOT.TF1("oneline","x",0,3)

# gr = ROOT.TGraphAsymmErrors( n, x, y, zeros,zeros,errMinus, errPlus)
# gr.SetTitle('Toy fitting for non prompt SF ')
# gr.GetXaxis().SetTitle("Expected  non prompt SF");
# gr.GetYaxis().SetTitle("Toy Data  non prompt SF");
# gr.SetMarkerColor(2)
# gr.SetMarkerStyle(7)
# gr.GetXaxis().SetRangeUser(0,3)
# gr.GetYaxis().SetRangeUser(0,3)
# # gr.SetMarkerSize(3)
# gr.Draw('AP')
# oneLine.Draw('same')

# c1.Draw()

# %%
# #########################
# import numpy
# import array

# ListOfFiles = [
#                "higgsCombineel_Ch_2016_NP_0.4.MultiDimFit.mH120.40.root",
#                "higgsCombineel_Ch_2016_NP_0.6.MultiDimFit.mH120.60.root",
#                "higgsCombineel_Ch_2016_NP_0.8.MultiDimFit.mH120.80.root",
#                "higgsCombineel_Ch_2016_NP_1.0.MultiDimFit.mH120.100.root",
#                "higgsCombineel_Ch_2016_NP_1.2.MultiDimFit.mH120.120.root",
#                "higgsCombineel_Ch_2016_NP_1.4.MultiDimFit.mH120.140.root",
#                "higgsCombineel_Ch_2016_NP_1.6.MultiDimFit.mH120.160.root",
#                "higgsCombineel_Ch_2016_NP_1.8.MultiDimFit.mH120.180.root",
#                "higgsCombineel_Ch_2016_NP_2.0.MultiDimFit.mH120.200.root",                                                                                          
#                "higgsCombineel_Ch_2016_NP_2.2.MultiDimFit.mH120.220.root",
#                "higgsCombineel_Ch_2016_NP_2.4.MultiDimFit.mH120.240.root",
#                "higgsCombineel_Ch_2016_NP_2.6.MultiDimFit.mH120.260.root",                                            
#               ]
              

# c1 = ROOT.TCanvas( 'c1', 'Toy Data vs expected signal strength', 800,800 )
# c1.SetGrid()

# xData = list(numpy.arange(0.4,2.8,0.2))
# yData = []
# n = len(xData)
# errMinusData = []
# errPlusData = []
# zerosData = []
# for ifile in ListOfFiles:
# 	zerosData.append(0)
# 	myfile = ROOT.TFile(ifile,"read")
# 	mytree=myfile.limit
# 	mytree.Draw("nonPromptSF>>hist1")
# 	hist1 = ROOT.gDirectory.Get('hist1')
# 	yData.append(hist1.GetMean())
# 	errMinusData.append(hist1.GetRMS())
# 	errPlusData.append(hist1.GetRMS())

# x = array.array( 'f', xData )
# y = array.array( 'f', yData )
# errMinus = array.array( 'f', errMinusData )
# errPlus  = array.array( 'f', errPlusData )
# zeros = array.array('f',zerosData)
# oneLine = ROOT.TF1("oneline","x",0,3)

# gr = ROOT.TGraphAsymmErrors( n, x, y, zeros,zeros,errMinus, errPlus)
# gr.SetTitle('Toy fitting for non prompt SF ')
# gr.GetXaxis().SetTitle("Expected non prompt SF");
# gr.GetYaxis().SetTitle("Toy Data non prompt SF");
# gr.SetMarkerColor(2)
# gr.SetMarkerStyle(7)
# gr.GetXaxis().SetRangeUser(0,3)
# gr.GetYaxis().SetRangeUser(0,3)
# # gr.SetMarkerSize(3)
# gr.Draw('AP')
# oneLine.Draw('same')

# c1.Draw()

# %%
######## simutaneous fitting with M3 and ChIso.

# %%
mylist = ["higgsCombineel_2016.MultiDimFit.mH120.314159.root", 
          "higgsCombineel_2017.MultiDimFit.mH120.314159.root", 
          "higgsCombineel_2018.MultiDimFit.mH120.314159.root", 
          "higgsCombinemu_2016.MultiDimFit.mH120.314159.root",
          "higgsCombinemu_2017.MultiDimFit.mH120.314159.root",
          "higgsCombinemu_2018.MultiDimFit.mH120.314159.root"]

line = ""
for ifile in mylist:
    myfile = ROOT.TFile(ifile,"read")
    mytree=myfile.limit
    mytree.Draw("r>>hist1")
    hist1 = ROOT.gDirectory.Get('hist1')
    mytree.Draw("nonPromptSF>>hist2")
    hist2 = ROOT.gDirectory.Get('hist2')

    line +=   "ttgammaSF_%s = %.3f \n"%(ifile[12:-30],hist1.GetMean())
    line += "nonPromptSF_%s = %.3f \n"%(ifile[12:-30],hist2.GetMean())


with open("TTGamma_nonPrompt_values_separateChannelYear.py","w") as _file:
    _file.write(line)
    
# !cat TTGamma_nonPrompt_values_separateChannelYear.py
# Out:
# ttgammaSF_el_2016 = 0.994
# nonPromptSF_el_2016 = 1.000
# ttgammaSF_el_2017 = 0.990
# nonPromptSF_el_2017 = 1.000
# ttgammaSF_el_2018 = 0.985
# nonPromptSF_el_2018 = 1.002
# ttgammaSF_mu_2016 = 0.989
# nonPromptSF_mu_2016 = 1.002
# ttgammaSF_mu_2017 = 0.993
# nonPromptSF_mu_2017 = 1.004
# ttgammaSF_mu_2018 = 0.995
# nonPromptSF_mu_2018 = 1.001

# %%
# !cp TTGamma_nonPrompt_values_separateChannelYear.py /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/Plotting

# %%
line = ""
mylist = ["higgsCombineel_2016.MultiDimFit.mH120.314159.root", 
          "higgsCombineel_2017.MultiDimFit.mH120.314159.root", 
          "higgsCombineel_2018.MultiDimFit.mH120.314159.root", 
          "higgsCombinemu_2016.MultiDimFit.mH120.314159.root",
          "higgsCombinemu_2017.MultiDimFit.mH120.314159.root",
          "higgsCombinemu_2018.MultiDimFit.mH120.314159.root"]

for ifile in mylist:
    myfile = ROOT.TFile(ifile,"read")
    mytree=myfile.limit
    mytree.Draw("r>>hist1")
    hist1 = ROOT.gDirectory.Get('hist1')
    mytree.Draw("nonPromptSF>>hist2")
    hist2 = ROOT.gDirectory.Get('hist2')
#     print ifile[15:-25]
#     print ifile[15:-30]
    if ifile[15:-30]=='2016': year='sixteen'
    elif ifile[15:-30]=='2017': year='seventeen'
    elif ifile[15:-30]=='2018': year='eightteen'

#     print year
#     print ifile[12:-35]
    line +=   "\\newcommand{\\ttgammaSF%s%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ -%.3f}}}\n"%(ifile[12:-35],year,hist1.GetMean(),hist1.GetRMS(), hist1.GetRMS())
    line +=   "\\newcommand{\\nonPromptSF%s%s} {\ensuremath{%.3f \\substack{+%.3f \\\\ -%.3f}}}\n"%(ifile[12:-35],year,hist2.GetMean(),hist2.GetRMS(), hist2.GetRMS())

with open("TTGamma_nonPrompt_values_separateChannelYear.tex","w") as _file:
    _file.write(line)

# !cat TTGamma_nonPrompt_values_separateChannelYear.tex
# Out:
# \newcommand{\ttgammaSFelsixteen} {\ensuremath{0.994 \substack{+0.068 \\ -0.068}}}
# \newcommand{\nonPromptSFelsixteen} {\ensuremath{1.000 \substack{+0.017 \\ -0.017}}}
# \newcommand{\ttgammaSFelseventeen} {\ensuremath{0.990 \substack{+0.070 \\ -0.070}}}
# \newcommand{\nonPromptSFelseventeen} {\ensuremath{1.000 \substack{+0.017 \\ -0.017}}}
# \newcommand{\ttgammaSFeleightteen} {\ensuremath{0.985 \substack{+0.070 \\ -0.070}}}
# \newcommand{\nonPromptSFeleightteen} {\ensuremath{1.002 \substack{+0.015 \\ -0.015}}}
# \newcommand{\ttgammaSFmusixteen} {\ensuremath{0.989 \substack{+0.069 \\ -0.069}}}
# \newcommand{\nonPromptSFmusixteen} {\ensuremath{1.002 \substack{+0.016 \\ -0.016}}}
# \newcommand{\ttgammaSFmuseventeen} {\ensuremath{0.993 \substack{+0.069 \\ -0.069}}}
# \newcommand{\nonPromptSFmuseventeen} {\ensuremath{1.004 \substack{+0.019 \\ -0.019}}}
# \newcommand{\ttgammaSFmueightteen} {\ensuremath{0.995 \substack{+0.064 \\ -0.064}}}
# ...

# %%
# !cp TTGamma_nonPrompt_values_separateChannelYear.tex ../AllTexFiles
