# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting/CombineFitting/Datacard_ZJets_2018

# %% [markdown]
# ## Both Channel

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          1405.993546     68.822583       total sum
# 0          417.000000      20.420578       Unweighted events, alpha=3.371687
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1911.895203     82.170652       total sum
# 1          541.000000      23.259407       Unweighted events, alpha=3.534002
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2595.861313     95.989160       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          1405.993546     68.822583       total sum
# 0          417.000000      20.420578       Unweighted events, alpha=3.371687
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1911.895203     82.170652       total sum
# 1          541.000000      23.259407       Unweighted events, alpha=3.534002
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2595.861313     95.989160       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          1085.282516     61.169285       total sum
# 0          315.000000      17.748239       Unweighted events, alpha=3.445341
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1410.683220     70.737702       total sum
# 1          398.000000      19.949937       Unweighted events, alpha=3.544430
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2006.401848     84.568397       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          259.916473      28.314040       total sum
# 0          84.000000       9.165151        Unweighted events, alpha=3.094244
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          377.452578      36.257006       total sum
# 1          108.000000      10.392305       Unweighted events, alpha=3.494931
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          466.190895      40.900955       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          60.794619       13.898981       total sum
# 0          19.000000       4.358899        Unweighted events, alpha=3.199717
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          123.758244      20.823618       total sum
# 1          35.000000       5.916080        Unweighted events, alpha=3.535950
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          123.268929      19.728583       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          209.301071      22.342319       total sum
# 0          88.000000       9.380832        Unweighted events, alpha=2.378421
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          260.622665      27.113113       total sum
# 1          92.000000       9.591663        Unweighted events, alpha=2.832855
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          261.348244      28.088593       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          67.233269       8.808938        total sum
# 0          58.000000       7.615773        Unweighted events, alpha=1.159194
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          79.440556       9.817868        total sum
# 1          65.000000       8.062258        Unweighted events, alpha=1.222162
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          116.188343      16.145697       total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          70.723935       5.306042        total sum
# 0          178.000000      13.341664       Unweighted events, alpha=0.397325
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          89.128223       8.786784        total sum
# 1          103.000000      10.148892       Unweighted events, alpha=0.865323
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          76.586389       6.167259        total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          42.900002       2.087081        total sum
# 0          423.000000      20.566964       Unweighted events, alpha=0.101418
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          47.000267       4.033838        total sum
# 1          136.000000      11.661904       Unweighted events, alpha=0.345590
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          45.322774       2.511374        total sum
# ...

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          65.833317       9.375631        total sum
# 0          49.000000       7.000000        Unweighted events, alpha=1.343537
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          64.059323       6.799742        total sum
# 1          89.000000       9.433981        Unweighted events, alpha=0.719768
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          60.096636       7.297275        total sum
# ...
