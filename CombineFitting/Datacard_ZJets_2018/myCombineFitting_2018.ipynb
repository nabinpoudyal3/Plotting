# %%
import ROOT
import os
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/Plotting/CombineFitting/Datacard_ZJets_2018

# %% [markdown]
# ## Both Channel

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3785.289886     115.161175      total sum
# 0          1080.000000     32.863353       Unweighted events, alpha=3.504898
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          6821.547791     157.613221      total sum
# 1          1873.000000     43.278170       Unweighted events, alpha=3.642044
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          15006.920471    233.679300      total sum
# 2          4124.000000     64.218377       Unweighted events, alpha=3.638923
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          34333.945496    356.265901      total sum
# 3          9288.000000     96.374270       Unweighted events, alpha=3.696592
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          74093.707642    527.325232      total sum
# 4          19743.000000    140.509786      Unweighted events, alpha=3.752910
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          95961.775146    596.882570      total sum
# 5          25848.000000    160.773132      Unweighted events, alpha=3.712542
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          58946.062378    468.550139      total sum
# 6          15827.000000    125.805405      Unweighted events, alpha=3.724399
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          26176.087952    309.468128      total sum
# 7          7154.000000     84.581322       Unweighted events, alpha=3.658944
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          12443.303223    216.788601      total sum
# 8          3295.000000     57.402091       Unweighted events, alpha=3.776420
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          6413.052582     152.142052      total sum
# 9          1777.000000     42.154478       Unweighted events, alpha=3.608921
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          11651.295105    207.028039      total sum
# 0          3167.000000     56.276105       Unweighted events, alpha=3.678969
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          18085.125488    258.848518      total sum
# 1          4881.000000     69.864154       Unweighted events, alpha=3.705209
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          31431.942200    345.558318      total sum
# 2          8274.000000     90.961530       Unweighted events, alpha=3.798881
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          66595.920410    507.068596      total sum
# 3          17249.000000    131.335448      Unweighted events, alpha=3.860857
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          165851.937012   798.347130      total sum
# 4          43158.000000    207.745036      Unweighted events, alpha=3.842901
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          283685.374512   1040.458239     total sum
# 5          74340.000000    272.653626      Unweighted events, alpha=3.816053
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          174288.190186   816.139265      total sum
# 6          45604.000000    213.550931      Unweighted events, alpha=3.821774
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          62675.607422    487.911472      total sum
# 7          16501.000000    128.456218      Unweighted events, alpha=3.798291
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          28320.585449    327.724130      total sum
# 8          7468.000000     86.417591       Unweighted events, alpha=3.792258
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          15453.910461    239.231860      total sum
# 9          4173.000000     64.598762       Unweighted events, alpha=3.703309
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-zIGtU4.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.20616  -0.00238896/+0.00242415  (68% CL)
# Done in 0.00 min (cpu), 0.02 min (real)

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3785.289886     115.161175      total sum
# 0          1080.000000     32.863353       Unweighted events, alpha=3.504898
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          6821.547791     157.613221      total sum
# 1          1873.000000     43.278170       Unweighted events, alpha=3.642044
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          15006.920471    233.679300      total sum
# 2          4124.000000     64.218377       Unweighted events, alpha=3.638923
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          34333.945496    356.265901      total sum
# 3          9288.000000     96.374270       Unweighted events, alpha=3.696592
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          74093.707642    527.325232      total sum
# 4          19743.000000    140.509786      Unweighted events, alpha=3.752910
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          95961.775146    596.882570      total sum
# 5          25848.000000    160.773132      Unweighted events, alpha=3.712542
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          58946.062378    468.550139      total sum
# 6          15827.000000    125.805405      Unweighted events, alpha=3.724399
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          26176.087952    309.468128      total sum
# 7          7154.000000     84.581322       Unweighted events, alpha=3.658944
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          12443.303223    216.788601      total sum
# 8          3295.000000     57.402091       Unweighted events, alpha=3.776420
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          6413.052582     152.142052      total sum
# 9          1777.000000     42.154478       Unweighted events, alpha=3.608921
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          11651.295105    207.028039      total sum
# 0          3167.000000     56.276105       Unweighted events, alpha=3.678969
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          18085.125488    258.848518      total sum
# 1          4881.000000     69.864154       Unweighted events, alpha=3.705209
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          31431.942200    345.558318      total sum
# 2          8274.000000     90.961530       Unweighted events, alpha=3.798881
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          66595.920410    507.068596      total sum
# 3          17249.000000    131.335448      Unweighted events, alpha=3.860857
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          165851.937012   798.347130      total sum
# 4          43158.000000    207.745036      Unweighted events, alpha=3.842901
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          283685.374512   1040.458239     total sum
# 5          74340.000000    272.653626      Unweighted events, alpha=3.816053
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          174288.190186   816.139265      total sum
# 6          45604.000000    213.550931      Unweighted events, alpha=3.821774
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          62675.607422    487.911472      total sum
# 7          16501.000000    128.456218      Unweighted events, alpha=3.798291
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          28320.585449    327.724130      total sum
# 8          7468.000000     86.417591       Unweighted events, alpha=3.792258
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          15453.910461    239.231860      total sum
# 9          4173.000000     64.598762       Unweighted events, alpha=3.703309
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-yWaFvz.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.20616  -0.00238896/+0.00242415  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2850.943726     100.272526      total sum
# 0          808.000000      28.425341       Unweighted events, alpha=3.528396
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          5161.888184     137.279130      total sum
# 1          1414.000000     37.603191       Unweighted events, alpha=3.650557
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          11368.023132    203.398921      total sum
# 2          3124.000000     55.892754       Unweighted events, alpha=3.638932
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          26405.091064    310.226308      total sum
# 3          7245.000000     85.117566       Unweighted events, alpha=3.644595
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          56831.354736    461.924425      total sum
# 4          15137.000000    123.032516      Unweighted events, alpha=3.754466
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          72815.105225    519.521389      total sum
# 5          19644.000000    140.157055      Unweighted events, alpha=3.706735
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          44590.847839    407.888742      total sum
# 6          11951.000000    109.320629      Unweighted events, alpha=3.731139
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          19811.796356    269.521296      total sum
# 7          5403.000000     73.505102       Unweighted events, alpha=3.666814
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          9658.070877     191.953813      total sum
# 8          2532.000000     50.318983       Unweighted events, alpha=3.814404
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4896.485260     133.089843      total sum
# 9          1354.000000     36.796739       Unweighted events, alpha=3.616311
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          9047.916748     183.089054      total sum
# 0          2442.000000     49.416596       Unweighted events, alpha=3.705126
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          14126.027283    229.412171      total sum
# 1          3791.000000     61.571097       Unweighted events, alpha=3.726201
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          24513.007935    305.402905      total sum
# 2          6442.000000     80.262071       Unweighted events, alpha=3.805186
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          51752.789307    446.776521      total sum
# 3          13418.000000    115.836091      Unweighted events, alpha=3.856967
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          130192.887451   708.113994      total sum
# 4          33804.000000    183.858641      Unweighted events, alpha=3.851405
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          223274.824951   924.089089      total sum
# 5          58378.000000    241.615397      Unweighted events, alpha=3.824640
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          136769.031616   723.931148      total sum
# 6          35693.000000    188.925911      Unweighted events, alpha=3.831817
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          48655.880981    430.581550      total sum
# 7          12769.000000    113.000000      Unweighted events, alpha=3.810469
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          21654.766907    285.654149      total sum
# 8          5747.000000     75.808970       Unweighted events, alpha=3.768012
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          12022.285767    211.352647      total sum
# 9          3236.000000     56.885851       Unweighted events, alpha=3.715169
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-a2GANR.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.20998  -0.00271841/+0.00275289  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          724.233376      49.649035       total sum
# 0          213.000000      14.594520       Unweighted events, alpha=3.400157
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1271.259369     68.115343       total sum
# 1          348.000000      18.654758       Unweighted events, alpha=3.653044
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2750.063080     100.071931      total sum
# 2          755.000000      27.477263       Unweighted events, alpha=3.642468
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          6039.633484     153.123638      total sum
# 3          1556.000000     39.446166       Unweighted events, alpha=3.881513
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          13317.277344    223.584867      total sum
# 4          3548.000000     59.565090       Unweighted events, alpha=3.753460
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          17545.553406    255.155082      total sum
# 5          4729.000000     68.767725       Unweighted events, alpha=3.710204
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          10907.260406    201.060581      total sum
# 6          2943.000000     54.249424       Unweighted events, alpha=3.706171
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          4913.420135     133.310163      total sum
# 7          1358.000000     36.851052       Unweighted events, alpha=3.618130
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2072.293831     86.497576       total sum
# 8          574.000000      23.958297       Unweighted events, alpha=3.610268
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1180.760872     65.143803       total sum
# 9          329.000000      18.138357       Unweighted events, alpha=3.588939
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2019.766205     85.516465       total sum
# 0          558.000000      23.622024       Unweighted events, alpha=3.619653
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2964.588593     103.559480      total sum
# 1          820.000000      28.635642       Unweighted events, alpha=3.615352
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          5408.619446     143.466943      total sum
# 2          1421.000000     37.696154       Unweighted events, alpha=3.806207
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          11503.150482    212.115541      total sum
# 3          2941.000000     54.230987       Unweighted events, alpha=3.911306
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          27778.409851    325.743340      total sum
# 4          7272.000000     85.276022       Unweighted events, alpha=3.819913
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          47187.155762    422.662760      total sum
# 5          12464.000000    111.642286      Unweighted events, alpha=3.785876
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          29031.349396    331.414008      total sum
# 6          7673.000000     87.595662       Unweighted events, alpha=3.783572
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          10816.131805    202.017557      total sum
# 7          2867.000000     53.544374       Unweighted events, alpha=3.772631
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          5085.310364     140.903588      total sum
# 8          1303.000000     36.097091       Unweighted events, alpha=3.902771
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          2747.277985     100.662687      total sum
# 9          745.000000      27.294688       Unweighted events, alpha=3.687621
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-SnYwbv.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.19821  -0.00575928/+0.00580279  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          210.112877      27.248674       total sum
# 0          59.000000       7.681146        Unweighted events, alpha=3.561235
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          388.399792      36.832975       total sum
# 1          111.000000      10.535654       Unweighted events, alpha=3.499097
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          888.827930      56.749477       total sum
# 2          245.000000      15.652476       Unweighted events, alpha=3.627869
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1889.182198     85.077501       total sum
# 3          493.000000      22.203603       Unweighted events, alpha=3.832013
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3944.989227     121.274620      total sum
# 4          1058.000000     32.526912       Unweighted events, alpha=3.728723
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          5601.114548     145.815680      total sum
# 5          1476.000000     38.418745       Unweighted events, alpha=3.794793
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          3447.999626     112.874489      total sum
# 6          933.000000      30.545049       Unweighted events, alpha=3.695605
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1450.889786     73.192855       total sum
# 7          393.000000      19.824228       Unweighted events, alpha=3.691832
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          712.934883      51.664309       total sum
# 8          190.000000      13.784049       Unweighted events, alpha=3.752289
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          335.808731      34.504817       total sum
# 9          95.000000       9.746794        Unweighted events, alpha=3.534829
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          583.612816      45.010462       total sum
# 0          168.000000      12.961481       Unweighted events, alpha=3.473886
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          994.513901      60.399051       total sum
# 1          271.000000      16.462078       Unweighted events, alpha=3.669793
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1510.286091     74.544302       total sum
# 2          410.000000      20.248457       Unweighted events, alpha=3.683625
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3340.174103     111.876268      total sum
# 3          891.000000      29.849623       Unweighted events, alpha=3.748792
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7880.921555     172.696230      total sum
# 4          2083.000000     45.639895       Unweighted events, alpha=3.783448
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          13222.776123    223.537233      total sum
# 5          3499.000000     59.152346       Unweighted events, alpha=3.779016
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          8488.018982     179.364847      total sum
# 6          2239.000000     47.318073       Unweighted events, alpha=3.790987
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          3203.653900     108.839513      total sum
# 7          866.000000      29.427878       Unweighted events, alpha=3.699369
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1580.525375     77.142668       total sum
# 8          420.000000      20.493902       Unweighted events, alpha=3.763156
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          684.361450      49.284527       total sum
# 9          193.000000      13.892444       Unweighted events, alpha=3.545914
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-MSU8Kg.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.17814  -0.0104242/+0.0105926  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          478.694000      35.991565       total sum
# 0          177.000000      13.304135       Unweighted events, alpha=2.704486
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          683.179504      45.350617       total sum
# 1          227.000000      15.066519       Unweighted events, alpha=3.009601
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1374.364197     69.067119       total sum
# 2          396.000000      19.899749       Unweighted events, alpha=3.470617
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          3056.121429     107.730098      total sum
# 3          805.000000      28.372522       Unweighted events, alpha=3.796424
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          6031.706085     156.884158      total sum
# 4          1478.000000     38.444766       Unweighted events, alpha=4.080992
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          7462.477173     169.765557      total sum
# 5          1932.000000     43.954522       Unweighted events, alpha=3.862566
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          4674.697021     134.729394      total sum
# 6          1204.000000     34.698703       Unweighted events, alpha=3.882639
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          2127.707764     88.872291       total sum
# 7          573.000000      23.937418       Unweighted events, alpha=3.713277
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1172.967163     63.867431       total sum
# 8          337.000000      18.357560       Unweighted events, alpha=3.480615
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          701.161743      45.168684       total sum
# 9          241.000000      15.524175       Unweighted events, alpha=2.909385
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          1338.424011     56.170264       total sum
# 0          568.000000      23.832751       Unweighted events, alpha=2.356380
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1879.620972     74.655146       total sum
# 1          634.000000      25.179357       Unweighted events, alpha=2.964702
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2917.805176     98.349063       total sum
# 2          880.000000      29.664794       Unweighted events, alpha=3.315688
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5964.748657     152.252672      total sum
# 3          1535.000000     39.179076       Unweighted events, alpha=3.885830
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          13381.273193    230.680656      total sum
# 4          3365.000000     58.008620       Unweighted events, alpha=3.976604
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          23375.138550    309.512541      total sum
# 5          5704.000000     75.524830       Unweighted events, alpha=4.098026
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          13988.280701    236.629166      total sum
# 6          3495.000000     59.118525       Unweighted events, alpha=4.002369
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          5495.288269     147.649892      total sum
# 7          1385.000000     37.215588       Unweighted events, alpha=3.967717
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2674.728149     99.485382       total sum
# 8          723.000000      26.888659       Unweighted events, alpha=3.699486
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1749.985657     71.208924       total sum
# 9          604.000000      24.576411       Unweighted events, alpha=2.897327
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-vV2l1p.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.28393  -0.00949857/+0.00961433  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          157.849136      15.042546       total sum
# 0          110.000000      10.488088       Unweighted events, alpha=1.434992
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          304.781006      29.389039       total sum
# 1          108.000000      10.392305       Unweighted events, alpha=2.822046
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          397.581726      35.130571       total sum
# 2          128.000000      11.313708       Unweighted events, alpha=3.106107
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          906.000809      57.148864       total sum
# 3          251.000000      15.842980       Unweighted events, alpha=3.609565
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1988.088989     86.612559       total sum
# 4          527.000000      22.956481       Unweighted events, alpha=3.772465
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2525.897583     99.028306       total sum
# 5          651.000000      25.514702       Unweighted events, alpha=3.880027
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1552.244904     78.322626       total sum
# 6          393.000000      19.824228       Unweighted events, alpha=3.949733
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          677.658997      46.710179       total sum
# 7          210.000000      14.491377       Unweighted events, alpha=3.226948
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          390.247292      35.869699       total sum
# 8          118.000000      10.862780       Unweighted events, alpha=3.307180
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          223.005722      21.247065       total sum
# 9          110.000000      10.488088       Unweighted events, alpha=2.027325
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          506.028503      31.844038       total sum
# 0          253.000000      15.905974       Unweighted events, alpha=2.000113
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          649.706329      38.718386       total sum
# 1          282.000000      16.792856       Unweighted events, alpha=2.303923
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1060.568573     58.525269       total sum
# 2          328.000000      18.110770       Unweighted events, alpha=3.233441
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1799.520538     79.522742       total sum
# 3          512.000000      22.627417       Unweighted events, alpha=3.514689
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3983.606384     126.079431      total sum
# 4          998.000000      31.591138       Unweighted events, alpha=3.991590
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          6451.538177     160.815023      total sum
# 5          1609.000000     40.112342       Unweighted events, alpha=4.009657
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          4258.370758     129.553638      total sum
# 6          1080.000000     32.863353       Unweighted events, alpha=3.942936
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1734.145630     78.374435       total sum
# 7          490.000000      22.135944       Unweighted events, alpha=3.539073
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          957.643036      54.918774       total sum
# 8          304.000000      17.435596       Unweighted events, alpha=3.150142
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          678.946930      41.009418       total sum
# 9          274.000000      16.552945       Unweighted events, alpha=2.477909
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-JbKD41.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.41891  -0.0191222/+0.0196272  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          164.294800      11.133559       total sum
# 0          218.000000      14.764823       Unweighted events, alpha=0.753646
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          187.433590      14.218794       total sum
# 1          174.000000      13.190906       Unweighted events, alpha=1.077205
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          282.655594      25.305541       total sum
# 2          125.000000      11.180340       Unweighted events, alpha=2.261245
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          394.756332      31.156198       total sum
# 3          161.000000      12.688578       Unweighted events, alpha=2.451903
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          811.636719      48.859989       total sum
# 4          276.000000      16.613248       Unweighted events, alpha=2.940713
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          962.895111      54.312275       total sum
# 5          314.000000      17.720045       Unweighted events, alpha=3.066545
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          594.653076      40.021693       total sum
# 6          221.000000      14.866069       Unweighted events, alpha=2.690738
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          369.297958      28.093170       total sum
# 7          173.000000      13.152946       Unweighted events, alpha=2.134670
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          265.820435      18.980209       total sum
# 8          196.000000      14.000000       Unweighted events, alpha=1.356227
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          204.416092      12.061228       total sum
# 9          287.000000      16.941074       Unweighted events, alpha=0.712251
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          485.937500      23.906642       total sum
# 0          413.000000      20.322401       Unweighted events, alpha=1.176604
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          543.855423      23.497401       total sum
# 1          536.000000      23.151674       Unweighted events, alpha=1.014656
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          641.302612      30.194214       total sum
# 2          451.000000      21.236761       Unweighted events, alpha=1.421957
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          960.041016      44.704191       total sum
# 3          461.000000      21.470911       Unweighted events, alpha=2.082518
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1825.745239     73.450260       total sum
# 4          618.000000      24.859606       Unweighted events, alpha=2.954280
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          2942.445679     98.997844       total sum
# 5          883.000000      29.715316       Unweighted events, alpha=3.332328
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1860.933777     74.256039       total sum
# 6          628.000000      25.059928       Unweighted events, alpha=2.963270
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          967.082581      46.860764       total sum
# 7          426.000000      20.639767       Unweighted events, alpha=2.270147
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          670.393036      31.211588       total sum
# 8          461.000000      21.470911       Unweighted events, alpha=1.454215
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          550.046707      23.819530       total sum
# 9          533.000000      23.086793       Unweighted events, alpha=1.031983
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-cFbbSJ.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.22228  -0.0275414/+0.0286102  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          93.489572       5.779394        total sum
# 0          262.000000      16.186414       Unweighted events, alpha=0.356830
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          93.485286       4.965747        total sum
# 1          354.000000      18.814888       Unweighted events, alpha=0.264083
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          144.307640      16.219780       total sum
# 2          79.000000       8.888194        Unweighted events, alpha=1.826679
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          240.284386      23.143991       total sum
# 3          108.000000      10.392305       Unweighted events, alpha=2.224855
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          444.006592      35.723033       total sum
# 4          154.000000      12.409674       Unweighted events, alpha=2.883160
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          562.646378      42.464810       total sum
# 5          176.000000      13.266499       Unweighted events, alpha=3.196854
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          344.981796      28.923685       total sum
# 6          142.000000      11.916375       Unweighted events, alpha=2.429449
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          208.050339      19.495496       total sum
# 7          114.000000      10.677078       Unweighted events, alpha=1.825003
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          169.626999      17.993424       total sum
# 8          89.000000       9.433981        Unweighted events, alpha=1.905921
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          156.759010      15.636804       total sum
# 9          101.000000      10.049876       Unweighted events, alpha=1.552069
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          321.538666      19.209620       total sum
# 0          280.000000      16.733201       Unweighted events, alpha=1.148352
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          293.189369      14.990193       total sum
# 1          383.000000      19.570386       Unweighted events, alpha=0.765507
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          361.491364      21.332570       total sum
# 2          287.000000      16.941074       Unweighted events, alpha=1.259552
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          593.163086      36.818962       total sum
# 3          260.000000      16.124515       Unweighted events, alpha=2.281396
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          922.571960      49.246190       total sum
# 4          351.000000      18.734994       Unweighted events, alpha=2.628410
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1457.056580     67.240845       total sum
# 5          470.000000      21.679483       Unweighted events, alpha=3.100120
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          916.083923      50.445724       total sum
# 6          330.000000      18.165902       Unweighted events, alpha=2.776012
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          550.826172      34.166048       total sum
# 7          260.000000      16.124515       Unweighted events, alpha=2.118562
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          351.616951      22.478542       total sum
# 8          245.000000      15.652476       Unweighted events, alpha=1.435171
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          291.076454      13.019725       total sum
# 9          500.000000      22.360680       Unweighted events, alpha=0.582153
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-vWt0r1.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.31945  -0.0410885/+0.0433743  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          129.347004      11.693230       total sum
# 0          122.000000      11.045361       Unweighted events, alpha=1.060221
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          188.555428      19.514084       total sum
# 1          93.000000       9.643651        Unweighted events, alpha=2.027478
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          248.407211      24.726770       total sum
# 2          101.000000      10.049876       Unweighted events, alpha=2.459477
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          510.717812      40.919179       total sum
# 3          156.000000      12.489996       Unweighted events, alpha=3.273832
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1030.354065     60.139571       total sum
# 4          294.000000      17.146428       Unweighted events, alpha=3.504606
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1244.693649     66.219016       total sum
# 5          353.000000      18.788294       Unweighted events, alpha=3.526044
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          855.593597      54.777095       total sum
# 6          244.000000      15.620499       Unweighted events, alpha=3.506531
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          492.558151      39.706435       total sum
# 7          154.000000      12.409674       Unweighted events, alpha=3.198430
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          244.158386      23.153850       total sum
# 8          111.000000      10.535654       Unweighted events, alpha=2.199625
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          172.134819      15.131310       total sum
# 9          129.000000      11.357817       Unweighted events, alpha=1.334378
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          447.533875      28.181993       total sum
# 0          252.000000      15.874508       Unweighted events, alpha=1.775928
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          468.008331      29.338016       total sum
# 1          254.000000      15.937377       Unweighted events, alpha=1.842552
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          646.447083      39.239309       total sum
# 2          271.000000      16.462078       Unweighted events, alpha=2.385414
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          931.453796      51.193072       total sum
# 3          331.000000      18.193405       Unweighted events, alpha=2.814060
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2229.155701     90.961864       total sum
# 4          601.000000      24.515301       Unweighted events, alpha=3.709078
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3332.933533     110.551666      total sum
# 5          909.000000      30.149627       Unweighted events, alpha=3.666594
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2263.759430     90.457667       total sum
# 6          626.000000      25.019992       Unweighted events, alpha=3.616229
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          985.352478      61.153875       total sum
# 7          260.000000      16.124515       Unweighted events, alpha=3.789817
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          627.567352      38.150316       total sum
# 8          271.000000      16.462078       Unweighted events, alpha=2.315747
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          468.902069      28.042894       total sum
# 9          280.000000      16.733201       Unweighted events, alpha=1.674650
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-HzvobX.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#
#  --- FitDiagnostics ---
# Best fit r: 1.47353  -0.0287294/+0.0298377  (68% CL)
# Done in 0.00 min (cpu), 0.00 min (real)
