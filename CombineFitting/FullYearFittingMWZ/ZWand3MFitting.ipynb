# %%
import ROOT
import os
# !pwd

# --redefineSignalPOIs r,rSeventeen,rEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF

# %%
# !combine -M FitDiagnostics -n CR123_ZWand3M_backup  datacard_CR123_ZWand3M_backup.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots

# %%
# !combine -M FitDiagnostics -n CR123_ZWand3M  datacard_CR123_ZWand3M.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# ...
# Channel b2016eJet will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ...
# Analysing bin errors for: prop_binb2016eJet
# Poisson cut-off: 0
# ...
# Bin        Contents        Error           Notes
# 0          1882.401367     177.788206      total sum
# 0          112.000000      10.583005       Unweighted events, alpha=16.807155
#   => Total parameter prop_binb2016eJet_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2167.104622     202.754647      total sum
# 1          114.000000      10.677078       Unweighted events, alpha=19.009690
#   => Total parameter prop_binb2016eJet_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          2514.708893     103.288856      total sum
# ...

# %%
# !combine -M FitDiagnostics -n CR1_ZWand3M  datacard_CR1_ZWand3M.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots

# %%
# !combine -M FitDiagnostics -n CR2_ZWand3M  datacard_CR2_ZWand3M.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots

# %%
# !combine -M FitDiagnostics -n CR3_ZWand3M  datacard_CR3_ZWand3M.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots

# %%
# !combine -M FitDiagnostics -n CR4_ZWand3M  datacard_CR4_ZWand3M.txt  --redefineSignalPOIs r,MisIDEleSeventeen,MisIDEleEighteen,ZGammaBkgPhotonSF,WGammaBkgPhotonSF --saveWithUncertainties --plots
