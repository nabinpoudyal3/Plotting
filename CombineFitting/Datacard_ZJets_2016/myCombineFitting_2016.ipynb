# %%
import ROOT
import os
# Out:
# Welcome to JupyROOT 6.12/07

# %% [markdown]
# ## Both Channel

# %%
# !combine --help
# !pwd
# Out:
# /uscms_data/d3/npoudyal/TTGammaSemiLeptonic13TeV/CMSSW_10_2_14/src/TTGammaSemiLep_13TeV/Plotting_Nabin/Plotting/CombineFitting/Datacard_ZJets_2016

# %%
# !combine -M FitDiagnostics -n AR_both  datacard_AR_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          924.282265      35.649317       total sum
# 0          672.000000      25.922963       Unweighted events, alpha=1.375420
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1115.768265     39.510877       total sum
# 1          797.000000      28.231188       Unweighted events, alpha=1.399960
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1463.594902     45.667380       total sum
# 2          1027.000000     32.046841       Unweighted events, alpha=1.425117
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2068.217026     54.307526       total sum
# 3          1450.000000     38.078866       Unweighted events, alpha=1.426357
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3078.218460     66.495172       total sum
# 4          2143.000000     46.292548       Unweighted events, alpha=1.436406
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4590.612839     81.465473       total sum
# 5          3175.000000     56.347138       Unweighted events, alpha=1.445862
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          6897.874023     99.811592       total sum
# 6          4776.000000     69.108610       Unweighted events, alpha=1.444278
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          10544.599243    123.918171      total sum
# 7          7241.000000     85.094066       Unweighted events, alpha=1.456235
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          15787.137268    151.989539      total sum
# 8          10789.000000    103.870111      Unweighted events, alpha=1.463262
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          21830.955566    179.011035      total sum
# 9          14873.000000    121.954910      Unweighted events, alpha=1.467825
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         26328.570892    196.751840      total sum
# 10         17907.000000    133.817039      Unweighted events, alpha=1.470295
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         25032.432861    191.999731      total sum
# 11         16998.000000    130.376378      Unweighted events, alpha=1.472669
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         18780.200073    166.075262      total sum
# 12         12788.000000    113.084040      Unweighted events, alpha=1.468580
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         12124.436584    133.239960      total sum
# 13         8280.000000     90.994505       Unweighted events, alpha=1.464304
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         7661.898422     105.870897      total sum
# 14         5237.000000     72.367120       Unweighted events, alpha=1.463032
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         4853.204285     84.155634       total sum
# 15         3326.000000     57.671483       Unweighted events, alpha=1.459171
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         3159.380493     67.430199       total sum
# 16         2195.000000     46.850827       Unweighted events, alpha=1.439353
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         2171.008789     55.852857       total sum
# 17         1511.000000     38.871583       Unweighted events, alpha=1.436803
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1772.868164     50.405992       total sum
# 18         1237.000000     35.171011       Unweighted events, alpha=1.433200
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1279.329876     42.774481       total sum
# 19         895.000000      29.916551       Unweighted events, alpha=1.429419
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3039.988770     66.481726       total sum
# 0          2091.000000     45.727453       Unweighted events, alpha=1.453844
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3531.392670     71.941387       total sum
# 1          2410.000000     49.091751       Unweighted events, alpha=1.465308
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4543.725983     82.031536       total sum
# 2          3068.000000     55.389530       Unweighted events, alpha=1.481006
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5752.468903     92.439901       total sum
# 3          3872.000000     62.225397       Unweighted events, alpha=1.485658
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7497.153748     106.055069      total sum
# 4          4997.000000     70.689462       Unweighted events, alpha=1.500331
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          10550.482941    126.317271      total sum
# 5          6976.000000     83.522452       Unweighted events, alpha=1.512397
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          15529.082550    153.573349      total sum
# 6          10225.000000    101.118742      Unweighted events, alpha=1.518737
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          23058.093689    187.350428      total sum
# 7          15147.000000    123.073149      Unweighted events, alpha=1.522288
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          36541.708923    236.069102      total sum
# 8          23961.000000    154.793411      Unweighted events, alpha=1.525049
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          57838.137207    297.429058      total sum
# 9          37815.000000    194.460793      Unweighted events, alpha=1.529503
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         78546.472656    346.816451      total sum
# 10         51293.000000    226.479580      Unweighted events, alpha=1.531329
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         80079.756226    350.243721      total sum
# 11         52276.000000    228.639454      Unweighted events, alpha=1.531865
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         60931.225891    305.402319      total sum
# 12         39805.000000    199.511904      Unweighted events, alpha=1.530743
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         38349.842102    242.044592      total sum
# 13         25104.000000    158.442419      Unweighted events, alpha=1.527639
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         22670.720367    185.846381      total sum
# 14         14881.000000    121.987704      Unweighted events, alpha=1.523468
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         14493.187347    148.452589      total sum
# 15         9531.000000     97.626841       Unweighted events, alpha=1.520637
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         9231.684021     118.103840      total sum
# 16         6110.000000     78.166489       Unweighted events, alpha=1.510914
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         6692.966949     100.319561      total sum
# 17         4451.000000     66.715815       Unweighted events, alpha=1.503700
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         4917.856232     86.010656       total sum
# 18         3269.000000     57.175169       Unweighted events, alpha=1.504392
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         4019.996170     77.475923       total sum
# 19         2692.000000     51.884487       Unweighted events, alpha=1.493312
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-BAUD8s.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7e43fe0
#   Clients:
#     (0x7f8ca20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7e45500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7d71010,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 171465
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7e53360
#   Clients:
#     (0x7f8ca20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7e52620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7e54350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 487816
# Error in <TList::Clear>: A list is accessing an object (0x7fbd6a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7fbd94c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8207c20
#   Clients:
#     (0x8206600,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x822f9a0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7d71010,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 19284
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x823a570
#   Clients:
#     (0x8206600,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8266e00,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7e54350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 52150.7
# Error in <TList::Clear>: A list is accessing an object (0x7fbe144) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7fbe3ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7e43fe0
#   Clients:
#     (0x7f8ca20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7e45500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7d71010,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 202380
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7e53360
#   Clients:
#     (0x7f8ca20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7e52620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7e54350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 568171
# Error in <TList::Clear>: A list is accessing an object (0x7fbe694) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7fbe93c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.17367  -0.00224708/+0.00226709  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR123_both  datacard_CR123_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          924.282265      35.649317       total sum
# 0          672.000000      25.922963       Unweighted events, alpha=1.375420
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          1115.768265     39.510877       total sum
# 1          797.000000      28.231188       Unweighted events, alpha=1.399960
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1463.594902     45.667380       total sum
# 2          1027.000000     32.046841       Unweighted events, alpha=1.425117
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          2068.217026     54.307526       total sum
# 3          1450.000000     38.078866       Unweighted events, alpha=1.426357
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          3078.218460     66.495172       total sum
# 4          2143.000000     46.292548       Unweighted events, alpha=1.436406
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          4590.612839     81.465473       total sum
# 5          3175.000000     56.347138       Unweighted events, alpha=1.445862
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          6897.874023     99.811592       total sum
# 6          4776.000000     69.108610       Unweighted events, alpha=1.444278
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          10544.599243    123.918171      total sum
# 7          7241.000000     85.094066       Unweighted events, alpha=1.456235
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          15787.137268    151.989539      total sum
# 8          10789.000000    103.870111      Unweighted events, alpha=1.463262
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          21830.955566    179.011035      total sum
# 9          14873.000000    121.954910      Unweighted events, alpha=1.467825
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         26328.570892    196.751840      total sum
# 10         17907.000000    133.817039      Unweighted events, alpha=1.470295
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         25032.432861    191.999731      total sum
# 11         16998.000000    130.376378      Unweighted events, alpha=1.472669
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         18780.200073    166.075262      total sum
# 12         12788.000000    113.084040      Unweighted events, alpha=1.468580
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         12124.436584    133.239960      total sum
# 13         8280.000000     90.994505       Unweighted events, alpha=1.464304
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         7661.898422     105.870897      total sum
# 14         5237.000000     72.367120       Unweighted events, alpha=1.463032
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         4853.204285     84.155634       total sum
# 15         3326.000000     57.671483       Unweighted events, alpha=1.459171
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         3159.380493     67.430199       total sum
# 16         2195.000000     46.850827       Unweighted events, alpha=1.439353
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         2171.008789     55.852857       total sum
# 17         1511.000000     38.871583       Unweighted events, alpha=1.436803
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1772.868164     50.405992       total sum
# 18         1237.000000     35.171011       Unweighted events, alpha=1.433200
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         1279.329876     42.774481       total sum
# 19         895.000000      29.916551       Unweighted events, alpha=1.429419
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          3039.988770     66.481726       total sum
# 0          2091.000000     45.727453       Unweighted events, alpha=1.453844
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          3531.392670     71.941387       total sum
# 1          2410.000000     49.091751       Unweighted events, alpha=1.465308
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          4543.725983     82.031536       total sum
# 2          3068.000000     55.389530       Unweighted events, alpha=1.481006
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          5752.468903     92.439901       total sum
# 3          3872.000000     62.225397       Unweighted events, alpha=1.485658
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          7497.153748     106.055069      total sum
# 4          4997.000000     70.689462       Unweighted events, alpha=1.500331
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          10550.482941    126.317271      total sum
# 5          6976.000000     83.522452       Unweighted events, alpha=1.512397
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          15529.082550    153.573349      total sum
# 6          10225.000000    101.118742      Unweighted events, alpha=1.518737
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          23058.093689    187.350428      total sum
# 7          15147.000000    123.073149      Unweighted events, alpha=1.522288
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          36541.708923    236.069102      total sum
# 8          23961.000000    154.793411      Unweighted events, alpha=1.525049
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          57838.137207    297.429058      total sum
# 9          37815.000000    194.460793      Unweighted events, alpha=1.529503
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         78546.472656    346.816451      total sum
# 10         51293.000000    226.479580      Unweighted events, alpha=1.531329
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         80079.756226    350.243721      total sum
# 11         52276.000000    228.639454      Unweighted events, alpha=1.531865
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         60931.225891    305.402319      total sum
# 12         39805.000000    199.511904      Unweighted events, alpha=1.530743
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         38349.842102    242.044592      total sum
# 13         25104.000000    158.442419      Unweighted events, alpha=1.527639
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         22670.720367    185.846381      total sum
# 14         14881.000000    121.987704      Unweighted events, alpha=1.523468
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         14493.187347    148.452589      total sum
# 15         9531.000000     97.626841       Unweighted events, alpha=1.520637
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         9231.684021     118.103840      total sum
# 16         6110.000000     78.166489       Unweighted events, alpha=1.510914
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         6692.966949     100.319561      total sum
# 17         4451.000000     66.715815       Unweighted events, alpha=1.503700
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         4917.856232     86.010656       total sum
# 18         3269.000000     57.175169       Unweighted events, alpha=1.504392
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         4019.996170     77.475923       total sum
# 19         2692.000000     51.884487       Unweighted events, alpha=1.493312
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-xqp0ru.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x97a1410
#   Clients:
#     (0x98e9e50,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x97a2930,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x96ce410,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 171465
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x97b07a0
#   Clients:
#     (0x98e9e50,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x97afa60,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x97b1790,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 487816
# Error in <TList::Clear>: A list is accessing an object (0x991aab4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x991ad5c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9b64ad0
#   Clients:
#     (0x9b634b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9b8caf0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x96ce410,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 19284
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9b97720
#   Clients:
#     (0x9b634b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9bc3f50,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x97b1790,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 52150.7
# Error in <TList::Clear>: A list is accessing an object (0x991b554) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x991b7fc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x97a1410
#   Clients:
#     (0x98e9e50,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x97a2930,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x96ce410,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 202380
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x97b07a0
#   Clients:
#     (0x98e9e50,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x97afa60,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x97b1790,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 568171
# Error in <TList::Clear>: A list is accessing an object (0x991baa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x991bd4c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.17367  -0.00224708/+0.00226709  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR1_both  datacard_CR1_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          675.059643      30.564077       total sum
# 0          488.000000      22.090722       Unweighted events, alpha=1.383319
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          839.950775      34.397712       total sum
# 1          596.000000      24.413111       Unweighted events, alpha=1.409313
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          1116.333458     39.957927       total sum
# 2          781.000000      27.946377       Unweighted events, alpha=1.429364
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          1599.522190     47.829938       total sum
# 3          1118.000000     33.436507       Unweighted events, alpha=1.430700
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          2428.972130     59.186299       total sum
# 4          1684.000000     41.036569       Unweighted events, alpha=1.442382
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          3513.540703     71.228685       total sum
# 5          2433.000000     49.325450       Unweighted events, alpha=1.444119
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          5213.565231     86.795049       total sum
# 6          3608.000000     60.066630       Unweighted events, alpha=1.445001
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          8149.984512     108.995616      total sum
# 7          5591.000000     74.772990       Unweighted events, alpha=1.457697
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          12189.020859    133.496654      total sum
# 8          8337.000000     91.307174       Unweighted events, alpha=1.462039
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          16757.190002    156.862633      total sum
# 9          11412.000000    106.826963      Unweighted events, alpha=1.468383
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         20190.609833    172.323103      total sum
# 10         13728.000000    117.166548      Unweighted events, alpha=1.470761
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         19082.354431    167.643166      total sum
# 11         12957.000000    113.828819      Unweighted events, alpha=1.472745
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         14301.723541    144.814892      total sum
# 12         9753.000000     98.757278       Unweighted events, alpha=1.466392
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         9283.165833     116.545706      total sum
# 13         6345.000000     79.655508       Unweighted events, alpha=1.463068
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         5918.634163     93.082738       total sum
# 14         4043.000000     63.584589       Unweighted events, alpha=1.463921
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         3703.730110     73.625823       total sum
# 15         2531.000000     50.309045       Unweighted events, alpha=1.463347
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         2430.443428     59.244518       total sum
# 16         1683.000000     41.024383       Unweighted events, alpha=1.444114
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1660.633205     48.957110       total sum
# 17         1151.000000     33.926391       Unweighted events, alpha=1.442774
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         1384.373138     44.566035       total sum
# 18         965.000000      31.064449       Unweighted events, alpha=1.434584
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         964.537750      37.267483       total sum
# 19         670.000000      25.884358       Unweighted events, alpha=1.439609
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          2341.177017     58.535020       total sum
# 0          1600.000000     40.000000       Unweighted events, alpha=1.463236
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          2730.380737     63.549253       total sum
# 1          1846.000000     42.965102       Unweighted events, alpha=1.479079
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          3554.925369     72.798863       total sum
# 2          2385.000000     48.836462       Unweighted events, alpha=1.490535
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          4467.451218     81.647419       total sum
# 3          2994.000000     54.717456       Unweighted events, alpha=1.492135
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          5809.402817     93.458344       total sum
# 4          3864.000000     62.161081       Unweighted events, alpha=1.503469
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          8201.434387     111.563513      total sum
# 5          5404.000000     73.511904       Unweighted events, alpha=1.517660
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          12009.221527    135.239158      total sum
# 6          7885.000000     88.797522       Unweighted events, alpha=1.523046
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          17880.118805    165.159443      total sum
# 7          11720.000000    108.258949      Unweighted events, alpha=1.525607
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          28424.181580    208.335667      total sum
# 8          18614.000000    136.433134      Unweighted events, alpha=1.527032
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          45097.462280    262.747806      total sum
# 9          29460.000000    171.639156      Unweighted events, alpha=1.530803
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         62246.424805    308.906276      total sum
# 10         40605.000000    201.506824      Unweighted events, alpha=1.532974
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         63314.707214    311.559350      total sum
# 11         41298.000000    203.219094      Unweighted events, alpha=1.533118
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         47912.876831    271.055506      total sum
# 12         31246.000000    176.765381      Unweighted events, alpha=1.533408
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         29923.547058    213.894187      total sum
# 13         19572.000000    139.899964      Unweighted events, alpha=1.528896
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         17649.959991    164.239080      total sum
# 14         11549.000000    107.466274      Unweighted events, alpha=1.528267
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         11237.492737    130.898198      total sum
# 15         7370.000000     85.848704       Unweighted events, alpha=1.524762
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         7170.527985     104.222490      total sum
# 16         4733.000000     68.796802       Unweighted events, alpha=1.515007
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         5251.725586     89.051676       total sum
# 17         3478.000000     58.974571       Unweighted events, alpha=1.509984
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         3847.088196     76.348080       total sum
# 18         2539.000000     50.388491       Unweighted events, alpha=1.515198
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         3119.317902     68.509857       total sum
# 19         2073.000000     45.530210       Unweighted events, alpha=1.504736
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-BWuPOA.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9482fe0
#   Clients:
#     (0x95cba20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9484500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x93afff0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 131403
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9492360
#   Clients:
#     (0x95cba20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9491620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9493350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 382189
# Error in <TList::Clear>: A list is accessing an object (0x95fc6a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95fc94c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9846d20
#   Clients:
#     (0x9845700,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x986e9c0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x93afff0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 14429.8
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9879650
#   Clients:
#     (0x9845700,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x98a6060,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x9493350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 39702.1
# Error in <TList::Clear>: A list is accessing an object (0x95fd144) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95fd3ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9482fe0
#   Clients:
#     (0x95cba20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9484500,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x93afff0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 155436
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9492360
#   Clients:
#     (0x95cba20,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9491620,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9493350,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 445636
# Error in <TList::Clear>: A list is accessing an object (0x95fd694) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x95fd93c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.17504  -0.00254538/+0.00256675  (68% CL)
# Done in 0.04 min (cpu), 0.04 min (real)

# %%
# !combine -M FitDiagnostics -n CR2_both  datacard_CR2_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          171.431753      15.216155       total sum
# 0          127.000000      11.269428       Unweighted events, alpha=1.349856
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          197.206228      16.378682       total sum
# 1          145.000000      12.041595       Unweighted events, alpha=1.360043
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          263.689350      19.345717       total sum
# 2          186.000000      13.638182       Unweighted events, alpha=1.417685
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          359.382887      22.480187       total sum
# 3          256.000000      16.000000       Unweighted events, alpha=1.403839
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          509.594564      26.864671       total sum
# 4          360.000000      18.973666       Unweighted events, alpha=1.415540
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          804.573380      34.134027       total sum
# 5          556.000000      23.579652       Unweighted events, alpha=1.447074
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1283.232407     42.993652       total sum
# 6          891.000000      29.849623       Unweighted events, alpha=1.440216
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1761.666271     50.579487       total sum
# 7          1213.000000     34.828150       Unweighted events, alpha=1.452322
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2673.830185     62.677287       total sum
# 8          1820.000000     42.661458       Unweighted events, alpha=1.469137
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          3813.931419     74.832423       total sum
# 9          2598.000000     50.970580       Unweighted events, alpha=1.468026
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         4497.728874     81.214899       total sum
# 10         3067.000000     55.380502       Unweighted events, alpha=1.466491
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         4417.270035     80.597470       total sum
# 11         3004.000000     54.808758       Unweighted events, alpha=1.470463
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         3333.560707     70.138888       total sum
# 12         2259.000000     47.528939       Unweighted events, alpha=1.475680
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         2120.390423     55.742720       total sum
# 13         1447.000000     38.039453       Unweighted events, alpha=1.465370
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1327.179638     44.030804       total sum
# 14         909.000000      30.149627       Unweighted events, alpha=1.460044
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         865.276258      35.339532       total sum
# 15         599.000000      24.474477       Unweighted events, alpha=1.444535
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         561.082632      28.348543       total sum
# 16         392.000000      19.798990       Unweighted events, alpha=1.431333
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         384.827667      23.398544       total sum
# 17         270.000000      16.431677       Unweighted events, alpha=1.425288
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         286.062269      20.283653       total sum
# 18         199.000000      14.106736       Unweighted events, alpha=1.437499
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         219.517307      17.422585       total sum
# 19         159.000000      12.609520       Unweighted events, alpha=1.380612
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          505.242905      26.753155       total sum
# 0          357.000000      18.894444       Unweighted events, alpha=1.415246
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          598.184208      29.170622       total sum
# 1          421.000000      20.518285       Unweighted events, alpha=1.420865
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          762.647240      33.278065       total sum
# 2          525.000000      22.912878       Unweighted events, alpha=1.452661
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          962.108997      37.601716       total sum
# 3          655.000000      25.592968       Unweighted events, alpha=1.468869
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          1265.423321     43.491552       total sum
# 4          847.000000      29.103264       Unweighted events, alpha=1.494006
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          1782.040298     51.646287       total sum
# 5          1191.000000     34.510868       Unweighted events, alpha=1.496255
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          2628.206825     62.875437       total sum
# 6          1747.000000     41.797129       Unweighted events, alpha=1.504411
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          3905.489014     76.830796       total sum
# 7          2584.000000     50.833060       Unweighted events, alpha=1.511412
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          6154.157379     96.675376       total sum
# 8          4052.000000     63.655322       Unweighted events, alpha=1.518795
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          9751.090134     122.000261      total sum
# 9          6388.000000     79.924965       Unweighted events, alpha=1.526470
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         12501.510162    138.085185      total sum
# 10         8197.000000     90.537285       Unweighted events, alpha=1.525132
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         12804.029816    139.881926      total sum
# 11         8379.000000     91.536878       Unweighted events, alpha=1.528110
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         9899.042526     122.714599      total sum
# 12         6507.000000     80.665978       Unweighted events, alpha=1.521291
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         6352.192383     98.357711       total sum
# 13         4171.000000     64.583280       Unweighted events, alpha=1.522942
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         3765.677582     75.357871       total sum
# 14         2497.000000     49.969991       Unweighted events, alpha=1.508081
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         2481.946716     61.154857       total sum
# 15         1647.000000     40.583248       Unweighted events, alpha=1.506950
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         1561.592648     48.338428       total sum
# 16         1044.000000     32.310989       Unweighted events, alpha=1.495778
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         1078.911453     40.043184       total sum
# 17         726.000000      26.944387       Unweighted events, alpha=1.486104
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         806.207237      34.494018       total sum
# 18         546.000000      23.366643       Unweighted events, alpha=1.476570
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         695.654243      31.980713       total sum
# 19         473.000000      21.748563       Unweighted events, alpha=1.470728
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-eOVFle.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9967f00
#   Clients:
#     (0x9ab0920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9969420,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x9894f50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 29851.4
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9977260
#   Clients:
#     (0x9ab0920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9976520,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9978250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 80261.4
# Error in <TList::Clear>: A list is accessing an object (0x9ae15a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ae184c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d2b9e0
#   Clients:
#     (0x9d2a3c0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9d53640,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x9894f50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 3695.78
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9d5e2d0
#   Clients:
#     (0x9d2a3c0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9d8ab00,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x9978250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 9601.27
# Error in <TList::Clear>: A list is accessing an object (0x9ae2044) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ae22ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9967f00
#   Clients:
#     (0x9ab0920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9969420,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x9894f50,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 35944.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9977260
#   Clients:
#     (0x9ab0920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x9976520,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x9978250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 95452.9
# Error in <TList::Clear>: A list is accessing an object (0x9ae2594) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x9ae283c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.19995  -0.00562194/+0.00567841  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR3_both  datacard_CR3_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          77.791001       10.255710       total sum
# 0          58.000000       7.615773        Unweighted events, alpha=1.341224
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          78.611232       10.471179       total sum
# 1          56.000000       7.483315        Unweighted events, alpha=1.403772
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          83.572454       10.705929       total sum
# 2          61.000000       7.810250        Unweighted events, alpha=1.370040
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          109.311094      12.499823       total sum
# 3          76.000000       8.717798        Unweighted events, alpha=1.438304
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          139.650349      14.031369       total sum
# 4          99.000000       9.949874        Unweighted events, alpha=1.410610
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          272.500199      19.949082       total sum
# 5          187.000000      13.674794       Unweighted events, alpha=1.457220
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          401.076603      24.093967       total sum
# 6          277.000000      16.643317       Unweighted events, alpha=1.447930
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          632.953136      30.288350       total sum
# 7          437.000000      20.904545       Unweighted events, alpha=1.448405
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          924.277266      36.756238       total sum
# 8          632.000000      25.139610       Unweighted events, alpha=1.462464
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1259.842903     42.885587       total sum
# 9          863.000000      29.376862       Unweighted events, alpha=1.459841
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1640.223169     49.195273       total sum
# 10         1112.000000     33.346664       Unweighted events, alpha=1.475021
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1532.759693     47.578498       total sum
# 11         1038.000000     32.218007       Unweighted events, alpha=1.476647
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1144.909218     41.111751       total sum
# 12         776.000000      27.856777       Unweighted events, alpha=1.475398
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         720.851606      32.599612       total sum
# 13         489.000000      22.113344       Unweighted events, alpha=1.474134
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         416.080704      24.607702       total sum
# 14         286.000000      16.911535       Unweighted events, alpha=1.454828
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         284.197802      20.310746       total sum
# 15         196.000000      14.000000       Unweighted events, alpha=1.449989
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         167.852180      15.273470       total sum
# 16         121.000000      11.000000       Unweighted events, alpha=1.387208
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         125.548911      13.238245       total sum
# 17         90.000000       9.486833        Unweighted events, alpha=1.394988
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         102.432501      11.966870       total sum
# 18         73.000000       8.544004        Unweighted events, alpha=1.403185
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         95.274824       11.715139       total sum
# 19         66.000000       8.124038        Unweighted events, alpha=1.443558
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          193.569410      16.665537       total sum
# 0          135.000000      11.618950       Unweighted events, alpha=1.433847
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          202.826868      16.915386       total sum
# 1          144.000000      12.000000       Unweighted events, alpha=1.408520
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          226.155766      17.946275       total sum
# 2          159.000000      12.609520       Unweighted events, alpha=1.422363
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          322.905558      21.562592       total sum
# 3          224.000000      14.966630       Unweighted events, alpha=1.441543
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          422.316101      24.933924       total sum
# 4          287.000000      16.941074       Unweighted events, alpha=1.471485
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          566.991472      29.022345       total sum
# 5          382.000000      19.544820       Unweighted events, alpha=1.484271
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          891.656244      36.630902       total sum
# 6          593.000000      24.351591       Unweighted events, alpha=1.503636
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1272.453648     43.812899       total sum
# 7          843.000000      29.034462       Unweighted events, alpha=1.509435
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1963.375217     54.577858       total sum
# 8          1294.000000     35.972211       Unweighted events, alpha=1.517292
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          2989.548904     67.406017       total sum
# 9          1967.000000     44.350874       Unweighted events, alpha=1.519852
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         3798.563370     76.098915       total sum
# 10         2492.000000     49.919936       Unweighted events, alpha=1.524303
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         3961.583237     77.681933       total sum
# 11         2601.000000     51.000000       Unweighted events, alpha=1.523100
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         3119.463181     68.852134       total sum
# 12         2053.000000     45.310043       Unweighted events, alpha=1.519466
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         2074.125595     56.219409       total sum
# 13         1361.000000     36.891733       Unweighted events, alpha=1.523972
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1255.152771     43.423421       total sum
# 14         835.000000      28.896367       Unweighted events, alpha=1.503177
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         773.744881      34.116220       total sum
# 15         514.000000      22.671568       Unweighted events, alpha=1.505340
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         499.557104      27.378570       total sum
# 16         333.000000      18.248288       Unweighted events, alpha=1.500171
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         362.331627      23.029474       total sum
# 17         248.000000      15.748016       Unweighted events, alpha=1.461015
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         264.563425      19.467055       total sum
# 18         185.000000      13.601471       Unweighted events, alpha=1.430073
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         205.025549      16.916035       total sum
# 19         147.000000      12.124356       Unweighted events, alpha=1.394732
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-a2TOaR.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8f53e60
#   Clients:
#     (0x909c880,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8f55380,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8e80e90,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 10209.7
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8f631c0
#   Clients:
#     (0x909c880,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8f62480,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8f641b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 25365.9
# Error in <TList::Clear>: A list is accessing an object (0x90cd504) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x90cd7ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x93179d0
#   Clients:
#     (0x93163b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x933f7b0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8e80e90,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 1146.45
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x934a3e0
#   Clients:
#     (0x93163b0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9376bb0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8f641b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2803.64
# Error in <TList::Clear>: A list is accessing an object (0x90cdfa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x90ce24c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8f53e60
#   Clients:
#     (0x909c880,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8f55380,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8e80e90,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 10969.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8f631c0
#   Clients:
#     (0x909c880,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8f62480,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8f641b0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 27111.3
# Error in <TList::Clear>: A list is accessing an object (0x90ce4f4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x90ce79c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.07444  -0.00906597/+0.00917133  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR4_both  datacard_CR4_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          109.961586      9.427760        total sum
# 0          136.000000      11.661904       Unweighted events, alpha=0.808541
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          113.869049      9.402345        total sum
# 1          147.000000      12.124356       Unweighted events, alpha=0.774619
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          152.258038      11.687911       total sum
# 2          170.000000      13.038405       Unweighted events, alpha=0.895636
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          207.540298      14.902429       total sum
# 3          194.000000      13.928388       Unweighted events, alpha=1.069795
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          259.934334      17.127238       total sum
# 4          230.000000      15.165751       Unweighted events, alpha=1.130149
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          414.091732      22.803151       total sum
# 5          330.000000      18.165902       Unweighted events, alpha=1.254823
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          554.000298      26.772777       total sum
# 6          428.000000      20.688161       Unweighted events, alpha=1.294393
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          825.489975      33.192327       total sum
# 7          619.000000      24.879711       Unweighted events, alpha=1.333586
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          1208.093689     40.721403       total sum
# 8          880.000000      29.664794       Unweighted events, alpha=1.372834
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1666.945786     48.068566       total sum
# 9          1203.000000     34.684290       Unweighted events, alpha=1.385657
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1921.794052     51.805387       total sum
# 10         1376.000000     37.094474       Unweighted events, alpha=1.396653
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1850.760147     51.010225       total sum
# 11         1316.000000     36.276714       Unweighted events, alpha=1.406353
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1376.044624     43.746360       total sum
# 12         989.000000      31.448370       Unweighted events, alpha=1.391349
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         913.579201      35.038259       total sum
# 13         680.000000      26.076810       Unweighted events, alpha=1.343499
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         670.416405      29.949236       total sum
# 14         501.000000      22.383029       Unweighted events, alpha=1.338156
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         416.084114      22.725341       total sum
# 15         335.000000      18.303005       Unweighted events, alpha=1.242042
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         285.408966      17.750290       total sum
# 16         259.000000      16.093477       Unweighted events, alpha=1.101965
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         217.882240      15.008701       total sum
# 17         211.000000      14.525839       Unweighted events, alpha=1.032617
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         181.717407      12.812225       total sum
# 18         201.000000      14.177447       Unweighted events, alpha=0.904067
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         163.772736      12.130551       total sum
# 19         182.000000      13.490738       Unweighted events, alpha=0.899850
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          387.984741      18.421472       total sum
# 0          444.000000      21.071308       Unweighted events, alpha=0.873840
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          446.522247      21.207773       total sum
# 1          443.000000      21.047565       Unweighted events, alpha=1.007951
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          502.498444      22.430667       total sum
# 2          502.000000      22.405357       Unweighted events, alpha=1.000993
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          550.887924      24.032089       total sum
# 3          525.000000      22.912878       Unweighted events, alpha=1.049310
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          736.861664      29.202716       total sum
# 4          637.000000      25.238859       Unweighted events, alpha=1.156769
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          896.046249      33.081747       total sum
# 5          734.000000      27.092434       Unweighted events, alpha=1.220771
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          1293.501480     41.307769       total sum
# 6          981.000000      31.320920       Unweighted events, alpha=1.318554
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          1876.935547     50.694493       total sum
# 7          1371.000000     37.027017       Unweighted events, alpha=1.369027
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          2889.394928     64.176645       total sum
# 8          2027.000000     45.022217       Unweighted events, alpha=1.425454
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          4405.644226     79.940875       total sum
# 9          3037.000000     55.108983       Unweighted events, alpha=1.450657
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         5939.804901     93.285472       total sum
# 10         4054.000000     63.671030       Unweighted events, alpha=1.465171
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         6175.799286     95.219930       total sum
# 11         4207.000000     64.861391       Unweighted events, alpha=1.467982
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         4640.606598     82.059028       total sum
# 12         3198.000000     56.550862       Unweighted events, alpha=1.451096
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         3003.268845     65.249892       total sum
# 13         2119.000000     46.032597       Unweighted events, alpha=1.417305
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         1770.359787     49.051097       total sum
# 14         1303.000000     36.097091       Unweighted events, alpha=1.358680
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         1163.871002     38.676684       total sum
# 15         906.000000      30.099834       Unweighted events, alpha=1.284626
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         868.426682      32.358194       total sum
# 16         720.000000      26.832816       Unweighted events, alpha=1.206148
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         661.554764      26.919705       total sum
# 17         604.000000      24.576411       Unweighted events, alpha=1.095289
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         538.539551      23.145218       total sum
# 18         541.000000      23.259407       Unweighted events, alpha=0.995452
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         449.196060      20.401201       total sum
# 19         485.000000      22.022716       Unweighted events, alpha=0.926177
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-4aQ0mI.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7cfcf00
#   Clients:
#     (0x7e45920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7cfe420,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7c29f20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 13509.6
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7d0c260
#   Clients:
#     (0x7e45920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7d0b520,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7d0d250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 39197.7
# Error in <TList::Clear>: A list is accessing an object (0x7e765a4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e7684c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x80c0c60
#   Clients:
#     (0x80bf640,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x80e8830,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7c29f20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 2404.98
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x80f34c0
#   Clients:
#     (0x80bf640,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x811fcf0,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7d0d250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 6808.37
# Error in <TList::Clear>: A list is accessing an object (0x7e77044) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e772ec) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7cfcf00
#   Clients:
#     (0x7e45920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7cfe420,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7c29f20,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 16072.2
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7d0c260
#   Clients:
#     (0x7e45920,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7d0b520,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7d0d250,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 45416.4
# Error in <TList::Clear>: A list is accessing an object (0x7e77594) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e7783c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.188  -0.00846259/+0.00855871  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR5_both  datacard_CR5_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          41.294193       4.806696        total sum
# 0          74.000000       8.602325        Unweighted events, alpha=0.558030
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          55.834621       6.562352        total sum
# 1          72.000000       8.485281        Unweighted events, alpha=0.775481
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          74.946318       8.268386        total sum
# 2          82.000000       9.055385        Unweighted events, alpha=0.913979
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          56.829157       6.846390        total sum
# 3          69.000000       8.306624        Unweighted events, alpha=0.823611
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          96.017273       10.068965       total sum
# 4          91.000000       9.539392        Unweighted events, alpha=1.055135
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          115.069775      11.070340       total sum
# 5          108.000000      10.392305       Unweighted events, alpha=1.065461
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          188.875338      15.477688       total sum
# 6          149.000000      12.206556       Unweighted events, alpha=1.267620
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          282.435474      19.258020       total sum
# 7          215.000000      14.662878       Unweighted events, alpha=1.313653
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          412.110699      23.791603       total sum
# 8          300.000000      17.320508       Unweighted events, alpha=1.373702
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          601.129902      28.942408       total sum
# 9          431.000000      20.760539       Unweighted events, alpha=1.394733
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         609.698849      29.161424       total sum
# 10         437.000000      20.904545       Unweighted events, alpha=1.395192
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         667.789066      30.613622       total sum
# 11         476.000000      21.817424       Unweighted events, alpha=1.402918
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         482.821331      25.543893       total sum
# 12         357.000000      18.894444       Unweighted events, alpha=1.352441
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         277.618008      18.933942       total sum
# 13         215.000000      14.662878       Unweighted events, alpha=1.291247
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         213.615612      16.244975       total sum
# 14         173.000000      13.152946       Unweighted events, alpha=1.234772
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         168.199280      14.251022       total sum
# 15         139.000000      11.789826       Unweighted events, alpha=1.210067
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         109.125343      10.922387       total sum
# 16         100.000000      10.000000       Unweighted events, alpha=1.091253
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         86.787052       8.910447        total sum
# 17         95.000000       9.746794        Unweighted events, alpha=0.913548
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         71.763630       7.485091        total sum
# 18         92.000000       9.591663        Unweighted events, alpha=0.780039
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         54.823921       5.768910        total sum
# 19         90.000000       9.486833        Unweighted events, alpha=0.609155
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          156.805626      10.793688       total sum
# 0          211.000000      14.525839       Unweighted events, alpha=0.743155
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          118.717964      7.765075        total sum
# 1          234.000000      15.297059       Unweighted events, alpha=0.507342
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          176.132500      11.932778       total sum
# 2          218.000000      14.764823       Unweighted events, alpha=0.807947
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          215.151901      14.247639       total sum
# 3          228.000000      15.099669       Unweighted events, alpha=0.943649
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          257.218910      16.272812       total sum
# 4          250.000000      15.811388       Unweighted events, alpha=1.028876
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          300.375145      18.317155       total sum
# 5          269.000000      16.401219       Unweighted events, alpha=1.116636
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          414.388939      22.446599       total sum
# 6          341.000000      18.466185       Unweighted events, alpha=1.215217
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          544.131500      26.284022       total sum
# 7          429.000000      20.712315       Unweighted events, alpha=1.268372
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          868.488052      34.444503       total sum
# 8          636.000000      25.219040       Unweighted events, alpha=1.365547
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          1367.989540     44.021549       total sum
# 9          966.000000      31.080541       Unweighted events, alpha=1.416138
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         1798.983063     50.963877       total sum
# 10         1246.000000     35.298725       Unweighted events, alpha=1.443807
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         1869.783539     52.072936       total sum
# 11         1289.000000     35.902646       Unweighted events, alpha=1.450569
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         1443.301506     45.256215       total sum
# 12         1017.000000     31.890437       Unweighted events, alpha=1.419176
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         936.829956      35.921498       total sum
# 13         680.000000      26.076810       Unweighted events, alpha=1.377691
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         614.357780      28.434119       total sum
# 14         467.000000      21.610183       Unweighted events, alpha=1.315541
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         373.169144      20.911962       total sum
# 15         318.000000      17.832555       Unweighted events, alpha=1.173488
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         277.775337      17.033031       total sum
# 16         266.000000      16.309506       Unweighted events, alpha=1.044268
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         231.413292      14.864523       total sum
# 17         242.000000      15.556349       Unweighted events, alpha=0.956253
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         195.069962      12.887095       total sum
# 18         229.000000      15.132746       Unweighted events, alpha=0.851834
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         170.478668      11.436413       total sum
# 19         222.000000      14.899664       Unweighted events, alpha=0.767922
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-9HrWnQ.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86afe40
#   Clients:
#     (0x87f8860,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86b1360,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x85dce80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 4666.78
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86bf1a0
#   Clients:
#     (0x87f8860,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86be460,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x86c0190,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 12330.6
# Error in <TList::Clear>: A list is accessing an object (0x88294e4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x882978c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8a73910
#   Clients:
#     (0x8a722f0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8a9b5b0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x85dce80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 996.026
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8aa6240
#   Clients:
#     (0x8a722f0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8ad2a10,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x86c0190,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2780.1
# Error in <TList::Clear>: A list is accessing an object (0x8829f84) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x882a22c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86afe40
#   Clients:
#     (0x87f8860,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86b1360,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x85dce80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 5549.85
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x86bf1a0
#   Clients:
#     (0x87f8860,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x86be460,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x86c0190,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 14492.9
# Error in <TList::Clear>: A list is accessing an object (0x882a4d4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x882a77c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.21856  -0.0158646/+0.0161768  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR6_both  datacard_CR6_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          44.789436       4.283176        total sum
# 0          109.000000      10.440307       Unweighted events, alpha=0.410912
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          41.296283       3.091230        total sum
# 1          178.000000      13.341664       Unweighted events, alpha=0.232002
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          44.772121       4.127301        total sum
# 2          118.000000      10.862780       Unweighted events, alpha=0.379425
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          50.718843       4.720840        total sum
# 3          115.000000      10.723805       Unweighted events, alpha=0.441033
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          48.338447       4.289722        total sum
# 4          127.000000      11.269428       Unweighted events, alpha=0.380618
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          61.025431       6.174382        total sum
# 5          98.000000       9.899495        Unweighted events, alpha=0.622708
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          77.905762       7.467809        total sum
# 6          109.000000      10.440307       Unweighted events, alpha=0.714732
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          104.699173      9.304807        total sum
# 7          127.000000      11.269428       Unweighted events, alpha=0.824403
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          139.678932      11.860561       total sum
# 8          139.000000      11.789826       Unweighted events, alpha=1.004884
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          203.966152      14.989773       total sum
# 9          185.000000      13.601471       Unweighted events, alpha=1.102520
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         232.123245      16.219280       total sum
# 10         205.000000      14.317821       Unweighted events, alpha=1.132309
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         222.068691      16.004158       total sum
# 11         193.000000      13.892444       Unweighted events, alpha=1.150615
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         159.550922      12.822011       total sum
# 12         155.000000      12.449900       Unweighted events, alpha=1.029361
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         126.269737      10.718421       total sum
# 13         139.000000      11.789826       Unweighted events, alpha=0.908415
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         94.055008       8.702219        total sum
# 14         117.000000      10.816654       Unweighted events, alpha=0.803889
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         69.442106       6.264195        total sum
# 15         123.000000      11.090537       Unweighted events, alpha=0.564570
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         59.679873       5.113479        total sum
# 16         136.000000      11.661904       Unweighted events, alpha=0.438823
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         51.609323       3.687136        total sum
# 17         196.000000      14.000000       Unweighted events, alpha=0.263313
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         56.427877       4.328246        total sum
# 18         170.000000      13.038405       Unweighted events, alpha=0.331929
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         49.574320       3.156498        total sum
# 19         247.000000      15.716234       Unweighted events, alpha=0.200706
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          125.219860      5.429380        total sum
# 0          532.000000      23.065125       Unweighted events, alpha=0.235376
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          134.327269      6.404670        total sum
# 1          440.000000      20.976177       Unweighted events, alpha=0.305289
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          139.054981      6.827220        total sum
# 2          415.000000      20.371549       Unweighted events, alpha=0.335072
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          151.903740      8.244792        total sum
# 3          339.000000      18.411953       Unweighted events, alpha=0.448094
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          153.523903      8.111019        total sum
# 4          358.000000      18.920888       Unweighted events, alpha=0.428838
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          180.488914      10.355869       total sum
# 5          304.000000      17.435596       Unweighted events, alpha=0.593714
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          206.496773      11.798599       total sum
# 6          306.000000      17.492856       Unweighted events, alpha=0.674826
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          250.758484      14.155105       total sum
# 7          314.000000      17.720045       Unweighted events, alpha=0.798594
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          387.779266      20.083891       total sum
# 8          373.000000      19.313208       Unweighted events, alpha=1.039623
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          510.340576      23.823744       total sum
# 9          459.000000      21.424285       Unweighted events, alpha=1.111853
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         682.106857      28.561437       total sum
# 10         570.000000      23.874673       Unweighted events, alpha=1.196679
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         696.928375      28.860083       total sum
# 11         583.000000      24.145393       Unweighted events, alpha=1.195417
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         524.802002      24.178352       total sum
# 12         471.000000      21.702534       Unweighted events, alpha=1.114229
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         402.374542      20.198978       total sum
# 13         397.000000      19.924859       Unweighted events, alpha=1.013538
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         268.093498      14.971309       total sum
# 14         321.000000      17.916473       Unweighted events, alpha=0.835182
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         214.757065      12.010878       total sum
# 15         320.000000      17.888544       Unweighted events, alpha=0.671116
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         183.762688      10.106222       total sum
# 16         331.000000      18.193405       Unweighted events, alpha=0.555174
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         155.320755      7.862826        total sum
# 17         390.000000      19.748418       Unweighted events, alpha=0.398258
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         147.921579      6.978388        total sum
# 18         449.000000      21.189620       Unweighted events, alpha=0.329447
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         134.317476      6.173715        total sum
# 19         473.000000      21.748563       Unweighted events, alpha=0.283969
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-cTGyPU.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x857de10
#   Clients:
#     (0x86c6830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x857f330,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x84aae80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1937.99
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x858d170
#   Clients:
#     (0x86c6830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x858c430,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x858e160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 5650.28
# Error in <TList::Clear>: A list is accessing an object (0x86f7504) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86f77ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8941550
#   Clients:
#     (0x893ff30,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8969430,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x84aae80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 891.748
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x89740c0
#   Clients:
#     (0x893ff30,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x89a0950,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x858e160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2572.29
# Error in <TList::Clear>: A list is accessing an object (0x86f7fa4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86f824c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x857de10
#   Clients:
#     (0x86c6830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x857f330,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x84aae80,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2188.36
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x858d170
#   Clients:
#     (0x86c6830,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x858c430,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x858e160,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 6277.25
# Error in <TList::Clear>: A list is accessing an object (0x86f84f4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86f879c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.20455  -0.0292708/+0.0302264  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n CR7_both  datacard_CR7_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          23.757116       1.807496        total sum
# 0          173.000000      13.152946       Unweighted events, alpha=0.137324
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          25.425773       2.721573        total sum
# 1          87.000000       9.327379        Unweighted events, alpha=0.292250
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          29.094074       3.503809        total sum
# 2          69.000000       8.306624        Unweighted events, alpha=0.421653
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          36.423377       4.412916        total sum
# 3          68.000000       8.246211        Unweighted events, alpha=0.535638
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          32.656796       4.021809        total sum
# 4          66.000000       8.124038        Unweighted events, alpha=0.494800
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          39.393843       4.976666        total sum
# 5          63.000000       7.937254        Unweighted events, alpha=0.625299
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          59.256109       7.117168        total sum
# 6          69.000000       8.306624        Unweighted events, alpha=0.858784
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          53.424519       6.595976        total sum
# 7          66.000000       8.124038        Unweighted events, alpha=0.809462
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          79.020124       8.758635        total sum
# 8          81.000000       9.000000        Unweighted events, alpha=0.975557
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          91.288265       9.837624        total sum
# 9          86.000000       9.273618        Unweighted events, alpha=1.061491
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         105.779276      10.557806       total sum
# 10         100.000000      10.000000       Unweighted events, alpha=1.057793
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         112.861702      10.906806       total sum
# 11         107.000000      10.344080       Unweighted events, alpha=1.054782
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         86.681389       9.383368        total sum
# 12         85.000000       9.219544        Unweighted events, alpha=1.019781
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         58.303255       6.886373        total sum
# 13         72.000000       8.485281        Unweighted events, alpha=0.809767
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         63.412642       7.431054        total sum
# 14         73.000000       8.544004        Unweighted events, alpha=0.868666
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         41.447599       4.838667        total sum
# 15         73.000000       8.544004        Unweighted events, alpha=0.567775
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         40.283850       4.436005        total sum
# 16         82.000000       9.055385        Unweighted events, alpha=0.491266
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         27.954129       2.362271        total sum
# 17         140.000000      11.832160       Unweighted events, alpha=0.199672
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         34.570722       3.765693        total sum
# 18         84.000000       9.165151        Unweighted events, alpha=0.411556
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         31.774667       3.440174        total sum
# 19         85.000000       9.219544        Unweighted events, alpha=0.373820
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          74.191243       3.884802        total sum
# 0          365.000000      19.104973       Unweighted events, alpha=0.203264
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          70.792795       3.256017        total sum
# 1          473.000000      21.748563       Unweighted events, alpha=0.149668
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          91.087252       6.561369        total sum
# 2          193.000000      13.892444       Unweighted events, alpha=0.471955
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          93.905775       6.677894        total sum
# 3          198.000000      14.071247       Unweighted events, alpha=0.474272
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          96.503407       6.635939        total sum
# 4          211.000000      14.525839       Unweighted events, alpha=0.457362
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          98.899858       7.070237        total sum
# 5          196.000000      14.000000       Unweighted events, alpha=0.504591
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          125.454712      9.387641        total sum
# 6          179.000000      13.379088       Unweighted events, alpha=0.700864
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          150.234909      10.922923       total sum
# 7          189.000000      13.747727       Unweighted events, alpha=0.794894
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          174.198639      12.374843       total sum
# 8          198.000000      14.071247       Unweighted events, alpha=0.879791
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          262.865982      16.738283       total sum
# 9          247.000000      15.716234       Unweighted events, alpha=1.064235
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         362.173294      20.536649       total sum
# 10         311.000000      17.635192       Unweighted events, alpha=1.164544
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         304.269585      18.337112       total sum
# 11         275.000000      16.583124       Unweighted events, alpha=1.106435
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         267.251839      16.955906       total sum
# 12         248.000000      15.748016       Unweighted events, alpha=1.077628
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         210.699547      14.283770       total sum
# 13         218.000000      14.764823       Unweighted events, alpha=0.966512
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         142.219101      10.719102       total sum
# 14         176.000000      13.266499       Unweighted events, alpha=0.808063
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         110.666195      7.790816        total sum
# 15         202.000000      14.212670       Unweighted events, alpha=0.547852
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         95.714361       6.250924        total sum
# 16         234.000000      15.297059       Unweighted events, alpha=0.409036
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         100.081303      6.437124        total sum
# 17         242.000000      15.556349       Unweighted events, alpha=0.413559
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         86.199646       5.456631        total sum
# 18         250.000000      15.811388       Unweighted events, alpha=0.344799
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         83.861000       4.971580        total sum
# 19         285.000000      16.881943       Unweighted events, alpha=0.294249
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-FoxFnQ.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8d79860
#   Clients:
#     (0x8ec22b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8d7ad80,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8ca6870,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1072.81
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8d88bf0
#   Clients:
#     (0x8ec22b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8d87eb0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8d89be0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 3001.27
# Error in <TList::Clear>: A list is accessing an object (0x8ef2f14) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8ef31bc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x913e0c0
#   Clients:
#     (0x913caa0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x9165e40,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x8ca6870,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 535.774
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x9170ad0
#   Clients:
#     (0x913caa0,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x919d480,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x8d89be0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 1512.42
# Error in <TList::Clear>: A list is accessing an object (0x8ef39b4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8ef3c5c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8d79860
#   Clients:
#     (0x8ec22b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8d7ad80,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x8ca6870,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 1239.36
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8d88bf0
#   Clients:
#     (0x8ec22b0,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x8d87eb0,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x8d89be0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 3373.62
# Error in <TList::Clear>: A list is accessing an object (0x8ef3f04) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8ef41ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.26891  -0.0440376/+0.0463374  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)

# %%
# !combine -M FitDiagnostics -n SR8_both  datacard_SR8_both.txt --saveWithUncertainties --plots
# Out:
#  <<< Combine >>>
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# Channel elJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binelJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          33.827014       4.116612        total sum
# 0          68.000000       8.246211        Unweighted events, alpha=0.497456
#   => Total parameter prop_binelJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          49.699499       5.412697        total sum
# 1          84.000000       9.165151        Unweighted events, alpha=0.591661
#   => Total parameter prop_binelJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          45.608904       5.290193        total sum
# 2          74.000000       8.602325        Unweighted events, alpha=0.616337
#   => Total parameter prop_binelJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          65.485868       7.407957        total sum
# 3          78.000000       8.831761        Unweighted events, alpha=0.839562
#   => Total parameter prop_binelJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          69.401314       7.853073        total sum
# 4          78.000000       8.831761        Unweighted events, alpha=0.889760
#   => Total parameter prop_binelJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          90.705294       9.531393        total sum
# 5          91.000000       9.539392        Unweighted events, alpha=0.996761
#   => Total parameter prop_binelJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          108.282017      10.685739       total sum
# 6          103.000000      10.148892       Unweighted events, alpha=1.051282
#   => Total parameter prop_binelJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          205.151890      15.789689       total sum
# 7          169.000000      13.000000       Unweighted events, alpha=1.213917
#   => Total parameter prop_binelJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          203.500584      15.702632       total sum
# 8          168.000000      12.961481       Unweighted events, alpha=1.211313
#   => Total parameter prop_binelJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          328.318115      20.417015       total sum
# 9          259.000000      16.093477       Unweighted events, alpha=1.267638
#   => Total parameter prop_binelJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         417.393257      23.377636       total sum
# 10         319.000000      17.860571       Unweighted events, alpha=1.308443
#   => Total parameter prop_binelJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         348.301025      21.266020       total sum
# 11         268.000000      16.370706       Unweighted events, alpha=1.299631
#   => Total parameter prop_binelJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         280.378254      18.845315       total sum
# 12         221.000000      14.866069       Unweighted events, alpha=1.268680
#   => Total parameter prop_binelJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         179.526360      14.666030       total sum
# 13         150.000000      12.247449       Unweighted events, alpha=1.196842
#   => Total parameter prop_binelJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         125.626720      11.528278       total sum
# 14         119.000000      10.908712       Unweighted events, alpha=1.055687
#   => Total parameter prop_binelJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         87.959652       8.802079        total sum
# 15         100.000000      10.000000       Unweighted events, alpha=0.879597
#   => Total parameter prop_binelJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         70.579304       7.475311        total sum
# 16         89.000000       9.433981        Unweighted events, alpha=0.793026
#   => Total parameter prop_binelJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         61.135450       6.770071        total sum
# 17         82.000000       9.055385        Unweighted events, alpha=0.745554
#   => Total parameter prop_binelJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         52.887518       5.282426        total sum
# 18         100.000000      10.000000       Unweighted events, alpha=0.528875
#   => Total parameter prop_binelJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         47.664819       4.945563        total sum
# 19         93.000000       9.643651        Unweighted events, alpha=0.512525
#   => Total parameter prop_binelJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Channel muJets will use autoMCStats with settings: event-threshold=0, include-signal=1, hist-mode=1
# ============================================================
# Analysing bin errors for: prop_binmuJets
# Poisson cut-off: 0
# ============================================================
# Bin        Contents        Error           Notes
# 0          105.836517      6.880224        total sum
# 0          237.000000      15.394804       Unweighted events, alpha=0.446568
#   => Total parameter prop_binmuJets_bin0[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 1          117.547241      7.500897        total sum
# 1          246.000000      15.684387       Unweighted events, alpha=0.477834
#   => Total parameter prop_binmuJets_bin1[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 2          125.394444      8.093994        total sum
# 2          240.000000      15.491933       Unweighted events, alpha=0.522477
#   => Total parameter prop_binmuJets_bin2[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 3          151.694214      10.484511       total sum
# 3          209.000000      14.456832       Unweighted events, alpha=0.725810
#   => Total parameter prop_binmuJets_bin3[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 4          181.137650      12.414193       total sum
# 4          213.000000      14.594520       Unweighted events, alpha=0.850412
#   => Total parameter prop_binmuJets_bin4[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 5          206.505638      13.940588       total sum
# 5          219.000000      14.798649       Unweighted events, alpha=0.942948
#   => Total parameter prop_binmuJets_bin5[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 6          264.011536      16.533268       total sum
# 6          255.000000      15.968719       Unweighted events, alpha=1.035339
#   => Total parameter prop_binmuJets_bin6[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 7          367.987038      20.708831       total sum
# 7          316.000000      17.776389       Unweighted events, alpha=1.164516
#   => Total parameter prop_binmuJets_bin7[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 8          465.706894      23.853836       total sum
# 8          381.000000      19.519221       Unweighted events, alpha=1.222328
#   => Total parameter prop_binmuJets_bin8[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 9          723.650513      30.917809       total sum
# 9          548.000000      23.409400       Unweighted events, alpha=1.320530
#   => Total parameter prop_binmuJets_bin9[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 10         993.898643      36.875983       total sum
# 10         726.000000      26.944387       Unweighted events, alpha=1.369006
#   => Total parameter prop_binmuJets_bin10[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 11         977.392868      36.214554       total sum
# 11         728.000000      26.981475       Unweighted events, alpha=1.342573
#   => Total parameter prop_binmuJets_bin11[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 12         780.320068      32.033507       total sum
# 12         593.000000      24.351591       Unweighted events, alpha=1.315885
#   => Total parameter prop_binmuJets_bin12[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 13         515.314224      25.384922       total sum
# 13         412.000000      20.297783       Unweighted events, alpha=1.250763
#   => Total parameter prop_binmuJets_bin13[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 14         340.306496      19.175530       total sum
# 14         315.000000      17.748239       Unweighted events, alpha=1.080338
#   => Total parameter prop_binmuJets_bin14[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 15         254.089279      15.820931       total sum
# 15         258.000000      16.062378       Unweighted events, alpha=0.984842
#   => Total parameter prop_binmuJets_bin15[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 16         184.566986      12.250079       total sum
# 16         227.000000      15.066519       Unweighted events, alpha=0.813070
#   => Total parameter prop_binmuJets_bin16[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 17         157.998451      10.633682       total sum
# 17         221.000000      14.866069       Unweighted events, alpha=0.714925
#   => Total parameter prop_binmuJets_bin17[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 18         146.880989      10.189858       total sum
# 18         208.000000      14.422205       Unweighted events, alpha=0.706159
#   => Total parameter prop_binmuJets_bin18[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# 19         126.935665      8.645598        total sum
# 19         216.000000      14.696938       Unweighted events, alpha=0.587665
#   => Total parameter prop_binmuJets_bin19[0.00,-7.00,7.00] to be gaussian constrained
# ------------------------------------------------------------
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-JWGqAg.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7c21e70
#   Clients:
#     (0x7d6a890,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7c23390,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7b4eea0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 2871.43
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7c311d0
#   Clients:
#     (0x7d6a890,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7c30490,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7c321c0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 7187.18
# Error in <TList::Clear>: A list is accessing an object (0x7d9b514) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7d9b7bc) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_prefit.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binelJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7fe5d40
#   Clients:
#     (0x7fe4720,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x800dbe0,V-) RooRealSumPdf::pdf_binelJets_nuis__model_bonly_ ""
#     (0x7b4eea0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis__model_bonly_
#       2)                 pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets__model_bonly_ = 852.671
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binmuJets,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x8018870
#   Clients:
#     (0x7fe4720,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x8045100,V-) RooRealSumPdf::pdf_binmuJets_nuis__model_bonly_ ""
#     (0x7c321c0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis__model_bonly_
#       2)                 pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets__model_bonly_ = 2222.63
# Error in <TList::Clear>: A list is accessing an object (0x7d9bfb4) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7d9c25c) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7c21e70
#   Clients:
#     (0x7d6a890,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7c23390,V-) RooRealSumPdf::pdf_binelJets_nuis ""
#     (0x7b4eea0,V-) RooProdPdf::pdfbins_binelJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binelJets_nuis
#       2)   pdfbins_binelJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binelJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore elJets (elJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in elJets_CMS_th1x, pdf pdf_binelJets = 3282.41
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x7c311d0
#   Clients:
#     (0x7d6a890,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x7c30490,V-) RooRealSumPdf::pdf_binmuJets_nuis ""
#     (0x7c321c0,V-) RooProdPdf::pdfbins_binmuJets ""
#   Proxies:
#     !pdfs ->
#       1)  pdf_binmuJets_nuis
#       2)   pdfbins_binmuJets
# --- RooAbsReal ---
#
#   Plot label is "pdf_binmuJets"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore muJets (muJets)
#   Contains 20 entries
#   Observables:
#     1)  CMS_th1x = 19.5  L(0 - 20) B(20)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in muJets_CMS_th1x, pdf pdf_binmuJets = 8086.21
# Error in <TList::Clear>: A list is accessing an object (0x7d9c504) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7d9c7ac) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./elJets_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./muJets_CMS_th1x_fit_s.png has been created
# Warning in <TFile::Append>: Replacing existing TH1: correlation_matrix (Potential memory leak).
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 1.18452  -0.0218656/+0.0223831  (68% CL)
# Done in 0.04 min (cpu), 0.05 min (real)
